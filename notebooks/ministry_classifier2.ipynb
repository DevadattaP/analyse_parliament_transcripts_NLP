# %%
import json
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

import sys
sys.path.append("../")
from src.preprocessing.pdf_extractor import PDFExtractor
from src.preprocessing.document_validator import DocumentValidator

# %%
# ---------------------------------------------------------
# LOAD FILES
# ---------------------------------------------------------

VOCAB_FILE = "../data/vocabulary/ministry_tfidf_vocab.json"
EMBED_FILE = "../data/embeddings/ministry_embeddings2.json"


def load_vocab():
    with open(VOCAB_FILE, "r") as f:
        return json.load(f)


def load_embeddings():
    with open(EMBED_FILE, "r") as f:
        data = json.load(f)

    # convert to numpy
    for k in data:
        data[k] = np.array(data[k])

    return data

# %%
STOPWORD_FILES = ["../data/stopwords/GBparl_stopwords-empirical.txt", "../data/stopwords/stopwords.txt"]

from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

def load_stopwords(custom_files):

    stopwords = set(ENGLISH_STOP_WORDS)

    # load domain stopwords
    for custom_file in custom_files:
        with open(custom_file, "r", encoding="utf-8") as f:
            for line in f:
                word = line.strip().lower()
                if word:
                    stopwords.add(word)

    return stopwords

stopwords = load_stopwords(STOPWORD_FILES)

# %%
import re

def clean_text(text, stopwords=None):

    # remove bullet characters
    text = text.replace("\uf0b7", " ")

    # remove numbering like "1." "2."
    text = re.sub(r"\n?\d+\.\s*", " ", text)

    # replace newlines with space
    text = text.replace("\n", " ")

    # remove multiple spaces
    text = re.sub(r"\s+", " ", text)
    
    # remove all punctuation
    text = re.sub(r'[^\w\s]', '', text)
    
    # keep only alphabets, remove numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    # remove numbers
    text = re.sub(r"\d+", " ", text)
    
    # make everything lowercase
    text = text.lower()

    # tokenize
    words = text.split()

    if stopwords:
        words = [w for w in words if w not in stopwords and len(w) > 2]

    # remove duplicates while preserving order
    seen = set()
    unique_words = []
    for w in words:
        if w not in seen:
            seen.add(w)
            unique_words.append(w)

    return " ".join(unique_words)

# %%
# ---------------------------------------------------------
# EXTRACT PARAGRAPHS FROM PDF
# ---------------------------------------------------------

def extract_paragraphs(pdf_path, skip_length=10):

    extractor = PDFExtractor()
    result = extractor.extract(pdf_path)

    paragraphs = [clean_text(seg["paragraph"], stopwords) for seg in result["segments"] if len(seg["paragraph"].split()) > skip_length]
    speakers = [seg["speaker"] for seg in result["segments"]]

    return paragraphs, speakers

# %%
# ---------------------------------------------------------
# VALIDATE DOCUMENT
# ---------------------------------------------------------

def validate(text):

    validator = DocumentValidator(vocab_path="../data/vocabulary/parliament_vocab.txt")
    results = validator.validate_document(text)

    return results

# %%
# ---------------------------------------------------------
# VOCAB BASED CLASSIFICATION
# ---------------------------------------------------------

def classify_vocab(paragraph, ministry_vocab):

    words = paragraph.lower().split()

    scores = {}

    for ministry, vocab in ministry_vocab.items():

        count = 0

        for term in vocab:
            if term.lower() in paragraph.lower():
                count += 1

        scores[ministry] = count

    total = sum(scores.values()) + 1e-9

    probs = {k: v / total for k, v in scores.items()}

    return probs


# ---------------------------------------------------------
# EMBEDDING BASED CLASSIFICATION
# ---------------------------------------------------------

def classify_embedding(paragraph, model, ministry_embeddings):

    p_emb = model.encode(paragraph)

    scores = {}

    for ministry, m_emb in ministry_embeddings.items():

        sim = cosine_similarity(
            p_emb.reshape(1, -1),
            m_emb.reshape(1, -1)
        )[0][0]

        scores[ministry] = float(sim)

    # softmax normalization
    exp_scores = np.exp(list(scores.values()))
    probs = exp_scores / np.sum(exp_scores)

    return dict(zip(scores.keys(), probs))

# %%
# ---------------------------------------------------------
# MAIN PIPELINE
# ---------------------------------------------------------

def run_pipeline(pdf_path):

    print(f"Processing: {pdf_path}")
    print("-" * 50)

    paragraphs, speaker = extract_paragraphs(pdf_path, skip_length=10)

    full_text = "\n\n".join(paragraphs)

    validation = validate(full_text)

    print("VALIDATION RESULTS:")
    print(json.dumps(validation, indent=4))

    if not validation["is_valid"]:
        print("Document failed validation")
        return

    print("\nLoading ministry vocab...")
    ministry_vocab = load_vocab()

    print("Loading ministry embeddings...")
    ministry_embeddings = load_embeddings()

    model = SentenceTransformer("all-MiniLM-L6-v2", cache_folder="../models")

    print("\nClassifying paragraphs...\n")

    results = []

    for i, para in enumerate(paragraphs):

        vocab_probs = classify_vocab(para, ministry_vocab)

        embed_probs = classify_embedding(
            para,
            model,
            ministry_embeddings
        )

        results.append({
            "paragraph_id": i,
            "paragraph": para,
            "speaker": speaker[i],
            "vocab_distribution": vocab_probs,
            "embedding_distribution": embed_probs
        })

        print("=" * 80)
        print(f"Paragraph {i}")
        # print(para[:200])

        print("\nTop vocab ministry:")
        print(sorted(vocab_probs.items(), key=lambda x: x[1], reverse=True)[:3])

        print("\nTop embedding ministry:")
        print(sorted(embed_probs.items(), key=lambda x: x[1], reverse=True)[:3])

    return results

# %%
# ---------------------------------------------------------
# RUN
# ---------------------------------------------------------

# if __name__ == "__main__":

file_name = "test.pdf"
file_path = f"../data/uploads/{file_name}"

results = run_pipeline(file_path)
# Out:
# Processing: ../data/uploads/test.pdf
# --------------------------------------------------
# VALIDATION RESULTS:905
# {
#     "is_valid": true,
#     "is_english": true,
#     "validation_errors": [],
#     "vocab_size": 116,
#     "required_vocab_matches": 5,
#     "parliament_confidence": 0.06896551724137931,
#     "matched_vocab_terms": [
#         "act",
#         "budget",
#         "gazette",
#         "government",
#         "half",
#         "motion",
#         "schedule",
#         "speaker"
#     ]
# }
#
# Loading ministry vocab...
# Loading ministry embeddings...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Classifying paragraphs...
#
# ================================================================================
# Paragraph 0
#
# Top vocab ministry:
# [('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.14285714285034012), ('Ministry_of_Parliamentary_Affairs_MPA_', 0.0952380952335601), ('Ministry_of_Law_and_Justice_MoLJ_', 0.04761904761678005)]
#
# Top embedding ministry:
# [('Ministry_of_Parliamentary_Affairs_MPA_', np.float64(0.023907633264838038)), ('Ministry_of_Cooperation_MoC_', np.float64(0.02140455957184313)), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.021267114843822828))]
# ================================================================================
# Paragraph 1
#
# Top vocab ministry:
# [('Ministry_of_Coal_MoC_', 0.22222222219753085), ('Ministry_of_AYUSH_MoA_', 0.11111111109876542), ('Ministry_of_Textiles_MoT_', 0.11111111109876542)]
#
# Top embedding ministry:
# [('Ministry_of_Parliamentary_Affairs_MPA_', np.float64(0.022278515962998364)), ('Ministry_of_Information_and_Broadcasting_MIB_', np.float64(0.02092681476661069)), ('Ministry_of_Finance_MoF_', np.float64(0.020873650398589173))]
# ================================================================================
# Paragraph 2
#
# Top vocab ministry:
# [('Ministry_of_Law_and_Justice_MoLJ_', 0.1428571428367347), ('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.1428571428367347), ('Ministry_of_Women_and_Child_Development_MoWCD_', 0.1428571428367347)]
#
# Top embedding ministry:
# [('Ministry_of_External_Affairs_MEA_', np.float64(0.022079327337545696)), ('Ministry_of_Culture', np.float64(0.02087575313692586)), ('Ministry_of_Home_Affairs_MHA_', np.float64(0.020682827210448982))]
# ================================================================================
# Paragraph 3
#
# Top vocab ministry:
# [('Ministry_of_Planning_MoP_', 0.0909090909063361), ('Ministry_of_Textiles_MoT_', 0.06060606060422406), ('Ministry_of_Culture', 0.06060606060422406)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.022272716387667677)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.02199817242191828)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.02157233568581403))]
# ================================================================================
# Paragraph 4
#
# Top vocab ministry:
# [('Ministry_of_External_Affairs_MEA_', 0.22222222220987653), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', 0.11111111110493826), ('Ministry_of_Parliamentary_Affairs_MPA_', 0.11111111110493826)]
#
# Top embedding ministry:
# [('Ministry_of_Tourism_MoT_', np.float64(0.024601094553763712)), ('Ministry_of_External_Affairs_MEA_', np.float64(0.021969269857881085)), ('Ministry_of_Youth_Affairs_and_Sports_MoYAS_', np.float64(0.02155914130521008))]
# ================================================================================
# Paragraph 5
#
# Top vocab ministry:
# [('Ministry_of_Women_and_Child_Development_MoWCD_', 0.060606060605448424), ('Ministry_of_Planning_MoP_', 0.060606060605448424), ('Ministry_of_Textiles_MoT_', 0.04040404040363228)]
#
# Top embedding ministry:
# [('Ministry_of_External_Affairs_MEA_', np.float64(0.021887104319123152)), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', np.float64(0.02167084355510504)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.02158552639412995))]
# ================================================================================
# Paragraph 6
#
# Top vocab ministry:
# [('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.046391752577080454), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', 0.041237113401849296), ('Ministry_of_Textiles_MoT_', 0.03608247422661813)]
#
# Top embedding ministry:
# [('Ministry_of_Rural_Development_MoRD_', np.float64(0.023844306513107233)), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.022110148716949617)), ('Ministry_of_Minority_Affairs_MoMA_', np.float64(0.021864238194926985))]
# ================================================================================
# Paragraph 7
#
# Top vocab ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.08108108107888971), ('Ministry_of_Heavy_Industries_MoHI_', 0.054054054052593135), ('Ministry_of_Petroleum_and_Natural_Gas_MoPNG_', 0.054054054052593135)]
#
# Top embedding ministry:
# [('Ministry_of_Coal_MoC_', np.float64(0.024017412889842365)), ('Ministry_of_Finance_MoF_', np.float64(0.0228680195558973)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.021963474599072226))]
# ================================================================================
# Paragraph 8
#
# Top vocab ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.2499999999375), ('Ministry_of_Culture', 0.2499999999375), ('Ministry_of_Tourism_MoT_', 0.2499999999375)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.02661682540952556)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.023799841686461536)), ('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', np.float64(0.022865525868654073))]
# ================================================================================
# Paragraph 9
#
# Top vocab ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', 0.062068965516813325), ('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', 0.05517241379272295), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.04827586206863258)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.02493763856926484)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.023454797382663106)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.02224383165514569))]
# ================================================================================
# Paragraph 10
#
# Top vocab ministry:
# [('Ministry_of_Rural_Development_MoRD_', 0.0793650793638196), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.04761904761829176), ('Ministry_of_Tourism_MoT_', 0.04761904761829176)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.023703621315018474)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.02366620467643632)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.02193277439021703))]
# ================================================================================
# Paragraph 11
#
# Top vocab ministry:
# [('Ministry_of_Food_Processing_Industries_MoFPI_', 0.09090909090495868), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', 0.09090909090495868), ('Ministry_of_Cooperation_MoC_', 0.09090909090495868)]
#
# Top embedding ministry:
# [('Ministry_of_Women_and_Child_Development_MoWCD_', np.float64(0.02405849717959084)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.02400018101701871)), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.023481022807711104))]
# ================================================================================
# Paragraph 12
#
# Top vocab ministry:
# [('Ministry_of_Commerce_and_Industry_MoCI_', 0.06122448979466889), ('Ministry_of_Finance_MoF_', 0.06122448979466889), ('Ministry_of_AYUSH_MoA_', 0.04081632652977926)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.022768127611676063)), ('Ministry_of_Cooperation_MoC_', np.float64(0.021738005930028212)), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', np.float64(0.021447219519025774))]
# ================================================================================
# Paragraph 13
#
# Top vocab ministry:
# [('Ministry_of_Food_Processing_Industries_MoFPI_', 0.1333333333288889), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', 0.1333333333288889), ('Ministry_of_Cooperation_MoC_', 0.09999999999666667)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.02373247942628624)), ('Ministry_of_AYUSH_MoA_', np.float64(0.023515008125638198)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.02336836976863435))]
# ================================================================================
# Paragraph 14
#
# Top vocab ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', 0.09803921568435219), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.07843137254748174), ('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.07843137254748174)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.025387403509569705)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.023788048095575262)), ('Ministry_of_Chemicals_and_Fertilizers_MoCF_', np.float64(0.02280016506229528))]
# ================================================================================
# Paragraph 15
#
# Top vocab ministry:
# [('Ministry_of_Textiles_MoT_', 0.08333333333101853), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.08333333333101853), ('Ministry_of_Home_Affairs_MHA_', 0.08333333333101853)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.023518009731069326)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.02189142181402612)), ('Ministry_of_Cooperation_MoC_', np.float64(0.021723102309953626))]
# ================================================================================
# Paragraph 16
#
# Top vocab ministry:
# [('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.07692307692110455), ('Ministry_of_Education_MoE_', 0.07692307692110455), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', 0.07692307692110455)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.024795351141818245)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.023772059992610953)), ('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', np.float64(0.021925100365657882))]
# ================================================================================
# Paragraph 17
#
# Top vocab ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', 0.09230769230627218), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.07692307692189349), ('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.07692307692189349)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.024644576377859998)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.02354739313421866)), ('Ministry_of_Cooperation_MoC_', np.float64(0.02336898865410727))]
# ================================================================================
# Paragraph 18
#
# Top vocab ministry:
# [('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.06451612903121749), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.06451612903121749), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', 0.06451612903121749)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.02288915457554907)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.022285402231081046)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.021809885287424984))]
# ================================================================================
# Paragraph 19
#
# Top vocab ministry:
# [('Ministry_of_Petroleum_and_Natural_Gas_MoPNG_', 0.08571428571183674), ('Ministry_of_Tourism_MoT_', 0.057142857141224496), ('Ministry_of_Rural_Development_MoRD_', 0.057142857141224496)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.02536660474657323)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.022520528454046777)), ('Ministry_of_Environment_Forest_and_Climate_Change_MoEFCC_', np.float64(0.021803862147202036))]
# ================================================================================
# Paragraph 20
#
# Top vocab ministry:
# [('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', 0.1323529411745242), ('Ministry_of_Coal_MoC_', 0.07352941176362457), ('Ministry_of_Mines_MoM_', 0.058823529410899654)]
#
# Top embedding ministry:
# [('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', np.float64(0.0246140109048636)), ('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', np.float64(0.023789725428391285)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.022116173312758638))]
# ================================================================================
# Paragraph 21
#
# Top vocab ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', 0.08695652173787019), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.043478260868935095), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.043478260868935095)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.024685424642541042)), ('Ministry_of_Textiles_MoT_', np.float64(0.023421981785547507)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.022583829902765744))]
# ================================================================================
# Paragraph 22
#
# Top vocab ministry:
# [('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', 0.13793103448038052), ('Ministry_of_Cooperation_MoC_', 0.12068965517033295), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', 0.08620689655023782)]
#
# Top embedding ministry:
# [('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', np.float64(0.021497372688291574)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.021462475474093107)), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.0213888541314041))]
# ================================================================================
# Paragraph 23
#
# Top vocab ministry:
# [('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', 0.15151515151056016), ('Ministry_of_Railways_MoR_', 0.0909090909063361), ('Ministry_of_Textiles_MoT_', 0.06060606060422406)]
#
# Top embedding ministry:
# [('Ministry_of_New_and_Renewable_Energy_MNRE_', np.float64(0.023012986761789374)), ('Ministry_of_Chemicals_and_Fertilizers_MoCF_', np.float64(0.02234420736463402)), ('Ministry_of_Tribal_Affairs_MoTA_', np.float64(0.02233750116788949))]
# ================================================================================
# Paragraph 24
#
# Top vocab ministry:
# [('Ministry_of_Communications_MoC_', 0.12499999999479167), ('Ministry_of_Culture', 0.0833333333298611), ('Ministry_of_Planning_MoP_', 0.0833333333298611)]
#
# Top embedding ministry:
# [('Ministry_of_Rural_Development_MoRD_', np.float64(0.022970855559232284)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.022285394876026408)), ('Ministry_of_Communications_MoC_', np.float64(0.021890287988471802))]
# ================================================================================
# Paragraph 25
#
# Top vocab ministry:
# [('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.09999999999), ('Ministry_of_Women_and_Child_Development_MoWCD_', 0.09999999999), ('Ministry_of_Railways_MoR_', 0.09999999999)]
#
# Top embedding ministry:
# [('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', np.float64(0.02128658273031916)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.021044461554666397)), ('Ministry_of_Civil_Aviation_MoCA_', np.float64(0.02083592574641335))]
# ================================================================================
# Paragraph 26
#
# Top vocab ministry:
# [('Ministry_of_Rural_Development_MoRD_', 0.11428571428244899), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.057142857141224496), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', 0.057142857141224496)]
#
# Top embedding ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.0233988172150329)), ('Ministry_of_Women_and_Child_Development_MoWCD_', np.float64(0.022020236115612456)), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', np.float64(0.02188744979388447))]
# ================================================================================
# Paragraph 27
#
# Top vocab ministry:
# [('Ministry_of_Food_Processing_Industries_MoFPI_', 0.16666666665277777), ('Ministry_of_Women_and_Child_Development_MoWCD_', 0.16666666665277777), ('Ministry_of_External_Affairs_MEA_', 0.08333333332638888)]
#
# Top embedding ministry:
# [('Ministry_of_Cooperation_MoC_', np.float64(0.02550275447325894)), ('Ministry_of_Corporate_Affairs_MCA_', np.float64(0.022482342838714954)), ('Ministry_of_Communications_MoC_', np.float64(0.021907571166508825))]
# ================================================================================
# Paragraph 28
#
# Top vocab ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.1764705882249135), ('Ministry_of_Textiles_MoT_', 0.117647058816609), ('Ministry_of_Home_Affairs_MHA_', 0.117647058816609)]
#
# Top embedding ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.02601250453555935)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.02234948521416091)), ('Ministry_of_Electronics_and_Information_Technology_MeitY_', np.float64(0.02150745829683535))]
# ================================================================================
# Paragraph 29
#
# Top vocab ministry:
# [('Ministry_of_Textiles_MoT_', 0.06976744185965386), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.04651162790643591), ('Ministry_of_Youth_Affairs_and_Sports_MoYAS_', 0.04651162790643591)]
#
# Top embedding ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.023795777131296752)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.022041538933355472)), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.02171440607835208))]
# ================================================================================
# Paragraph 30
#
# Top vocab ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.1034482758608799), ('Ministry_of_Textiles_MoT_', 0.0459770114937244), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.0459770114937244)]
#
# Top embedding ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.025667420330032713)), ('Ministry_of_Corporate_Affairs_MCA_', np.float64(0.021057414364084773)), ('Ministry_of_Finance_MoF_', np.float64(0.021018448039327276))]
# ================================================================================
# Paragraph 31
#
# Top vocab ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.12499999999687501), ('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', 0.07499999999812501), ('Ministry_of_Cooperation_MoC_', 0.07499999999812501)]
#
# Top embedding ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.024539293746012398)), ('Ministry_of_Electronics_and_Information_Technology_MeitY_', np.float64(0.0226256780973298)), ('Ministry_of_Corporate_Affairs_MCA_', np.float64(0.021477635807427488))]
# ================================================================================
# Paragraph 32
#
# Top vocab ministry:
# [('Ministry_of_Tourism_MoT_', 0.0645161290301769), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.0645161290301769), ('Ministry_of_Mines_MoM_', 0.0645161290301769)]
#
# Top embedding ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.02179489768729135)), ('Ministry_of_Finance_MoF_', np.float64(0.02171282075862489)), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', np.float64(0.02106429874711985))]
# ================================================================================
# Paragraph 33
#
# Top vocab ministry:
# [('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.057142857142040815), ('Ministry_of_Panchayati_Raj_MoPR_', 0.057142857142040815), ('Ministry_of_Cooperation_MoC_', 0.057142857142040815)]
#
# Top embedding ministry:
# [('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.022587345582338724)), ('Ministry_of_Tribal_Affairs_MoTA_', np.float64(0.022242305910797303)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.02210112602031846))]
# ================================================================================
# Paragraph 34
#
# Top vocab ministry:
# [('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.11764705882006922), ('Ministry_of_Planning_MoP_', 0.08823529411505192), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.05882352941003461)]
#
# Top embedding ministry:
# [('Ministry_of_Labour_and_Employment_MoLE_', np.float64(0.022466438945316736)), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.021832465317336514)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.021476214208144724))]
# ================================================================================
# Paragraph 35
#
# Top vocab ministry:
# [('Ministry_of_Textiles_MoT_', 0.062499999999023434), ('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', 0.062499999999023434), ('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', 0.062499999999023434)]
#
# Top embedding ministry:
# [('Ministry_of_Textiles_MoT_', np.float64(0.024957821690666564)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.022701921956555175)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.022499834120733635))]
# ================================================================================
# Paragraph 36
#
# Top vocab ministry:
# [('Ministry_of_Textiles_MoT_', 0.057142857141224496), ('Ministry_of_Tourism_MoT_', 0.057142857141224496), ('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.057142857141224496)]
#
# Top embedding ministry:
# [('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.022348955604971514)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.02220343218742284)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.022088952293100088))]
# ================================================================================
# Paragraph 37
#
# Top vocab ministry:
# [('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.0660377358484336), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', 0.0660377358484336), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.05660377358437166)]
#
# Top embedding ministry:
# [('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.023581835147775846)), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.023260107764486473)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.022657859591519027))]
# ================================================================================
# Paragraph 38
#
# Top vocab ministry:
# [('Ministry_of_Planning_MoP_', 0.09677419354526536), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.0645161290301769), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', 0.0645161290301769)]
#
# Top embedding ministry:
# [('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.022384828059553212)), ('Ministry_of_Planning_MoP_', np.float64(0.021703530379034264)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.021283909630322926))]
# ================================================================================
# Paragraph 39
#
# Top vocab ministry:
# [('Ministry_of_New_and_Renewable_Energy_MNRE_', 0.12499999999776787), ('Ministry_of_Heavy_Industries_MoHI_', 0.08928571428411991), ('Ministry_of_Power_MoP_', 0.07142857142729592)]
#
# Top embedding ministry:
# [('Ministry_of_New_and_Renewable_Energy_MNRE_', np.float64(0.026447743499595208)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.025263396546214435)), ('Ministry_of_Power_MoP_', np.float64(0.024671737616433403))]
# ================================================================================
# Paragraph 40
#
# Top vocab ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.3333333332222222), ('Ministry_of_Tourism_MoT_', 0.3333333332222222), ('Ministry_of_Coal_MoC_', 0.3333333332222222)]
#
# Top embedding ministry:
# [('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.022079992046399106)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.021908808673245204)), ('Ministry_of_Science_and_Technology_MST_', np.float64(0.021612410657523253))]
# ================================================================================
# Paragraph 41
#
# Top vocab ministry:
# [('Ministry_of_Education_MoE_', 0.10526315789289013), ('Ministry_of_Women_and_Child_Development_MoWCD_', 0.08771929824407511), ('Ministry_of_Law_and_Justice_MoLJ_', 0.052631578946445066)]
#
# Top embedding ministry:
# [('Ministry_of_Women_and_Child_Development_MoWCD_', np.float64(0.024763739563750147)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.0218325916579131)), ('Ministry_of_Health_and_Family_Welfare_MoHFW_', np.float64(0.021528218063929124))]
# ================================================================================
# Paragraph 42
#
# Top vocab ministry:
# [('Ministry_of_Youth_Affairs_and_Sports_MoYAS_', 0.14285714284693876), ('Ministry_of_Minority_Affairs_MoMA_', 0.14285714284693876), ('Ministry_of_Education_MoE_', 0.14285714284693876)]
#
# Top embedding ministry:
# [('Ministry_of_Science_and_Technology_MST_', np.float64(0.02488012251912263)), ('Ministry_of_Education_MoE_', np.float64(0.023317728090258165)), ('Ministry_of_Youth_Affairs_and_Sports_MoYAS_', np.float64(0.02203159666303895))]
# ================================================================================
# Paragraph 43
#
# Top vocab ministry:
# [('Ministry_of_Minority_Affairs_MoMA_', 0.08823529411505192), ('Ministry_of_Education_MoE_', 0.08823529411505192), ('Ministry_of_Science_and_Technology_MST_', 0.08823529411505192)]
#
# Top embedding ministry:
# [('Ministry_of_Education_MoE_', np.float64(0.022517797990025932)), ('Ministry_of_Communications_MoC_', np.float64(0.0225139944899692)), ('Ministry_of_Health_and_Family_Welfare_MoHFW_', np.float64(0.02220144543495004))]
# ================================================================================
# Paragraph 44
#
# Top vocab ministry:
# [('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', 0.07407407407133058), ('Ministry_of_Women_and_Child_Development_MoWCD_', 0.07407407407133058), ('Ministry_of_Steel_MoS_', 0.07407407407133058)]
#
# Top embedding ministry:
# [('Ministry_of_Education_MoE_', np.float64(0.023956018470102706)), ('Ministry_of_Minority_Affairs_MoMA_', np.float64(0.022257228214634606)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.021744754387152218))]
# ================================================================================
# Paragraph 45
#
# Top vocab ministry:
# [('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.06779661016834243), ('Ministry_of_Home_Affairs_MHA_', 0.06779661016834243), ('Ministry_of_Youth_Affairs_and_Sports_MoYAS_', 0.06779661016834243)]
#
# Top embedding ministry:
# [('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.02605425580788868)), ('Ministry_of_Youth_Affairs_and_Sports_MoYAS_', np.float64(0.02370689444801728)), ('Ministry_of_Education_MoE_', np.float64(0.022815136158417935))]
# ================================================================================
# Paragraph 46
#
# Top vocab ministry:
# [('Ministry_of_Food_Processing_Industries_MoFPI_', 0.07547169811178356), ('Ministry_of_Petroleum_and_Natural_Gas_MoPNG_', 0.07547169811178356), ('Ministry_of_Steel_MoS_', 0.07547169811178356)]
#
# Top embedding ministry:
# [('Ministry_of_Education_MoE_', np.float64(0.024233350546698017)), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.0222855431446806)), ('Ministry_of_Women_and_Child_Development_MoWCD_', np.float64(0.020977753042430335))]
# ================================================================================
# Paragraph 47
#
# Top vocab ministry:
# [('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', 0.07692307692110455), ('Ministry_of_Heavy_Industries_MoHI_', 0.07692307692110455), ('Ministry_of_Electronics_and_Information_Technology_MeitY_', 0.07692307692110455)]
#
# Top embedding ministry:
# [('Ministry_of_Health_and_Family_Welfare_MoHFW_', np.float64(0.022348438262577548)), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.022147079523821996)), ('Ministry_of_Education_MoE_', np.float64(0.021791950132627552))]
# ================================================================================
# Paragraph 48
#
# Top vocab ministry:
# [('Ministry_of_Health_and_Family_Welfare_MoHFW_', 0.07499999999812501), ('Ministry_of_Power_MoP_', 0.04999999999875), ('Ministry_of_AYUSH_MoA_', 0.04999999999875)]
#
# Top embedding ministry:
# [('Ministry_of_Education_MoE_', np.float64(0.02340473809351774)), ('Ministry_of_Health_and_Family_Welfare_MoHFW_', np.float64(0.02319852198848768)), ('Ministry_of_AYUSH_MoA_', np.float64(0.021708664835791064))]
# ================================================================================
# Paragraph 49
#
# Top vocab ministry:
# [('Ministry_of_AYUSH_MoA_', 0.157894736833795), ('Ministry_of_Health_and_Family_Welfare_MoHFW_', 0.10526315788919667), ('Ministry_of_Education_MoE_', 0.10526315788919667)]
#
# Top embedding ministry:
# [('Ministry_of_Health_and_Family_Welfare_MoHFW_', np.float64(0.023679112562560244)), ('Ministry_of_Women_and_Child_Development_MoWCD_', np.float64(0.021703180450611658)), ('Ministry_of_AYUSH_MoA_', np.float64(0.021643321947549393))]
# ================================================================================
# Paragraph 50
#
# Top vocab ministry:
# [('Ministry_of_Rural_Development_MoRD_', 0.07594936708764621), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', 0.06329113923970517), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', 0.05063291139176414)]
#
# Top embedding ministry:
# [('Ministry_of_Rural_Development_MoRD_', np.float64(0.02389463072810348)), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', np.float64(0.023192192802701135)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.023025846721477474))]
# ================================================================================
# Paragraph 51
#
# Top vocab ministry:
# [('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', 0.07272727272595042), ('Ministry_of_Panchayati_Raj_MoPR_', 0.07272727272595042), ('Ministry_of_Health_and_Family_Welfare_MoHFW_', 0.054545454544462815)]
#
# Top embedding ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.022418457750654007)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.02204513044557798)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.0220241987934087))]
# ================================================================================
# Paragraph 52
#
# Top vocab ministry:
# [('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.0689655172405866), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', 0.0574712643671555), ('Ministry_of_Women_and_Child_Development_MoWCD_', 0.0574712643671555)]
#
# Top embedding ministry:
# [('Ministry_of_Labour_and_Employment_MoLE_', np.float64(0.023949434179354998)), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.022490474989452138)), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', np.float64(0.02247966913186974))]
# ================================================================================
# Paragraph 53
#
# Top vocab ministry:
# [('Ministry_of_External_Affairs_MEA_', 0.06666666666518518), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', 0.06666666666518518), ('Ministry_of_Tourism_MoT_', 0.04444444444345679)]
#
# Top embedding ministry:
# [('Ministry_of_Planning_MoP_', np.float64(0.02214774740386791)), ('Ministry_of_Power_MoP_', np.float64(0.02137615120679198)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.02124699523829596))]
# ================================================================================
# Paragraph 54
#
# Top vocab ministry:
# [('Ministry_of_Railways_MoR_', 0.10344827585850179), ('Ministry_of_Finance_MoF_', 0.10344827585850179), ('Ministry_of_Heavy_Industries_MoHI_', 0.06896551723900118)]
#
# Top embedding ministry:
# [('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.0228828642652611)), ('Ministry_of_Finance_MoF_', np.float64(0.022205441512252122)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.021949756090209775))]
# ================================================================================
# Paragraph 55
#
# Top vocab ministry:
# [('Ministry_of_Road_Transport_and_Highways_MoRTH_', 0.1111111111080247), ('Ministry_of_Tourism_MoT_', 0.08333333333101853), ('Ministry_of_Steel_MoS_', 0.08333333333101853)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.022390445672075026)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.02216367344377793)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.0221329081058611))]
# ================================================================================
# Paragraph 56
#
# Top vocab ministry:
# [('Ministry_of_Petroleum_and_Natural_Gas_MoPNG_', 0.1086956521715501), ('Ministry_of_Jal_Shakti_MoJS_', 0.08695652173724008), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.06521739130293006)]
#
# Top embedding ministry:
# [('Ministry_of_Jal_Shakti_MoJS_', np.float64(0.025000264002306434)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.023244437373749923)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.02117573933533295))]
# ================================================================================
# Paragraph 57
#
# Top vocab ministry:
# [('Ministry_of_Culture', 0.07692307692110455), ('Ministry_of_Health_and_Family_Welfare_MoHFW_', 0.07692307692110455), ('Ministry_of_Finance_MoF_', 0.07692307692110455)]
#
# Top embedding ministry:
# [('Ministry_of_Jal_Shakti_MoJS_', np.float64(0.024082574578847004)), ('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', np.float64(0.021134905298155374)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.021101974236899978))]
# ================================================================================
# Paragraph 58
#
# Top vocab ministry:
# [('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', 0.0799999999968), ('Ministry_of_Petroleum_and_Natural_Gas_MoPNG_', 0.0799999999968), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', 0.0799999999968)]
#
# Top embedding ministry:
# [('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.02551258803741713)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.023771109534373176)), ('Ministry_of_Planning_MoP_', np.float64(0.02241590121388085))]
# ================================================================================
# Paragraph 59
#
# Top vocab ministry:
# [('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', 0.10344827585850179), ('Ministry_of_Science_and_Technology_MST_', 0.10344827585850179), ('Ministry_of_Tourism_MoT_', 0.06896551723900118)]
#
# Top embedding ministry:
# [('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.024253440488659517)), ('Ministry_of_Jal_Shakti_MoJS_', np.float64(0.02363309939381123)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.021636840662186546))]
# ================================================================================
# Paragraph 60
#
# Top vocab ministry:
# [('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.14285714285034012), ('Ministry_of_Coal_MoC_', 0.0952380952335601), ('Ministry_of_AYUSH_MoA_', 0.04761904761678005)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.0225664737127192)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.02167393987147602)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.021473940528382453))]
# ================================================================================
# Paragraph 61
#
# Top vocab ministry:
# [('Ministry_of_Power_MoP_', 0.08695652173724008), ('Ministry_of_Petroleum_and_Natural_Gas_MoPNG_', 0.08695652173724008), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.06521739130293006)]
#
# Top embedding ministry:
# [('Ministry_of_Power_MoP_', np.float64(0.025651995018204702)), ('Ministry_of_New_and_Renewable_Energy_MNRE_', np.float64(0.021954306422533494)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.02194677693702831))]
# ================================================================================
# Paragraph 62
#
# Top vocab ministry:
# [('Ministry_of_Power_MoP_', 0.07843137254748174), ('Ministry_of_Petroleum_and_Natural_Gas_MoPNG_', 0.05882352941061131), ('Ministry_of_Chemicals_and_Fertilizers_MoCF_', 0.05882352941061131)]
#
# Top embedding ministry:
# [('Ministry_of_Power_MoP_', np.float64(0.022651329460063752)), ('Ministry_of_New_and_Renewable_Energy_MNRE_', np.float64(0.02092344297811005)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.020646697379189765))]
# ================================================================================
# Paragraph 63
#
# Top vocab ministry:
# [('Ministry_of_Power_MoP_', 0.08108108107888971), ('Ministry_of_Heavy_Industries_MoHI_', 0.054054054052593135), ('Ministry_of_External_Affairs_MEA_', 0.054054054052593135)]
#
# Top embedding ministry:
# [('Ministry_of_Power_MoP_', np.float64(0.02298669853765444)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.021816653003248473)), ('Ministry_of_New_and_Renewable_Energy_MNRE_', np.float64(0.02167041480545614))]
# ================================================================================
# Paragraph 64
#
# Top vocab ministry:
# [('Ministry_of_Tourism_MoT_', 0.05555555555401235), ('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', 0.05555555555401235), ('Ministry_of_Science_and_Technology_MST_', 0.05555555555401235)]
#
# Top embedding ministry:
# [('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', np.float64(0.024722712653872828)), ('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', np.float64(0.021476158217749026)), ('Ministry_of_Finance_MoF_', np.float64(0.021293702669741472))]
# ================================================================================
# Paragraph 65
#
# Top vocab ministry:
# [('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', 0.11111111110493826), ('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', 0.11111111110493826), ('Ministry_of_Culture', 0.05555555555246913)]
#
# Top embedding ministry:
# [('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', np.float64(0.025483778406520944)), ('Ministry_of_Defence_MoD_', np.float64(0.022058184406258625)), ('Ministry_of_Railways_MoR_', np.float64(0.021696766125131616))]
# ================================================================================
# Paragraph 66
#
# Top vocab ministry:
# [('Ministry_of_Textiles_MoT_', 0.06521739130293006), ('Ministry_of_Petroleum_and_Natural_Gas_MoPNG_', 0.06521739130293006), ('Ministry_of_Steel_MoS_', 0.06521739130293006)]
#
# Top embedding ministry:
# [('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', np.float64(0.024707437766339897)), ('Ministry_of_Science_and_Technology_MST_', np.float64(0.02103621242121229)), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.021013902292681935))]
# ================================================================================
# Paragraph 67
#
# Top vocab ministry:
# [('Ministry_of_Power_MoP_', 0.0799999999968), ('Ministry_of_Petroleum_and_Natural_Gas_MoPNG_', 0.0799999999968), ('Ministry_of_Youth_Affairs_and_Sports_MoYAS_', 0.0799999999968)]
#
# Top embedding ministry:
# [('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', np.float64(0.026708912426285848)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.02158317856534039)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.021487471295317313))]
# ================================================================================
# Paragraph 68
#
# Top vocab ministry:
# [('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', 0.08219178082079188), ('Ministry_of_Civil_Aviation_MoCA_', 0.06849315068399324), ('Ministry_of_External_Affairs_MEA_', 0.054794520547194595)]
#
# Top embedding ministry:
# [('Ministry_of_Road_Transport_and_Highways_MoRTH_', np.float64(0.023403687388259754)), ('Ministry_of_Railways_MoR_', np.float64(0.022611653080610996)), ('Ministry_of_Civil_Aviation_MoCA_', np.float64(0.0224990898073278))]
# ================================================================================
# Paragraph 69
#
# Top vocab ministry:
# [('Ministry_of_Food_Processing_Industries_MoFPI_', 0.053571428570471945), ('Ministry_of_Railways_MoR_', 0.053571428570471945), ('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', 0.053571428570471945)]
#
# Top embedding ministry:
# [('Ministry_of_Civil_Aviation_MoCA_', np.float64(0.022176903933430324)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.021414719102835815)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.021285821995309515))]
# ================================================================================
# Paragraph 70
#
# Top vocab ministry:
# [('Ministry_of_Coal_MoC_', 0.10526315789196677), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', 0.05263157894598339), ('Ministry_of_Mines_MoM_', 0.05263157894598339)]
#
# Top embedding ministry:
# [('Ministry_of_Mines_MoM_', np.float64(0.025379515565106668)), ('Ministry_of_Coal_MoC_', np.float64(0.024792473051987226)), ('Ministry_of_Steel_MoS_', np.float64(0.021382037868807772))]
# ================================================================================
# Paragraph 71
#
# Top vocab ministry:
# [('Ministry_of_Coal_MoC_', 0.22222222219753085), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', 0.11111111109876542), ('Ministry_of_Tourism_MoT_', 0.11111111109876542)]
#
# Top embedding ministry:
# [('Ministry_of_Mines_MoM_', np.float64(0.026432112366084465)), ('Ministry_of_Coal_MoC_', np.float64(0.023992979175678192)), ('Ministry_of_Steel_MoS_', np.float64(0.023443914932569695))]
# ================================================================================
# Paragraph 72
#
# Top vocab ministry:
# [('Ministry_of_Women_and_Child_Development_MoWCD_', 0.07894736841897508), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.05263157894598339), ('Ministry_of_Home_Affairs_MHA_', 0.05263157894598339)]
#
# Top embedding ministry:
# [('Ministry_of_Rural_Development_MoRD_', np.float64(0.022989602320365204)), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', np.float64(0.02242544535611265)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.022213722204789878))]
# ================================================================================
# Paragraph 73
#
# Top vocab ministry:
# [('Ministry_of_Finance_MoF_', 0.18181818180165288), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.09090909090082644), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', 0.09090909090082644)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.021905855294240804)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.021684804748361722)), ('Ministry_of_Cooperation_MoC_', np.float64(0.02148639497829853))]
# ================================================================================
# Paragraph 74
#
# Top vocab ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.11111111109876542), ('Ministry_of_Heavy_Industries_MoHI_', 0.11111111109876542), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.11111111109876542)]
#
# Top embedding ministry:
# [('Ministry_of_Rural_Development_MoRD_', np.float64(0.021994789863668374)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.02177866923313687)), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', np.float64(0.021036528390628948))]
# ================================================================================
# Paragraph 75
#
# Top vocab ministry:
# [('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', 0.099999999995), ('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', 0.099999999995), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', 0.099999999995)]
#
# Top embedding ministry:
# [('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', np.float64(0.022444729075886412)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.021606810919249916)), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', np.float64(0.021467335591621416))]
# ================================================================================
# Paragraph 76
#
# Top vocab ministry:
# [('Ministry_of_Culture', 0.08333333333159723), ('Ministry_of_Tourism_MoT_', 0.062499999998697923), ('Ministry_of_Chemicals_and_Fertilizers_MoCF_', 0.062499999998697923)]
#
# Top embedding ministry:
# [('Ministry_of_Tourism_MoT_', np.float64(0.0259789820464099)), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', np.float64(0.021613371403550106)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.021360178025500918))]
# ================================================================================
# Paragraph 77
#
# Top vocab ministry:
# [('Ministry_of_Rural_Development_MoRD_', 0.04918032786844934), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', 0.04918032786844934), ('Ministry_of_Science_and_Technology_MST_', 0.04918032786844934)]
#
# Top embedding ministry:
# [('Ministry_of_Tourism_MoT_', np.float64(0.02315702329606625)), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.022588250715259026)), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', np.float64(0.021187408203360188))]
# ================================================================================
# Paragraph 78
#
# Top vocab ministry:
# [('Ministry_of_Tourism_MoT_', 0.08695652173534972), ('Ministry_of_Home_Affairs_MHA_', 0.08695652173534972), ('Ministry_of_Youth_Affairs_and_Sports_MoYAS_', 0.08695652173534972)]
#
# Top embedding ministry:
# [('Ministry_of_Tourism_MoT_', np.float64(0.025093603150785487)), ('Ministry_of_Culture', np.float64(0.022830375684643654)), ('Ministry_of_Tribal_Affairs_MoTA_', np.float64(0.021215446237715076))]
# ================================================================================
# Paragraph 79
#
# Top vocab ministry:
# [('Ministry_of_Culture', 0.09999999999666667), ('Ministry_of_AYUSH_MoA_', 0.06666666666444444), ('Ministry_of_Tourism_MoT_', 0.06666666666444444)]
#
# Top embedding ministry:
# [('Ministry_of_Tourism_MoT_', np.float64(0.024733663980374545)), ('Ministry_of_AYUSH_MoA_', np.float64(0.022109481732302982)), ('Ministry_of_Health_and_Family_Welfare_MoHFW_', np.float64(0.02174495301024672))]
# ================================================================================
# Paragraph 80
#
# Top vocab ministry:
# [('Ministry_of_Tourism_MoT_', 0.1199999999952), ('Ministry_of_Steel_MoS_', 0.0799999999968), ('Ministry_of_Planning_MoP_', 0.0799999999968)]
#
# Top embedding ministry:
# [('Ministry_of_Planning_MoP_', np.float64(0.02124273020097761)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.021163595190274543)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.020617047166121047))]
# ================================================================================
# Paragraph 81
#
# Top vocab ministry:
# [('Ministry_of_Mines_MoM_', 0.09756097560737657), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.04878048780368829), ('Ministry_of_Culture', 0.04878048780368829)]
#
# Top embedding ministry:
# ...
# ================================================================================
# Paragraph 153
#
# Top vocab ministry:
# [('Ministry_of_Commerce_and_Industry_MoCI_', 0.06779661016834243), ('Ministry_of_Corporate_Affairs_MCA_', 0.06779661016834243), ('Ministry_of_Law_and_Justice_MoLJ_', 0.05084745762625682)]
#
# Top embedding ministry:
# [('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.02238465680914997)), ('Ministry_of_Finance_MoF_', np.float64(0.022320447191104875)), ('Ministry_of_Railways_MoR_', np.float64(0.021662645509464666))]
# ================================================================================
# Paragraph 154
#
# Top vocab ministry:
# [('Ministry_of_Civil_Aviation_MoCA_', 0.08333333333101853), ('Ministry_of_Home_Affairs_MHA_', 0.05555555555401235), ('Ministry_of_Electronics_and_Information_Technology_MeitY_', 0.05555555555401235)]
#
# Top embedding ministry:
# [('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', np.float64(0.02342321864217647)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.023360493587673715)), ('Ministry_of_Finance_MoF_', np.float64(0.023044345485351263))]
# ================================================================================
# Paragraph 155
#
# Top vocab ministry:
# [('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.117647058816609), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.0588235294083045), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', 0.0588235294083045)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.021908862094335957)), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', np.float64(0.02172443062347581)), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.02128373019270074))]
# ================================================================================
# Paragraph 156
#
# Top vocab ministry:
# [('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.099999999995), ('Ministry_of_Commerce_and_Industry_MoCI_', 0.099999999995), ('Ministry_of_Communications_MoC_', 0.099999999995)]
#
# Top embedding ministry:
# [('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', np.float64(0.022255164615441966)), ('Ministry_of_Health_and_Family_Welfare_MoHFW_', np.float64(0.022187869481590714)), ('Ministry_of_Women_and_Child_Development_MoWCD_', np.float64(0.021090091396599238))]
# ================================================================================
# Paragraph 157
#
# Top vocab ministry:
# [('Ministry_of_Food_Processing_Industries_MoFPI_', 0.09374999999707033), ('Ministry_of_Women_and_Child_Development_MoWCD_', 0.09374999999707033), ('Ministry_of_Law_and_Justice_MoLJ_', 0.06249999999804688)]
#
# Top embedding ministry:
# [('Ministry_of_Information_and_Broadcasting_MIB_', np.float64(0.023745525356978013)), ('Ministry_of_Electronics_and_Information_Technology_MeitY_', np.float64(0.02326232051513613)), ('Ministry_of_Law_and_Justice_MoLJ_', np.float64(0.022956069844557583))]
# ================================================================================
# Paragraph 158
#
# Top vocab ministry:
# [('Ministry_of_Women_and_Child_Development_MoWCD_', 0.1599999999936), ('Ministry_of_Electronics_and_Information_Technology_MeitY_', 0.0799999999968), ('Ministry_of_Finance_MoF_', 0.0799999999968)]
#
# Top embedding ministry:
# [('Ministry_of_Law_and_Justice_MoLJ_', np.float64(0.023239139714262603)), ('Ministry_of_Finance_MoF_', np.float64(0.021837769003192026)), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.021669979295692934))]
# ================================================================================
# Paragraph 159
#
# Top vocab ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.19999999996), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.19999999996), ('Ministry_of_Rural_Development_MoRD_', 0.19999999996)]
#
# Top embedding ministry:
# [('Ministry_of_Labour_and_Employment_MoLE_', np.float64(0.02266452224996404)), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.021663865851587)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.02121831367717553))]
# ================================================================================
# Paragraph 160
#
# Top vocab ministry:
# [('Ministry_of_Heavy_Industries_MoHI_', 0.0781249999987793), ('Ministry_of_Electronics_and_Information_Technology_MeitY_', 0.0781249999987793), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.04687499999926758)]
#
# Top embedding ministry:
# [('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.02343806878073534)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.022685236894844762)), ('Ministry_of_Electronics_and_Information_Technology_MeitY_', np.float64(0.021882448043542033))]
# ================================================================================
# Paragraph 161
#
# Top vocab ministry:
# [('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', 0.07692307692110455), ('Ministry_of_Women_and_Child_Development_MoWCD_', 0.05128205128073636), ('Ministry_of_Home_Affairs_MHA_', 0.05128205128073636)]
#
# Top embedding ministry:
# [('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', np.float64(0.029038687114822017)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.02260710954202018)), ('Ministry_of_Railways_MoR_', np.float64(0.02133531989285104))]
# ================================================================================
# Paragraph 162
#
# Top vocab ministry:
# [('Ministry_of_Health_and_Family_Welfare_MoHFW_', 0.07692307692110455), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.05128205128073636), ('Ministry_of_Tourism_MoT_', 0.05128205128073636)]
#
# Top embedding ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.02173949779353702)), ('Ministry_of_Corporate_Affairs_MCA_', np.float64(0.021537093764408835)), ('Ministry_of_Cooperation_MoC_', np.float64(0.021206779000599953))]
# ================================================================================
# Paragraph 163
#
# Top vocab ministry:
# [('Ministry_of_Power_MoP_', 0.04878048780368829), ('Ministry_of_Textiles_MoT_', 0.04878048780368829), ('Ministry_of_Heavy_Industries_MoHI_', 0.04878048780368829)]
#
# Top embedding ministry:
# [('Ministry_of_Corporate_Affairs_MCA_', np.float64(0.02131289125687968)), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.021302883109910735)), ('Ministry_of_Communications_MoC_', np.float64(0.02127819278714824))]
# ================================================================================
# Paragraph 164
#
# Top vocab ministry:
# [('Ministry_of_Finance_MoF_', 0.13333333332444444), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.06666666666222222), ('Ministry_of_Heavy_Industries_MoHI_', 0.06666666666222222)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.02339667542431272)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.021198329842954045)), ('Ministry_of_Corporate_Affairs_MCA_', np.float64(0.020826807410550215))]
# ================================================================================
# Paragraph 165
#
# Top vocab ministry:
# [('Ministry_of_Finance_MoF_', 0.15384615383431952), ('Ministry_of_Power_MoP_', 0.07692307691715976), ('Ministry_of_Textiles_MoT_', 0.07692307691715976)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.02136506388223246)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.021078783598226354)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.021006172688860833))]
# ================================================================================
# Paragraph 166
#
# Top vocab ministry:
# [('Ministry_of_Parliamentary_Affairs_MPA_', 0.06896551724019026), ('Ministry_of_Home_Affairs_MHA_', 0.05172413793014269), ('Ministry_of_Coal_MoC_', 0.05172413793014269)]
#
# Top embedding ministry:
# [('Ministry_of_Rural_Development_MoRD_', np.float64(0.02265360033891841)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.022178486366335907)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.02159497367474357))]
# ================================================================================
# Paragraph 167
#
# Top vocab ministry:
# [('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', 0.0952380952335601), ('Ministry_of_Civil_Aviation_MoCA_', 0.0952380952335601), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.04761904761678005)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.02224699241555688)), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', np.float64(0.021845615955318726)), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.021126928177298193))]
# ================================================================================
# Paragraph 168
#
# Top vocab ministry:
# [('Ministry_of_Road_Transport_and_Highways_MoRTH_', 0.0909090909070248), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.0681818181802686), ('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.0681818181802686)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.023011633874806568)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.021179594286135518)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.02117610921164376))]
# ================================================================================
# Paragraph 169
#
# Top vocab ministry:
# [('Ministry_of_Finance_MoF_', 0.1499999999925), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.099999999995), ('Ministry_of_Environment_Forest_and_Climate_Change_MoEFCC_', 0.099999999995)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.022345133169972126)), ('Ministry_of_Labour_and_Employment_MoLE_', np.float64(0.021225879572634027)), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.020611460932076688))]
# ================================================================================
# Paragraph 170
#
# Top vocab ministry:
# [('Ministry_of_Finance_MoF_', 0.14285714285034012), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.0952380952335601), ('Ministry_of_Home_Affairs_MHA_', 0.0952380952335601)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.022190726251566407)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.02192286294188195)), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', np.float64(0.02168867963157192))]
# ================================================================================
# Paragraph 171
#
# Top vocab ministry:
# [('Ministry_of_Finance_MoF_', 0.09090909090743803), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.054545454544462815), ('Ministry_of_Home_Affairs_MHA_', 0.054545454544462815)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.023345622051373312)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.020937923451755835)), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.020787333335155443))]
# ================================================================================
# Paragraph 172
#
# Top vocab ministry:
# [('Ministry_of_Finance_MoF_', 0.18181818180991735), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.09090909090495868), ('Ministry_of_Mines_MoM_', 0.09090909090495868)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.023477987780208133)), ('Ministry_of_Labour_and_Employment_MoLE_', np.float64(0.0221248880002973)), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.022063467030040508))]
# ================================================================================
# Paragraph 173
#
# Top vocab ministry:
# [('Ministry_of_Finance_MoF_', 0.157894736833795), ('Ministry_of_Steel_MoS_', 0.10526315788919667), ('Ministry_of_Coal_MoC_', 0.10526315788919667)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.022993281724824045)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.02167080327873752)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.021103418367565033))]
# ================================================================================
# Paragraph 174
#
# Top vocab ministry:
# [('Ministry_of_Power_MoP_', 0.0), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.0), ('Ministry_of_AYUSH_MoA_', 0.0)]
#
# Top embedding ministry:
# [('Ministry_of_Parliamentary_Affairs_MPA_', np.float64(0.021401288871718816)), ('Ministry_of_Communications_MoC_', np.float64(0.020948499397468068)), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.020258288492253817))]
# ================================================================================
# Paragraph 175
#
# Top vocab ministry:
# [('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.07142857142687076), ('Ministry_of_Home_Affairs_MHA_', 0.07142857142687076), ('Ministry_of_Planning_MoP_', 0.07142857142687076)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.023445943204875787)), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.021579964460123724)), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', np.float64(0.020900320022750583))]
# ================================================================================
# Paragraph 176
#
# Top vocab ministry:
# [('Ministry_of_Home_Affairs_MHA_', 0.3333333332222222), ('Ministry_of_Environment_Forest_and_Climate_Change_MoEFCC_', 0.3333333332222222), ('Ministry_of_Labour_and_Employment_MoLE_', 0.3333333332222222)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.0229555723562838)), ('Ministry_of_Cooperation_MoC_', np.float64(0.021479033047363028)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.0211335613910542))]
# ================================================================================
# Paragraph 177
#
# Top vocab ministry:
# [('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', 0.19999999996), ('Ministry_of_Law_and_Justice_MoLJ_', 0.19999999996), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', 0.19999999996)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.02336259448348015)), ('Ministry_of_Corporate_Affairs_MCA_', np.float64(0.021314775933826552)), ('Ministry_of_Cooperation_MoC_', np.float64(0.021145395611791958))]
# ================================================================================
# Paragraph 178
#
# Top vocab ministry:
# [('Ministry_of_Culture', 0.3333333332222222), ('Ministry_of_Health_and_Family_Welfare_MoHFW_', 0.3333333332222222), ('Ministry_of_Chemicals_and_Fertilizers_MoCF_', 0.3333333332222222)]
#
# Top embedding ministry:
# [('Ministry_of_Corporate_Affairs_MCA_', np.float64(0.02296632666084082)), ('Ministry_of_Finance_MoF_', np.float64(0.022788647801394623)), ('Ministry_of_Information_and_Broadcasting_MIB_', np.float64(0.021764156118248796))]
# ================================================================================
# Paragraph 179
#
# Top vocab ministry:
# [('Ministry_of_Textiles_MoT_', 0.124999999984375), ('Ministry_of_Tourism_MoT_', 0.124999999984375), ('Ministry_of_Youth_Affairs_and_Sports_MoYAS_', 0.124999999984375)]
#
# Top embedding ministry:
# [('Ministry_of_Parliamentary_Affairs_MPA_', np.float64(0.021011422904621692)), ('Ministry_of_Law_and_Justice_MoLJ_', np.float64(0.02087807750481551)), ('Ministry_of_Corporate_Affairs_MCA_', np.float64(0.02071088008552669))]
# ================================================================================
# Paragraph 180
#
# Top vocab ministry:
# [('Ministry_of_Law_and_Justice_MoLJ_', 0.136363636357438), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.136363636357438), ('Ministry_of_Parliamentary_Affairs_MPA_', 0.136363636357438)]
#
# Top embedding ministry:
# [('Ministry_of_Parliamentary_Affairs_MPA_', np.float64(0.022270578790899144)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.022138215674505187)), ('Ministry_of_Women_and_Child_Development_MoWCD_', np.float64(0.02181250897466322))]

# %%
len(results)
# Out:
# 181

# %%
# find for which ministries the vocab and embedding classifications match
matches = []
for res in results:
    vocab_top = max(res["vocab_distribution"], key=res["vocab_distribution"].get)
    embed_top = max(res["embedding_distribution"], key=res["embedding_distribution"].get)

    if vocab_top == embed_top:
        matches.append({
            "paragraph_id": res["paragraph_id"],
            "speaker": res["speaker"],
            "ministry": vocab_top,
            "paragraph_snippet": res["paragraph"]
        })
print("\nParagraphs where vocab and embedding classifications match:")
for match in matches:
    print(f"Paragraph {match['paragraph_id']} - Speaker: {match['speaker']} - Ministry: {match['ministry']}")
    print(f"Snippet: {match['paragraph_snippet']}")
    print("-" * 80)
# Out:
# Paragraphs where vocab and embedding classifications match:
# Paragraph 9 - Speaker: HON. SPEAKER - Ministry: Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_
# Snippet: prime dhandhaanya krishi yojana developing agri districts programme motivated success aspirational undertake partnership states convergence existing schemes measures cover low productivity moderate crop intensity belowaverage credit parameters enhance agricultural adopt diversification sustainable agriculture practices augment postharvest storage panchayat block level improve irrigation facilities facilitate availability longterm shortterm likely help crore farmers
# --------------------------------------------------------------------------------
# Paragraph 14 - Speaker: HON. SPEAKER - Ministry: Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_
# Snippet: years ago concerted efforts succeeded achieving near selfsufficiency pulses farmers responded increasing cultivated area cent arranged procurement remunerative prices rising incomes better affordability consumption increased significantly
# --------------------------------------------------------------------------------
# Paragraph 17 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_
# Snippet: comprehensive programme promote production efficient supplies processing remunerative prices farmers launched partnership states appropriate institutional mechanisms implementation participation farmer producer organizations cooperatives
# --------------------------------------------------------------------------------
# Paragraph 21 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_
# Snippet: cotton productivity benefit lakhs growing farmers announce facilitate significant improvements sustainability farming promote extralong staple varieties best science technology provided aligned integrated vision textile sector help increasing incomes steady supply quality rejuvenating indias traditional
# --------------------------------------------------------------------------------
# Paragraph 22 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_
# Snippet: enhanced credit kcc kisan cards facilitate short term loans crore farmers fishermen dairy loan limit modified subvention lakh taken
# --------------------------------------------------------------------------------
# Paragraph 28 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Micro_Small_Medium_Enterprises_MoME_
# Snippet: msmes engine encompasses manufacturing services numbering crore
# --------------------------------------------------------------------------------
# Paragraph 30 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Micro_Small_Medium_Enterprises_MoME_
# Snippet: significant enhancement credit availability guarantee cover improve access enhanced micro enterprises crore leading additional lakh years startups fee moderated cent loans sectors atmanirbhar wellrun exporter msmes term
# --------------------------------------------------------------------------------
# Paragraph 31 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Micro_Small_Medium_Enterprises_MoME_
# Snippet: credit cards micro enterprises introduce customized lakh limit registered udyam portal issued
# --------------------------------------------------------------------------------
# Paragraph 35 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Textiles_MoT_
# Snippet: product footwear leather sectors enhance productivity quality competitiveness indias sector implemented design capacity component manufacturing machinery required production nonleather products expected facilitate employment lakh persons generate turnover crore exports
# --------------------------------------------------------------------------------
# Paragraph 39 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_New_and_Renewable_Energy_MNRE_
# Snippet: clean tech manufacturing given commitment climatefriendly aim improve domestic addition build ecosystem solar cells batteries motors controllers electrolyzers wind turbines voltage transmission equipment grid scale
# --------------------------------------------------------------------------------
# Paragraph 50 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Rural_Development_MoRD_
# Snippet: strengthening urban livelihoods giving priority assisting poor vulnerable groups socioeconomic upliftment workers implemented help improve incomes sustainable better quality life
# --------------------------------------------------------------------------------
# Paragraph 59 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Housing_and_Urban_Affairs_MoHUA_
# Snippet: urban challenge fund lakh crore implement proposals cities growth hubs creative redevelopment water sanitation purposes announced july budget
# --------------------------------------------------------------------------------
# Paragraph 61 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Power_MoP_
# Snippet: power sector reforms incentivize electricity distribution augmentation intrastate transmission capacity states improve financial health companies additional borrowing cent gsdp allowed contingent
# --------------------------------------------------------------------------------
# Paragraph 62 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Power_MoP_
# Snippet: nuclear energy viksit essential transition efforts active partnership private sector goal amendments atomic civil liability damage taken
# --------------------------------------------------------------------------------
# Paragraph 63 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Power_MoP_
# Snippet: nuclear energy research modular reactors smr outlay crore indigenously developed smrs operationalized
# --------------------------------------------------------------------------------
# Paragraph 73 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: building success swamih fund established blended finance facility contribution banks private investors
# --------------------------------------------------------------------------------
# Paragraph 78 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Tourism_MoT_
# Snippet: continuing emphasis places spiritual religious significance july budget special destinations related life times buddha
# --------------------------------------------------------------------------------
# Paragraph 82 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Science_and_Technology_MST_
# Snippet: research fellowship years provide thousand fellowships technological iits iisc enhanced financial
# --------------------------------------------------------------------------------
# Paragraph 83 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_
# Snippet: gene bank crops germplasm lakh lines future food nutritional security provide conservation public private sectors genetic resources
# --------------------------------------------------------------------------------
# Paragraph 85 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Culture
# Snippet: gyan bharatam survey documentation conservation manuscript heritage academic institutions museums libraries private collectors undertaken cover crore manuscripts digital repository knowledge systems sharing
# --------------------------------------------------------------------------------
# Paragraph 94 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Petroleum_and_Natural_Gas_MoPNG_
# Snippet: reforms fuel specific
# --------------------------------------------------------------------------------
# Paragraph 96 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: financial sector reforms fdi insurance limit raised cent
# --------------------------------------------------------------------------------
# Paragraph 99 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: credit enhancement facility nabfid partial corporate bonds infrastructure
# --------------------------------------------------------------------------------
# Paragraph 113 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: revised estimate fiscal deficit cent gdp
# --------------------------------------------------------------------------------
# Paragraph 115 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: fiscal deficit estimated cent gdp
# --------------------------------------------------------------------------------
# Paragraph 125 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Heavy_Industries_MoHI_
# Snippet: lithium ion battery list exempted capital goods propose add additional manufacturing mobile phone boost domestic manufacture lithiumion batteries phones electric vehicles
# --------------------------------------------------------------------------------
# Paragraph 131 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_
# Snippet: marine products enhance indias competitiveness global seafood market propose reduce bcd frozen fish paste surimi manufacture export analogue hydrolysates shrimp feeds
# --------------------------------------------------------------------------------
# Paragraph 133 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Railways_MoR_
# Snippet: propose extend dispensation railway goods
# --------------------------------------------------------------------------------
# Paragraph 134 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: trade facilitation limit provisional assessment presently customs does provide finalize assessments leading uncertainty cost measure promoting ease doing business propose fix timelimit years extendable finalising
# --------------------------------------------------------------------------------
# Paragraph 153 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: ease doing business streamline transfer pricing provide alternative yearly examination propose introduce determining arms length price international transaction block period years line global best practices
# --------------------------------------------------------------------------------
# Paragraph 161 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Ports_Shipping_and_Waterways_MoPSW_
# Snippet: tonnage tax inland vessels presently available sea going ships benefits existing proposed extended registered promote water transport country
# --------------------------------------------------------------------------------
# Paragraph 164 - Speaker: SHRI AKHILESH YADAV (KANNAUJ) - Ministry: Ministry_of_Finance_MoF_
# Snippet: alternate investment funds aifs category undertaking investments infrastructure sectors propose provide certainty taxation entities gains securities
# --------------------------------------------------------------------------------
# Paragraph 165 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: extension investment date sovereign pension funds promote funding wealth infrastructure sector propose extend making years march
# --------------------------------------------------------------------------------
# Paragraph 169 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: slabs rates changed board benefit taxpayers
# --------------------------------------------------------------------------------
# Paragraph 170 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: structure substantially reduce taxes middle class leave money hands boosting household consumption savings investment
# --------------------------------------------------------------------------------
# Paragraph 171 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: tax regime propose revise rate structure follows lakh rupees nil cent payers upto normal income special capital gains read rebate provided addition benefit slab reduction manner payable total changes different levels illustrated examples
# --------------------------------------------------------------------------------
# Paragraph 172 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: tax payer regime income lakh benefit payable existing rates person having gets
# --------------------------------------------------------------------------------
# Paragraph 173 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: result proposals speaker sir revenue lakh crore direct taxes indirect forgone
# --------------------------------------------------------------------------------

# %%
len(matches)
# Out:
# 38

# %%
# total paragraphs = 181
# matches = 38
# top 2 = 37
# top 3 = 53
# top 4 = 65
# top 5 = 71

# %%
# find top 5 errors for ministry classification 
# (vocab top 1 != embedding top 1 and vocab top 1 is comming in top 5 of embedding or vice versa)
errors = []
for res in results:
    vocab_top = max(res["vocab_distribution"], key=res["vocab_distribution"].get)
    embed_top = max(res["embedding_distribution"], key=res["embedding_distribution"].get)

    if vocab_top != embed_top:
        vocab_top_5 = sorted(res["vocab_distribution"].items(), key=lambda x: x[1], reverse=True)[:5]
        embed_top_5 = sorted(res["embedding_distribution"].items(), key=lambda x: x[1], reverse=True)[:5]

        vocab_top_5_ministries = [v[0] for v in vocab_top_5]
        embed_top_5_ministries = [e[0] for e in embed_top_5]

        if (vocab_top in embed_top_5_ministries) or (embed_top in vocab_top_5_ministries):
            errors.append({
                "paragraph_id": res["paragraph_id"],
                "speaker": res["speaker"],
                "vocab_top": vocab_top,
                "embed_top": embed_top,
                "paragraph_snippet": res["paragraph"]
            })
print("\nClassification errors where vocab and embedding disagree but one is in top 5 of the other:")
for error in errors:
    print(f"Paragraph {error['paragraph_id']} - Speaker: {error['speaker']} - Vocab Top: {error['vocab_top']} - Embed Top: {error['embed_top']}")
    print(f"Snippet: {error['paragraph_snippet']}")
    print("-" * 80)
# Out:
# Classification errors where vocab and embedding disagree but one is in top 5 of the other:
# Paragraph 0 - Speaker: HON. SPEAKER - Vocab Top: Ministry_of_Statistics_and_Programme_Implementation_MoSPI_ - Embed Top: Ministry_of_Parliamentary_Affairs_MPA_
# Snippet: honble members ample opportunity participate discussion motion thanks presidents address budget
# --------------------------------------------------------------------------------
# Paragraph 4 - Speaker: HON. SPEAKER - Vocab Top: Ministry_of_External_Affairs_MEA_ - Embed Top: Ministry_of_Tourism_MoT_
# Snippet: embark journey unlock nations tremendous potential prosperity global positioning leadership
# --------------------------------------------------------------------------------
# Paragraph 10 - Speaker: HON. SPEAKER - Vocab Top: Ministry_of_Rural_Development_MoRD_ - Embed Top: Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_
# Snippet: building rural prosperity resilience comprehensive multisectoral programme launched partnership states address underemployment agriculture skilling investment technology invigorating economy goal generate ample opportunities areas migration option necessity
# --------------------------------------------------------------------------------
# Paragraph 12 - Speaker: HON. SPEAKER - Vocab Top: Ministry_of_Commerce_and_Industry_MoCI_ - Embed Top: Ministry_of_Finance_MoF_
# Snippet: global domestic best practices incorporated appropriate technical financial assistance sought multilateral banks phase developing agridistricts covered
# --------------------------------------------------------------------------------
# Paragraph 13 - Speaker: HON. SPEAKER - Vocab Top: Ministry_of_Food_Processing_Industries_MoFPI_ - Embed Top: Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_
# Snippet: aatmanirbharta pulses implementing edible oilseed achieving atmanirbhrata oils farmers capability grow needs
# --------------------------------------------------------------------------------
# Paragraph 15 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Textiles_MoT_ - Embed Top: Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_
# Snippet: launch aatmanirbharta pulses special tur urad masoor central agencies nafed nccf ready procure offered years farmers register enter agreements
# --------------------------------------------------------------------------------
# Paragraph 16 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_ - Embed Top: Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_
# Snippet: comprehensive programme vegetables fruits encouraging increasingly aware nutritional needs sign society healthier rising income levels consumption shreeanna increasing significantly
# --------------------------------------------------------------------------------
# Paragraph 18 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Statistics_and_Programme_Implementation_MoSPI_ - Embed Top: Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_
# Snippet: makhana board bihar special opportunity established state improve production processing addition marketing engaged activities organized fpos provide handholding training farmers work receive benefits relevant schemes
# --------------------------------------------------------------------------------
# Paragraph 20 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_ - Embed Top: Ministry_of_Ports_Shipping_and_Waterways_MoPSW_
# Snippet: seafood exports valued thousand crore unlock untapped potential marine sector bring enabling framework sustainable harnessing fisheries exclusive economic zone seas special andaman nicobar lakshadweep islands
# --------------------------------------------------------------------------------
# Paragraph 23 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Development_of_North_Eastern_Region_MDoNER_ - Embed Top: Ministry_of_New_and_Renewable_Energy_MNRE_
# Snippet: urea plant assam atmanirbharta production reopened dormant plants eastern region augment supply annual capacity lakh metric tons namrup
# --------------------------------------------------------------------------------
# Paragraph 24 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Communications_MoC_ - Embed Top: Ministry_of_Rural_Development_MoRD_
# Snippet: post catalyst rural economy lakh offices complemented payment bank vast network dak sevaks repositioned
# --------------------------------------------------------------------------------
# Paragraph 25 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Statistics_and_Programme_Implementation_MoSPI_ - Embed Top: Ministry_of_Ports_Shipping_and_Waterways_MoPSW_
# Snippet: post transformed large public logistics organization
# --------------------------------------------------------------------------------
# Paragraph 26 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Rural_Development_MoRD_ - Embed Top: Ministry_of_Micro_Small_Medium_Enterprises_MoME_
# Snippet: meet rising needs viswakarmas entrepreneurs women selfhelp groups msmes large business organizations
# --------------------------------------------------------------------------------
# Paragraph 29 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Textiles_MoT_ - Embed Top: Ministry_of_Micro_Small_Medium_Enterprises_MoME_
# Snippet: revision classification criteria msmes currently crore registered employing generating cent manufacturing come position global hub quality products responsible exports help achieve efficiencies scale technological upgradation better access capital investment turnover limits enhanced times respectively confidence grow generate employment youth
# --------------------------------------------------------------------------------
# Paragraph 36 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Textiles_MoT_ - Embed Top: Ministry_of_Food_Processing_Industries_MoFPI_
# Snippet: measures toy sector building action plan toys implement global hub clusters skills manufacturing ecosystem create highquality unique innovative sustainable represent brand
# --------------------------------------------------------------------------------
# Paragraph 37 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_ - Embed Top: Ministry_of_Food_Processing_Industries_MoFPI_
# Snippet: food processing line commitment purvodaya establish institute technology entrepreneurship management bihar provide strong fillip activities entire eastern region result enhanced income farmers addition produce skilling employment opportunities youth
# --------------------------------------------------------------------------------
# Paragraph 38 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Planning_MoP_ - Embed Top: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: manufacturing furthering covering medium large industries providing policy execution roadmaps governance monitoring framework central ministries states
# --------------------------------------------------------------------------------
# Paragraph 41 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Education_MoE_ - Embed Top: Ministry_of_Women_and_Child_Development_MoWCD_
# Snippet: investing saksham anganwadi poshan programme nutritional crore children pregnant women lactating mothers country lakh adolescent girls aspirational districts northeast region cost norms enhanced appropriately
# --------------------------------------------------------------------------------
# Paragraph 42 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Youth_Affairs_and_Sports_MoYAS_ - Embed Top: Ministry_of_Science_and_Technology_MST_
# Snippet: atal tinkering labs thousand schools years cultivate spirit curiosity innovation foster scientific temper young minds
# --------------------------------------------------------------------------------
# Paragraph 43 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Minority_Affairs_MoMA_ - Embed Top: Ministry_of_Education_MoE_
# Snippet: broadband connectivity secondary schools phcs provided primary health centres rural areas bharatnet project
# --------------------------------------------------------------------------------
# Paragraph 44 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_ - Embed Top: Ministry_of_Education_MoE_
# Snippet: bharatiya bhasha pustak propose implement provide digitalform language books school education help students understand subjects better
# --------------------------------------------------------------------------------
# Paragraph 45 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Statistics_and_Programme_Implementation_MoSPI_ - Embed Top: Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_
# Snippet: centres excellence skilling building initiative announced july budget global expertise partnerships equip youth skills required world manufacturing cover curriculum design training trainers certification framework periodic reviews
# --------------------------------------------------------------------------------
# Paragraph 46 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Food_Processing_Industries_MoFPI_ - Embed Top: Ministry_of_Education_MoE_
# Snippet: expansion capacity iits total number students increased cent lakh past years additional infrastructure started facilitate education hostel iit patna expanded
# --------------------------------------------------------------------------------
# Paragraph 48 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Health_and_Family_Welfare_MoHFW_ - Embed Top: Ministry_of_Education_MoE_
# Snippet: expansion medical education added lakh seats years increase cent additional colleges hospitals goal adding
# --------------------------------------------------------------------------------
# Paragraph 49 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_AYUSH_MoA_ - Embed Top: Ministry_of_Health_and_Family_Welfare_MoHFW_
# Snippet: day care cancer centres district hospitals facilitate setting years established
# --------------------------------------------------------------------------------
# Paragraph 56 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Petroleum_and_Natural_Gas_MoPNG_ - Embed Top: Ministry_of_Jal_Shakti_MoJS_
# Snippet: jal jeevan crore households representing cent indias rural population provided access potable tap water connections achieve coverage announce extension enhanced total outlay
# --------------------------------------------------------------------------------
# Paragraph 65 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_ - Embed Top: Ministry_of_Ports_Shipping_and_Waterways_MoPSW_
# Snippet: large ships specified size included infrastructure harmonized master list hml
# --------------------------------------------------------------------------------
# Paragraph 67 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Power_MoP_ - Embed Top: Ministry_of_Ports_Shipping_and_Waterways_MoPSW_
# Snippet: maritime fund longterm financing industry corpus crore distributed promoting competition cent contribution balance mobilized ports private sector
# --------------------------------------------------------------------------------
# Paragraph 68 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Development_of_North_Eastern_Region_MDoNER_ - Embed Top: Ministry_of_Road_Transport_and_Highways_MoRTH_
# Snippet: udan regional connectivity enabled crore middleclass meet aspirations speedier travel connected airports operationalized routes inspired success modified launched enhance destinations carry additional passengers yearsthe helipads smaller hilly aspirational east districts
# --------------------------------------------------------------------------------
# Paragraph 70 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Coal_MoC_ - Embed Top: Ministry_of_Mines_MoM_
# Snippet: mining sector reforms including minor minerals encouraged sharing best practices institution state index
# --------------------------------------------------------------------------------
# Paragraph 71 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Coal_MoC_ - Embed Top: Ministry_of_Mines_MoM_
# Snippet: policy recovery critical minerals tailings brought
# --------------------------------------------------------------------------------
# Paragraph 72 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Women_and_Child_Development_MoWCD_ - Embed Top: Ministry_of_Rural_Development_MoRD_
# Snippet: swamih fund special window affordable midincome housing thousand dwelling units stressed projects completed keys handed homebuyers fortythousand helping middleclass families paying emis loans taken apartments rent current dwellings
# --------------------------------------------------------------------------------
# Paragraph 74 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Micro_Small_Medium_Enterprises_MoME_ - Embed Top: Ministry_of_Rural_Development_MoRD_
# Snippet: fund crore aim expeditious completion lakh units
# --------------------------------------------------------------------------------
# Paragraph 76 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Culture - Embed Top: Ministry_of_Tourism_MoT_
# Snippet: tourism employmentled growth tourist destination sites country developed partnership states challenge mode land building infrastructure provided hotels destinations included harmonized list
# --------------------------------------------------------------------------------
# Paragraph 79 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Culture - Embed Top: Ministry_of_Tourism_MoT_
# Snippet: medical tourism heal promoted partnership private sector capacity building easier visa norms
# --------------------------------------------------------------------------------
# Paragraph 80 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Tourism_MoT_ - Embed Top: Ministry_of_Planning_MoP_
# Snippet: investing innovation research implement private sector driven initiative announced july budget allocating crore
# --------------------------------------------------------------------------------
# Paragraph 81 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Mines_MoM_ - Embed Top: Ministry_of_Science_and_Technology_MST_
# Snippet: deep tech fund funds explored catalyse generation startups initiative
# --------------------------------------------------------------------------------
# Paragraph 86 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Micro_Small_Medium_Enterprises_MoME_ - Embed Top: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: exports engine export promotion sectoral targets driven jointly ministries commerce msme finance facilitate easy access credit crossborder factoring msmes tackle nontariff measures overseas markets
# --------------------------------------------------------------------------------
# Paragraph 89 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Food_Processing_Industries_MoFPI_ - Embed Top: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: integration global supply chains provided develop domestic manufacturing capacities economys sectors identified objective criteria
# --------------------------------------------------------------------------------
# Paragraph 90 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_ - Embed Top: Ministry_of_Food_Processing_Industries_MoFPI_
# Snippet: facilitation groups participation senior officers industry representatives formed select products supply chains
# --------------------------------------------------------------------------------
# Paragraph 91 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Youth_Affairs_and_Sports_MoYAS_ - Embed Top: Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_
# Snippet: huge opportunities related industry needs skills talent youth domestic electronic equipment leverage opportunity benefit
# --------------------------------------------------------------------------------
# Paragraph 93 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_ - Embed Top: Ministry_of_Ports_Shipping_and_Waterways_MoPSW_
# Snippet: warehousing facility air cargo facilitate upgradation infrastructure including perishable horticulture produce screening customs protocols streamlined userfriendly
# --------------------------------------------------------------------------------
# Paragraph 95 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Culture - Embed Top: Ministry_of_Finance_MoF_
# Snippet: tax reforms past years implemented convenience payers faceless assessment charter faster returns cent selfassessment vivad vishwas schemecontinuing efforts reaffirm commitment trust scrutinize later propose introduce incometax week indirect changes direct taxes
# --------------------------------------------------------------------------------
# Paragraph 102 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Communications_MoC_ - Embed Top: Ministry_of_Electronics_and_Information_Technology_MeitY_
# Snippet: kyc simplification implement earlier announcement simplifying processes revamped central registry rolled streamlined periodic updating
# --------------------------------------------------------------------------------
# Paragraph 105 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Corporate_Affairs_MCA_ - Embed Top: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: regulatory reforms years aspects including financial nonfinancial demonstrated steadfast commitment ease doing business determined regulations technological innovations global policy developments lighttouch framework principles trust unleash productivity employment
# --------------------------------------------------------------------------------
# Paragraph 107 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Commerce_and_Industry_MoCI_ - Embed Top: Ministry_of_Corporate_Affairs_MCA_
# Snippet: develop modern flexible peoplefriendly trustbased regulatory framework appropriate twentyfirst century propose specific measures level reforms highlevel review nonfinancial sector regulations certifications licenses permissions expected recommendations objective strengthen economic governance transformational enhance ease doing business especially matters inspections compliances states encouraged join endeavour
# --------------------------------------------------------------------------------
# Paragraph 108 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Planning_MoP_ - Embed Top: Ministry_of_Cooperation_MoC_
# Snippet: investment friendliness index states launched spirit competitive cooperative federalism
# --------------------------------------------------------------------------------
# Paragraph 112 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Statistics_and_Programme_Implementation_MoSPI_ - Embed Top: Ministry_of_Finance_MoF_
# Snippet: revised estimates estimate total receipts borrowings lakh crore net tax expenditure capital
# --------------------------------------------------------------------------------
# Paragraph 114 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Statistics_and_Programme_Implementation_MoSPI_ - Embed Top: Ministry_of_Finance_MoF_
# Snippet: budget estimates coming total receipts borrowings expenditure estimated lakh crore respectively net tax
# --------------------------------------------------------------------------------
# Paragraph 117 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Finance_MoF_ - Embed Top: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: indirect taxes proposals relating customs aim rationalize tariff structure address duty inversion domestic manufacturing addition promote exports facilitate trade provide relief common
# --------------------------------------------------------------------------------
# Paragraph 118 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Finance_MoF_ - Embed Top: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: rationalisation customs tariff structure industrial goods comprehensive review rate announced july budget propose remove seven rates removed remaining including zero apply appropriate cess broadly maintain effective duty incidence items reduce marginally iii levy surcharge exempt social welfare lines subject
# --------------------------------------------------------------------------------
# Paragraph 119 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_AYUSH_MoA_ - Embed Top: Ministry_of_Chemicals_and_Fertilizers_MoCF_
# Snippet: relief import drugsmedicines provide patients particularly suffering cancer rare diseases severe chronic propose add lifesaving drugs medicines list fully exempted basic custom duty bcd attracting concessional exemption respectively apply bulk manufacture
# --------------------------------------------------------------------------------
# Paragraph 120 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Chemicals_and_Fertilizers_MoCF_ - Embed Top: Ministry_of_Health_and_Family_Welfare_MoHFW_
# Snippet: specified drugs medicines patient assistance programmes run pharmaceutical companies fully exempt bcd provided supplied free cost patients propose add
# --------------------------------------------------------------------------------
# Paragraph 121 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Micro_Small_Medium_Enterprises_MoME_ - Embed Top: Ministry_of_Mines_MoM_
# Snippet: domestic manufacturing addition critical minerals july budget fully exempted bcd domestically available reduced provide major fillip processing especially msmes propose exempt cobalt powder waste scrap lithiumion battery lead zinc help secure availability promote jobs youth
# --------------------------------------------------------------------------------
# Paragraph 122 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Food_Processing_Industries_MoFPI_ - Embed Top: Ministry_of_Textiles_MoT_
# Snippet: textiles promote domestic production technical textile products agrotextiles medical geo competitive prices propose add types shuttleless looms list fully exempted machinery revise bcd rate knitted fabrics covered tariff lines whichever
# --------------------------------------------------------------------------------
# Paragraph 123 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Heavy_Industries_MoHI_ - Embed Top: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: electronic goods line policy rectify inverted duty structure propose increase bcd interactive flat panel display ifpd reduce cell components
# --------------------------------------------------------------------------------
# Paragraph 128 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_ - Embed Top: Ministry_of_Communications_MoC_
# Snippet: telecommunication prevent classification disputes propose reduce bcd carrier grade ethernet switches par noncarrier
# --------------------------------------------------------------------------------
# Paragraph 129 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Textiles_MoT_ - Embed Top: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: export promotion handicraft goods facilitate exports handicrafts propose extend period months extendable required add items list dutyfree inputs
# --------------------------------------------------------------------------------
# Paragraph 130 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Steel_MoS_ - Embed Top: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: leather sector propose fully exempt bcd wet blue facilitate imports domestic addition employment crust export duty exports tanners
# --------------------------------------------------------------------------------
# Paragraph 132 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_ - Embed Top: Ministry_of_Railways_MoR_
# Snippet: domestic mros railway goods july budget promote aircraft ships extended limit export foreign origin imported repairs months extendable
# --------------------------------------------------------------------------------
# Paragraph 137 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Food_Processing_Industries_MoFPI_ - Embed Top: Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_
# Snippet: provide operational flexibility view cost uncertainty supply
# --------------------------------------------------------------------------------
# Paragraph 139 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Commerce_and_Industry_MoCI_ - Embed Top: Ministry_of_Finance_MoF_
# Snippet: gone missing kumbh disappeareddirect taxes
# --------------------------------------------------------------------------------
# Paragraph 140 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Home_Affairs_MHA_ - Embed Top: Ministry_of_Finance_MoF_
# Snippet: briefly underlined taxation reforms realize vision viksit respect criminal law earlier ushered bharatiya nyaya sanhita replacing danda happy inform august country incometax carry forward spirit drafting
# --------------------------------------------------------------------------------
# Paragraph 146 - Speaker: SHRI ANAND BHADAURIA (DHAURAHRA) - Vocab Top: Ministry_of_Women_and_Child_Development_MoWCD_ - Embed Top: Ministry_of_Finance_MoF_
# Snippet: tdstcs rationalization easing difficulties propose rationalize tax deduction source tds reducing number rates thresholds deducted threshold amounts increased better clarity uniformity limit senior citizens doubled present lakh similarly annual rent reduce transactions liable benefitting payers receiving payments
# --------------------------------------------------------------------------------
# Paragraph 148 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Electronics_and_Information_Technology_MeitY_ - Embed Top: Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_
# Snippet: tds tcs applied transaction relating sale goods prevent compliance difficulties propose omit provisions deduction apply nonpan cases
# --------------------------------------------------------------------------------
# Paragraph 154 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Civil_Aviation_MoCA_ - Embed Top: Ministry_of_Ports_Shipping_and_Waterways_MoPSW_
# Snippet: view reduce litigation provide certainty international taxation scope safe harbour rules expanded
# --------------------------------------------------------------------------------
# Paragraph 159 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Micro_Small_Medium_Enterprises_MoME_ - Embed Top: Ministry_of_Labour_and_Employment_MoLE_
# Snippet: employment investment proposals promote
# --------------------------------------------------------------------------------
# Paragraph 160 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Heavy_Industries_MoHI_ - Embed Top: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: tax certainty electronics manufacturing schemes proposed provide presumptive taxation regime nonresidents services resident company establishing operating facility propose introduce safe harbour store components supply specified units
# --------------------------------------------------------------------------------
# Paragraph 168 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Road_Transport_and_Highways_MoRTH_ - Embed Top: Ministry_of_Finance_MoF_
# Snippet: right nil tax slab raised lakh reflective governments trust middleclass payers happy announce income payable upto average month special rate capital gains regime limit salaried standard deduction
# --------------------------------------------------------------------------------
# Paragraph 175 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Statistics_and_Programme_Implementation_MoSPI_ - Embed Top: Ministry_of_Finance_MoF_
# Snippet: sir permission rise lay table following statements section fiscal responsibility budget management frbm mediumterm policy cum strategy statement macroeconomic framework
# --------------------------------------------------------------------------------
# Paragraph 180 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Law_and_Justice_MoLJ_ - Embed Top: Ministry_of_Parliamentary_Affairs_MPA_
# Snippet: lok sabha adjourned till clock monday february magha saka
# --------------------------------------------------------------------------------

# %%
len(errors)
# Out:
# 71

# %%
import numpy as np

def compute_document_distribution(results, method="embedding"):
    
    ministry_scores = {}

    for item in results:

        if method == "embedding":
            dist = item["embedding_distribution"]
        else:
            dist = item["vocab_distribution"]

        for ministry, prob in dist.items():
            ministry_scores[ministry] = ministry_scores.get(ministry, 0) + prob

    # normalize
    total = sum(ministry_scores.values())

    ministry_scores = {
        k: v / total
        for k, v in ministry_scores.items()
    }

    return ministry_scores

# %%
def print_top_ministries(distribution, top_k=10):

    sorted_min = sorted(
        distribution.items(),
        key=lambda x: x[1],
        reverse=True
    )

    print("\nTOP MINISTRIES IN DOCUMENT\n")

    for ministry, score in sorted_min[:top_k]:
        print(f"{ministry:40} {score:.4f}")

# %%
import matplotlib.pyplot as plt

def plot_ministry_distribution(distribution, top_k=10):

    sorted_min = sorted(
        distribution.items(),
        key=lambda x: x[1],
        reverse=True
    )[:top_k]

    ministries = [x[0] for x in sorted_min]
    scores = [x[1] for x in sorted_min]

    plt.figure(figsize=(12,6))

    plt.barh(ministries, scores)

    plt.xlabel("Probability")
    plt.title("Document Ministry Distribution")

    plt.gca().invert_yaxis()

    plt.show()

# %%
def plot_comparison(vocab_dist, embed_dist, top_k=10):

    vocab_sorted = sorted(vocab_dist.items(), key=lambda x: x[1], reverse=True)[:top_k]
    embed_sorted = sorted(embed_dist.items(), key=lambda x: x[1], reverse=True)[:top_k]

    ministries = [x[0] for x in embed_sorted]

    vocab_scores = [vocab_dist.get(m,0) for m in ministries]
    embed_scores = [embed_dist.get(m,0) for m in ministries]

    x = np.arange(len(ministries))

    plt.figure(figsize=(12,6))

    plt.bar(x-0.2, vocab_scores, width=0.4, label="Vocab")
    plt.bar(x+0.2, embed_scores, width=0.4, label="Embedding")

    plt.xticks(x, ministries, rotation=60)
    plt.ylabel("Score")

    plt.title("Ministry Distribution Comparison")

    plt.legend()

    plt.show()

# %%
def build_heatmap_matrix(results, method="embedding"):

    ministries = list(results[0][f"{method}_distribution"].keys())
    num_paragraphs = len(results)

    matrix = np.zeros((len(ministries), num_paragraphs))

    for j, para in enumerate(results):

        dist = para[f"{method}_distribution"]

        for i, ministry in enumerate(ministries):

            matrix[i, j] = dist[ministry]

    return matrix, ministries

import matplotlib.pyplot as plt

def plot_ministry_heatmap(matrix, ministries):

    plt.figure(figsize=(16,8))

    plt.imshow(matrix, aspect='auto')

    plt.colorbar(label="Ministry Relevance")

    plt.ylabel("Ministries")
    plt.xlabel("Paragraph Index")

    plt.yticks(range(len(ministries)), ministries)

    plt.title("Ministry Discussion Heatmap Across Paragraphs")

    plt.show()

# %%
vocab_doc_dist = compute_document_distribution(results, "vocab")
embed_doc_dist = compute_document_distribution(results, "embedding")

print_top_ministries(embed_doc_dist)
# Out:
# TOP MINISTRIES IN DOCUMENT
#
# Ministry_of_Finance_MoF_                 0.0203
# Ministry_of_Micro_Small_Medium_Enterprises_MoME_ 0.0202
# Ministry_of_Commerce_and_Industry_MoCI_  0.0201
# Ministry_of_Development_of_North_Eastern_Region_MDoNER_ 0.0200
# Ministry_of_Heavy_Industries_MoHI_       0.0199
# Ministry_of_Rural_Development_MoRD_      0.0199
# Ministry_of_Cooperation_MoC_             0.0198
# Ministry_of_Housing_and_Urban_Affairs_MoHUA_ 0.0196
# Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_ 0.0196
# Ministry_of_Food_Processing_Industries_MoFPI_ 0.0195

# %%
plot_ministry_distribution(embed_doc_dist, top_k=15)

# %%
plot_comparison(vocab_doc_dist, embed_doc_dist, top_k=15)

# %%
matrix, ministries = build_heatmap_matrix(results, "embedding")

plot_ministry_heatmap(matrix, ministries)

# %%
matrix, ministries = build_heatmap_matrix(results, "vocab")

plot_ministry_heatmap(matrix, ministries)

# %%
def plot_top_ministry_heatmap(matrix, ministries, top_k=10):

    ministry_scores = matrix.sum(axis=1)

    top_idx = np.argsort(ministry_scores)[::-1][:top_k]

    top_matrix = matrix[top_idx]
    top_ministries = [ministries[i] for i in top_idx]

    plt.figure(figsize=(16,6))

    plt.imshow(top_matrix, aspect='auto')

    plt.colorbar(label="Relevance")

    plt.yticks(range(top_k), top_ministries)

    plt.xlabel("Paragraph Index")
    plt.ylabel("Top Ministries")

    plt.title("Top Ministry Heatmap Across Paragraphs")

    plt.show()
    
matrix, ministries = build_heatmap_matrix(results)

plot_top_ministry_heatmap(matrix, ministries)

# %%
matrix, ministries = build_heatmap_matrix(results, method="vocab")

plot_top_ministry_heatmap(matrix, ministries)

# %%
from collections import defaultdict

def build_speaker_ministry_matrix(results, method="embedding"):

    speaker_ministry = defaultdict(lambda: defaultdict(float))

    for item in results:

        speaker = item["speaker"]

        dist = item[f"{method}_distribution"]

        for ministry, prob in dist.items():
            speaker_ministry[speaker][ministry] += prob

    speakers = list(speaker_ministry.keys())
    ministries = list(next(iter(speaker_ministry.values())).keys())

    matrix = np.zeros((len(speakers), len(ministries)))

    for i, spk in enumerate(speakers):
        for j, minstry in enumerate(ministries):

            matrix[i, j] = speaker_ministry[spk][minstry]

    # ministers dominate because they speak more
    # it should show speaker focus instead of speaker volume
    # so normalize rows to sum to 1
    matrix = matrix / (matrix.sum(axis=0, keepdims=True) + 1e-9)
    
    return matrix, speakers, ministries

# %%
def select_top_ministries(matrix, ministries, top_k=10):

    scores = matrix.sum(axis=0)

    top_idx = np.argsort(scores)[::-1][:top_k]

    new_matrix = matrix[:, top_idx]

    new_ministries = [ministries[i] for i in top_idx]

    return new_matrix, new_ministries

# %%
import seaborn as sns

def plot_speaker_ministry_heatmap(matrix, speakers, ministries):

    plt.figure(figsize=(14,8))

    sns.heatmap(
        matrix,
        xticklabels=ministries,
        yticklabels=speakers,
        cmap="YlOrRd"
    )

    plt.xlabel("Ministry")
    plt.ylabel("Speaker")

    plt.title("Speaker × Ministry Discussion Heatmap")

    plt.show()

# %%
matrix, speakers, ministries = build_speaker_ministry_matrix(results, method="embedding")

matrix, ministries = select_top_ministries(matrix, ministries, top_k=20)

plot_speaker_ministry_heatmap(matrix, speakers, ministries)

# %%
matrix, speakers, ministries = build_speaker_ministry_matrix(results, method="vocab")

matrix, ministries = select_top_ministries(matrix, ministries, top_k=20)

plot_speaker_ministry_heatmap(matrix, speakers, ministries)
