# %%
import json
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

import sys
sys.path.append("../")
from src.preprocessing.pdf_extractor import PDFExtractor
from src.preprocessing.document_validator import DocumentValidator

# %%
# ---------------------------------------------------------
# LOAD FILES
# ---------------------------------------------------------

VOCAB_FILE = "../data/vocabulary/ministry_tfidf_vocab.json"
EMBED_FILE = "../data/embeddings/ministry_embeddings2.json"


def load_vocab():
    with open(VOCAB_FILE, "r") as f:
        return json.load(f)


def load_embeddings():
    with open(EMBED_FILE, "r") as f:
        data = json.load(f)

    # convert to numpy
    for k in data:
        data[k] = np.array(data[k])

    return data

# %%
STOPWORD_FILE = "../data/stopwords/GBparl_stopwords-empirical.txt"

from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

def load_stopwords(custom_file):

    stopwords = set(ENGLISH_STOP_WORDS)

    # load domain stopwords
    with open(custom_file, "r", encoding="utf-8") as f:
        for line in f:
            word = line.strip().lower()
            if word:
                stopwords.add(word)

    return stopwords

stopwords = load_stopwords(STOPWORD_FILE)

# %%
import re

def clean_text(text, stopwords=None):

    # remove bullet characters
    text = text.replace("\uf0b7", " ")

    # remove numbering like "1." "2."
    text = re.sub(r"\n?\d+\.\s*", " ", text)

    # replace newlines with space
    text = text.replace("\n", " ")

    # remove multiple spaces
    text = re.sub(r"\s+", " ", text)
    
    # remove all punctuation
    text = re.sub(r'[^\w\s]', '', text)
    
    # keep only alphabets, remove numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    # remove numbers
    text = re.sub(r"\d+", " ", text)
    
    # make everything lowercase
    text = text.lower()

    # tokenize
    words = text.split()

    if stopwords:
        words = [w for w in words if w not in stopwords and len(w) > 2]

    return " ".join(words)

# %%
# ---------------------------------------------------------
# EXTRACT PARAGRAPHS FROM PDF
# ---------------------------------------------------------

def extract_paragraphs(pdf_path, skip_length=10):

    extractor = PDFExtractor()
    result = extractor.extract(pdf_path)

    paragraphs = [clean_text(seg["paragraph"], stopwords) for seg in result["segments"] if len(seg["paragraph"].split()) > skip_length]
    speakers = [seg["speaker"] for seg in result["segments"]]

    return paragraphs, speakers

# %%
# ---------------------------------------------------------
# VALIDATE DOCUMENT
# ---------------------------------------------------------

def validate(text):

    validator = DocumentValidator(vocab_path="../data/vocabulary/parliament_vocab.txt")
    results = validator.validate_document(text)

    return results

# %%
# ---------------------------------------------------------
# VOCAB BASED CLASSIFICATION
# ---------------------------------------------------------

def classify_vocab(paragraph, ministry_vocab):

    words = paragraph.lower().split()

    scores = {}

    for ministry, vocab in ministry_vocab.items():

        count = 0

        for term in vocab:
            if term.lower() in paragraph.lower():
                count += 1

        scores[ministry] = count

    total = sum(scores.values()) + 1e-9

    probs = {k: v / total for k, v in scores.items()}

    return probs


# ---------------------------------------------------------
# EMBEDDING BASED CLASSIFICATION
# ---------------------------------------------------------

def classify_embedding(paragraph, model, ministry_embeddings):

    p_emb = model.encode(paragraph)

    scores = {}

    for ministry, m_emb in ministry_embeddings.items():

        sim = cosine_similarity(
            p_emb.reshape(1, -1),
            m_emb.reshape(1, -1)
        )[0][0]

        scores[ministry] = float(sim)

    # softmax normalization
    exp_scores = np.exp(list(scores.values()))
    probs = exp_scores / np.sum(exp_scores)

    return dict(zip(scores.keys(), probs))

# %%
# ---------------------------------------------------------
# MAIN PIPELINE
# ---------------------------------------------------------

def run_pipeline(pdf_path):

    print(f"Processing: {pdf_path}")
    print("-" * 50)

    paragraphs, speaker = extract_paragraphs(pdf_path, skip_length=10)

    full_text = "\n\n".join(paragraphs)

    validation = validate(full_text)

    print("VALIDATION RESULTS:")
    print(json.dumps(validation, indent=4))

    if not validation["is_valid"]:
        print("Document failed validation")
        return

    print("\nLoading ministry vocab...")
    ministry_vocab = load_vocab()

    print("Loading ministry embeddings...")
    ministry_embeddings = load_embeddings()

    model = SentenceTransformer("all-MiniLM-L6-v2", cache_folder="../models")

    print("\nClassifying paragraphs...\n")

    results = []

    for i, para in enumerate(paragraphs):

        vocab_probs = classify_vocab(para, ministry_vocab)

        embed_probs = classify_embedding(
            para,
            model,
            ministry_embeddings
        )

        results.append({
            "paragraph_id": i,
            "paragraph": para,
            "speaker": speaker[i],
            "vocab_distribution": vocab_probs,
            "embedding_distribution": embed_probs
        })

        print("=" * 80)
        print(f"Paragraph {i}")
        # print(para[:200])

        print("\nTop vocab ministry:")
        print(sorted(vocab_probs.items(), key=lambda x: x[1], reverse=True)[:3])

        print("\nTop embedding ministry:")
        print(sorted(embed_probs.items(), key=lambda x: x[1], reverse=True)[:3])

    return results

# %%
# ---------------------------------------------------------
# RUN
# ---------------------------------------------------------

# if __name__ == "__main__":

file_name = "test.pdf"
file_path = f"../data/uploads/{file_name}"

results = run_pipeline(file_path)
# Out:
# Processing: ../data/uploads/test.pdf
# --------------------------------------------------
# VALIDATION RESULTS:905
# {
#     "is_valid": true,
#     "is_english": true,
#     "validation_errors": [],
#     "vocab_size": 116,
#     "required_vocab_matches": 5,
#     "parliament_confidence": 0.06896551724137931,
#     "matched_vocab_terms": [
#         "act",
#         "budget",
#         "gazette",
#         "government",
#         "half",
#         "motion",
#         "schedule",
#         "speaker"
#     ]
# }
#
# Loading ministry vocab...
# Loading ministry embeddings...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Classifying paragraphs...
#
# ================================================================================
# Paragraph 0
#
# Top vocab ministry:
# [('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.14285714285034012), ('Ministry_of_Parliamentary_Affairs_MPA_', 0.0952380952335601), ('Ministry_of_Law_and_Justice_MoLJ_', 0.04761904761678005)]
#
# Top embedding ministry:
# [('Ministry_of_Parliamentary_Affairs_MPA_', np.float64(0.023493686586233367)), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.02129882390786567)), ('Ministry_of_Cooperation_MoC_', np.float64(0.021174237294473427))]
# ================================================================================
# Paragraph 1
#
# Top vocab ministry:
# [('Ministry_of_Coal_MoC_', 0.22222222219753085), ('Ministry_of_AYUSH_MoA_', 0.11111111109876542), ('Ministry_of_Textiles_MoT_', 0.11111111109876542)]
#
# Top embedding ministry:
# [('Ministry_of_Parliamentary_Affairs_MPA_', np.float64(0.021888582835750486)), ('Ministry_of_Information_and_Broadcasting_MIB_', np.float64(0.020762308452740536)), ('Ministry_of_Finance_MoF_', np.float64(0.02075483966978072))]
# ================================================================================
# Paragraph 2
#
# Top vocab ministry:
# [('Ministry_of_Law_and_Justice_MoLJ_', 0.1428571428367347), ('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.1428571428367347), ('Ministry_of_Women_and_Child_Development_MoWCD_', 0.1428571428367347)]
#
# Top embedding ministry:
# [('Ministry_of_External_Affairs_MEA_', np.float64(0.021740200056216536)), ('Ministry_of_Culture', np.float64(0.020725738752471728)), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.020648351444825554))]
# ================================================================================
# Paragraph 3
#
# Top vocab ministry:
# [('Ministry_of_Planning_MoP_', 0.08823529411505192), ('Ministry_of_Textiles_MoT_', 0.05882352941003461), ('Ministry_of_Culture', 0.05882352941003461)]
#
# Top embedding ministry:
# [('Ministry_of_Rural_Development_MoRD_', np.float64(0.021719606207392946)), ('Ministry_of_Finance_MoF_', np.float64(0.021388206316330923)), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', np.float64(0.02094873939987344))]
# ================================================================================
# Paragraph 4
#
# Top vocab ministry:
# [('Ministry_of_External_Affairs_MEA_', 0.22222222220987653), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', 0.11111111110493826), ('Ministry_of_Parliamentary_Affairs_MPA_', 0.11111111110493826)]
#
# Top embedding ministry:
# [('Ministry_of_Tourism_MoT_', np.float64(0.023567156510735276)), ('Ministry_of_External_Affairs_MEA_', np.float64(0.021590123954788935)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.02128829685160316))]
# ================================================================================
# Paragraph 5
#
# Top vocab ministry:
# [('Ministry_of_Planning_MoP_', 0.06666666666603174), ('Ministry_of_Women_and_Child_Development_MoWCD_', 0.057142857142312924), ('Ministry_of_Rural_Development_MoRD_', 0.047619047618594104)]
#
# Top embedding ministry:
# [('Ministry_of_External_Affairs_MEA_', np.float64(0.021525401885868916)), ('Ministry_of_Planning_MoP_', np.float64(0.02110439013582572)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.02079175542436054))]
# ================================================================================
# Paragraph 6
#
# Top vocab ministry:
# [('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.044999999999775005), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', 0.0399999999998), ('Ministry_of_Textiles_MoT_', 0.034999999999825004)]
#
# Top embedding ministry:
# [('Ministry_of_Rural_Development_MoRD_', np.float64(0.023354911209003883)), ('Ministry_of_Youth_Affairs_and_Sports_MoYAS_', np.float64(0.02132788919561514)), ('Ministry_of_Minority_Affairs_MoMA_', np.float64(0.021313319077743694))]
# ================================================================================
# Paragraph 7
#
# Top vocab ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.07894736841897508), ('Ministry_of_Heavy_Industries_MoHI_', 0.05263157894598339), ('Ministry_of_Petroleum_and_Natural_Gas_MoPNG_', 0.05263157894598339)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.022199434480934085)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.022043593555977525)), ('Ministry_of_Coal_MoC_', np.float64(0.02173363978765176))]
# ================================================================================
# Paragraph 8
#
# Top vocab ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.2499999999375), ('Ministry_of_Culture', 0.2499999999375), ('Ministry_of_Tourism_MoT_', 0.2499999999375)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.026882197143228048)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.02397934038629503)), ('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', np.float64(0.02320221540413458))]
# ================================================================================
# Paragraph 9
#
# Top vocab ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', 0.06040268456335301), ('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', 0.0536912751674249), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.046979865771496786)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.02367458821583336)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.02286345735745361)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.021578838730057878))]
# ================================================================================
# Paragraph 10
#
# Top vocab ministry:
# [('Ministry_of_Rural_Development_MoRD_', 0.0781249999987793), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.04687499999926758), ('Ministry_of_Tourism_MoT_', 0.04687499999926758)]
#
# Top embedding ministry:
# [('Ministry_of_Rural_Development_MoRD_', np.float64(0.023941878766424396)), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.023020642753628574)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.021547809568503277))]
# ================================================================================
# Paragraph 11
#
# Top vocab ministry:
# [('Ministry_of_Food_Processing_Industries_MoFPI_', 0.09090909090495868), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', 0.09090909090495868), ('Ministry_of_Cooperation_MoC_', 0.09090909090495868)]
#
# Top embedding ministry:
# [('Ministry_of_Women_and_Child_Development_MoWCD_', np.float64(0.0241337686436116)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.023904872058118417)), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.023503921126590752))]
# ================================================================================
# Paragraph 12
#
# Top vocab ministry:
# [('Ministry_of_Commerce_and_Industry_MoCI_', 0.06122448979466889), ('Ministry_of_Finance_MoF_', 0.06122448979466889), ('Ministry_of_AYUSH_MoA_', 0.04081632652977926)]
#
# Top embedding ministry:
# [('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', np.float64(0.021747875158305657)), ('Ministry_of_Finance_MoF_', np.float64(0.021579833561957692)), ('Ministry_of_Cooperation_MoC_', np.float64(0.02147987404578863))]
# ================================================================================
# Paragraph 13
#
# Top vocab ministry:
# [('Ministry_of_Food_Processing_Industries_MoFPI_', 0.12499999999609376), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', 0.12499999999609376), ('Ministry_of_Cooperation_MoC_', 0.09374999999707033)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.02391894148490558)), ('Ministry_of_AYUSH_MoA_', np.float64(0.023528794059886192)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.023235855584799407))]
# ================================================================================
# Paragraph 14
#
# Top vocab ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', 0.09803921568435219), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.07843137254748174), ('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.07843137254748174)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.025013561271404014)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.02386955476170206)), ('Ministry_of_Chemicals_and_Fertilizers_MoCF_', np.float64(0.02255583264872709))]
# ================================================================================
# Paragraph 15
#
# Top vocab ministry:
# [('Ministry_of_Textiles_MoT_', 0.08333333333101853), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.08333333333101853), ('Ministry_of_Home_Affairs_MHA_', 0.08333333333101853)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.023169972937244872)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.022102901718990403)), ('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', np.float64(0.021304745982048))]
# ================================================================================
# Paragraph 16
#
# Top vocab ministry:
# [('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.07692307692110455), ('Ministry_of_Education_MoE_', 0.07692307692110455), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', 0.07692307692110455)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.02457270960470026)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.023558302573071174)), ('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', np.float64(0.0220029011869537))]
# ================================================================================
# Paragraph 17
#
# Top vocab ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', 0.09230769230627218), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.07692307692189349), ('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.07692307692189349)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.024346917303165606)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.023405521545888718)), ('Ministry_of_Cooperation_MoC_', np.float64(0.02338631049087286))]
# ================================================================================
# Paragraph 18
#
# Top vocab ministry:
# [('Ministry_of_Food_Processing_Industries_MoFPI_', 0.07575757575642791), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.06060606060514233), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', 0.06060606060514233)]
#
# Top embedding ministry:
# [('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.021872764358563328)), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.021756206992770637)), ('Ministry_of_Tribal_Affairs_MoTA_', np.float64(0.02138838135412932))]
# ================================================================================
# Paragraph 19
#
# Top vocab ministry:
# [('Ministry_of_Petroleum_and_Natural_Gas_MoPNG_', 0.07894736841897508), ('Ministry_of_Science_and_Technology_MST_', 0.07894736841897508), ('Ministry_of_Tourism_MoT_', 0.05263157894598339)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.02507351577285997)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.02219262733083635)), ('Ministry_of_Chemicals_and_Fertilizers_MoCF_', np.float64(0.021501657951354843))]
# ================================================================================
# Paragraph 20
#
# Top vocab ministry:
# [('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', 0.1323529411745242), ('Ministry_of_Coal_MoC_', 0.07352941176362457), ('Ministry_of_Mines_MoM_', 0.058823529410899654)]
#
# Top embedding ministry:
# [('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', np.float64(0.024810251971453492)), ('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', np.float64(0.023372641056091693)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.022012334758368904))]
# ================================================================================
# Paragraph 21
#
# Top vocab ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', 0.08695652173787019), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.043478260868935095), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.043478260868935095)]
#
# Top embedding ministry:
# [('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.02340646566786777)), ('Ministry_of_Textiles_MoT_', np.float64(0.022502222233454352)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.021612558087721185))]
# ================================================================================
# Paragraph 22
#
# Top vocab ministry:
# [('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', 0.13793103448038052), ('Ministry_of_Cooperation_MoC_', 0.12068965517033295), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', 0.08620689655023782)]
#
# Top embedding ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.021369605166409116)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.02121252455106213)), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.021137154291935217))]
# ================================================================================
# Paragraph 23
#
# Top vocab ministry:
# [('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', 0.15151515151056016), ('Ministry_of_Railways_MoR_', 0.0909090909063361), ('Ministry_of_Textiles_MoT_', 0.06060606060422406)]
#
# Top embedding ministry:
# [('Ministry_of_Chemicals_and_Fertilizers_MoCF_', np.float64(0.022479996382461474)), ('Ministry_of_New_and_Renewable_Energy_MNRE_', np.float64(0.022098116008507453)), ('Ministry_of_Tribal_Affairs_MoTA_', np.float64(0.021643680259526843))]
# ================================================================================
# Paragraph 24
#
# Top vocab ministry:
# [('Ministry_of_Communications_MoC_', 0.12499999999479167), ('Ministry_of_Culture', 0.0833333333298611), ('Ministry_of_Planning_MoP_', 0.0833333333298611)]
#
# Top embedding ministry:
# [('Ministry_of_Rural_Development_MoRD_', np.float64(0.021889817718158937)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.0214483688144801)), ('Ministry_of_Communications_MoC_', np.float64(0.021356845062218147))]
# ================================================================================
# Paragraph 25
#
# Top vocab ministry:
# [('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.09999999999), ('Ministry_of_Women_and_Child_Development_MoWCD_', 0.09999999999), ('Ministry_of_Railways_MoR_', 0.09999999999)]
#
# Top embedding ministry:
# [('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.02148312047314901)), ('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', np.float64(0.02134598631405287)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.021318499683927374))]
# ================================================================================
# Paragraph 26
#
# Top vocab ministry:
# [('Ministry_of_Rural_Development_MoRD_', 0.11428571428244899), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.057142857141224496), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', 0.057142857141224496)]
#
# Top embedding ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.023311204090321166)), ('Ministry_of_Women_and_Child_Development_MoWCD_', np.float64(0.021904913639104857)), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', np.float64(0.021550964462053974))]
# ================================================================================
# Paragraph 27
#
# Top vocab ministry:
# [('Ministry_of_Food_Processing_Industries_MoFPI_', 0.16666666665277777), ('Ministry_of_Women_and_Child_Development_MoWCD_', 0.16666666665277777), ('Ministry_of_External_Affairs_MEA_', 0.08333333332638888)]
#
# Top embedding ministry:
# [('Ministry_of_Cooperation_MoC_', np.float64(0.02571073317017202)), ('Ministry_of_Corporate_Affairs_MCA_', np.float64(0.02228609207040945)), ('Ministry_of_Communications_MoC_', np.float64(0.02136026712052787))]
# ================================================================================
# Paragraph 28
#
# Top vocab ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.1764705882249135), ('Ministry_of_Textiles_MoT_', 0.117647058816609), ('Ministry_of_Home_Affairs_MHA_', 0.117647058816609)]
#
# Top embedding ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.02502933425028)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.02177719482761548)), ('Ministry_of_Electronics_and_Information_Technology_MeitY_', np.float64(0.021134964475315134))]
# ================================================================================
# Paragraph 29
#
# Top vocab ministry:
# [('Ministry_of_Textiles_MoT_', 0.0689655172405866), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.0459770114937244), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.0459770114937244)]
#
# Top embedding ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.023574105611246968)), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.021693685169799193)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.021593436308288427))]
# ================================================================================
# Paragraph 30
#
# Top vocab ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.08988764044842823), ('Ministry_of_Textiles_MoT_', 0.056179775280267644), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.044943820224214115)]
#
# Top embedding ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.02327714127839752)), ('Ministry_of_Corporate_Affairs_MCA_', np.float64(0.021406108537996592)), ('Ministry_of_Finance_MoF_', np.float64(0.020985583840457317))]
# ================================================================================
# Paragraph 31
#
# Top vocab ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.12499999999687501), ('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', 0.07499999999812501), ('Ministry_of_Cooperation_MoC_', 0.07499999999812501)]
#
# Top embedding ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.024692039319488882)), ('Ministry_of_Corporate_Affairs_MCA_', np.float64(0.021903799862514787)), ('Ministry_of_Electronics_and_Information_Technology_MeitY_', np.float64(0.02185536586104158))]
# ================================================================================
# Paragraph 32
#
# Top vocab ministry:
# [('Ministry_of_Tourism_MoT_', 0.0645161290301769), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.0645161290301769), ('Ministry_of_Mines_MoM_', 0.0645161290301769)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.021411277629495566)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.021316633298733855)), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', np.float64(0.02096387141864496))]
# ================================================================================
# Paragraph 33
#
# Top vocab ministry:
# [('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.057142857142040815), ('Ministry_of_Panchayati_Raj_MoPR_', 0.057142857142040815), ('Ministry_of_Cooperation_MoC_', 0.057142857142040815)]
#
# Top embedding ministry:
# [('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.0224070429675995)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.02219404620456886)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.022047090249101172))]
# ================================================================================
# Paragraph 34
#
# Top vocab ministry:
# [('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.11764705882006922), ('Ministry_of_Planning_MoP_', 0.08823529411505192), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.05882352941003461)]
#
# Top embedding ministry:
# [('Ministry_of_Labour_and_Employment_MoLE_', np.float64(0.02247162537564143)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.021476424138471673)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.02143136386020831))]
# ================================================================================
# Paragraph 35
#
# Top vocab ministry:
# [('Ministry_of_Textiles_MoT_', 0.07352941176362457), ('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', 0.07352941176362457), ('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', 0.058823529410899654)]
#
# Top embedding ministry:
# [('Ministry_of_Textiles_MoT_', np.float64(0.024415950896638644)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.022098092859962944)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.021857862295554448))]
# ================================================================================
# Paragraph 36
#
# Top vocab ministry:
# [('Ministry_of_Textiles_MoT_', 0.05555555555401235), ('Ministry_of_Tourism_MoT_', 0.05555555555401235), ('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.05555555555401235)]
#
# Top embedding ministry:
# [('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.021646818978948094)), ('Ministry_of_Youth_Affairs_and_Sports_MoYAS_', np.float64(0.021169366952510604)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.02104799515420782))]
# ================================================================================
# Paragraph 37
#
# Top vocab ministry:
# [('Ministry_of_Food_Processing_Industries_MoFPI_', 0.06363636363578512), ('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.06363636363578512), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', 0.06363636363578512)]
#
# Top embedding ministry:
# [('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.024329520467158774)), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.02317435148575052)), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.022364881589087445))]
# ================================================================================
# Paragraph 38
#
# Top vocab ministry:
# [('Ministry_of_Planning_MoP_', 0.09677419354526536), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.0645161290301769), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', 0.0645161290301769)]
#
# Top embedding ministry:
# [('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.0216809006215647)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.021474674782574487)), ('Ministry_of_Planning_MoP_', np.float64(0.021340688336254573))]
# ================================================================================
# Paragraph 39
#
# Top vocab ministry:
# [('Ministry_of_New_and_Renewable_Energy_MNRE_', 0.11475409835877452), ('Ministry_of_Heavy_Industries_MoHI_', 0.09836065573609246), ('Ministry_of_Power_MoP_', 0.06557377049072831)]
#
# Top embedding ministry:
# [('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.024447399862690008)), ('Ministry_of_New_and_Renewable_Energy_MNRE_', np.float64(0.023557284558364422)), ('Ministry_of_Power_MoP_', np.float64(0.022195483908346195))]
# ================================================================================
# Paragraph 40
#
# Top vocab ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.3333333332222222), ('Ministry_of_Tourism_MoT_', 0.3333333332222222), ('Ministry_of_Coal_MoC_', 0.3333333332222222)]
#
# Top embedding ministry:
# [('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.021878437740496887)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.021220066015138966)), ('Ministry_of_Science_and_Technology_MST_', np.float64(0.021210652092815994))]
# ================================================================================
# Paragraph 41
#
# Top vocab ministry:
# [('Ministry_of_Education_MoE_', 0.10526315789289013), ('Ministry_of_Women_and_Child_Development_MoWCD_', 0.08771929824407511), ('Ministry_of_Law_and_Justice_MoLJ_', 0.052631578946445066)]
#
# Top embedding ministry:
# [('Ministry_of_Women_and_Child_Development_MoWCD_', np.float64(0.024038493653043027)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.022199266401774782)), ('Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_', np.float64(0.02173931771188148))]
# ================================================================================
# Paragraph 42
#
# Top vocab ministry:
# [('Ministry_of_Youth_Affairs_and_Sports_MoYAS_', 0.14285714284693876), ('Ministry_of_Minority_Affairs_MoMA_', 0.14285714284693876), ('Ministry_of_Education_MoE_', 0.14285714284693876)]
#
# Top embedding ministry:
# [('Ministry_of_Science_and_Technology_MST_', np.float64(0.024925309707604825)), ('Ministry_of_Education_MoE_', np.float64(0.02250432051528297)), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.021722875768767545))]
# ================================================================================
# Paragraph 43
#
# Top vocab ministry:
# [('Ministry_of_Minority_Affairs_MoMA_', 0.08823529411505192), ('Ministry_of_Education_MoE_', 0.08823529411505192), ('Ministry_of_Science_and_Technology_MST_', 0.08823529411505192)]
#
# Top embedding ministry:
# [('Ministry_of_Communications_MoC_', np.float64(0.023047254940969982)), ('Ministry_of_Education_MoE_', np.float64(0.02298498737839701)), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.021485814639842428))]
# ================================================================================
# Paragraph 44
#
# Top vocab ministry:
# [('Ministry_of_Education_MoE_', 0.12499999999609376), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', 0.06249999999804688), ('Ministry_of_Women_and_Child_Development_MoWCD_', 0.06249999999804688)]
#
# Top embedding ministry:
# [('Ministry_of_Education_MoE_', np.float64(0.022391048407494316)), ('Ministry_of_Minority_Affairs_MoMA_', np.float64(0.022214970615862455)), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', np.float64(0.02148488872810848))]
# ================================================================================
# Paragraph 45
#
# Top vocab ministry:
# [('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.06779661016834243), ('Ministry_of_Home_Affairs_MHA_', 0.06779661016834243), ('Ministry_of_Youth_Affairs_and_Sports_MoYAS_', 0.06779661016834243)]
#
# Top embedding ministry:
# [('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.026197105829630474)), ('Ministry_of_Education_MoE_', np.float64(0.022930306690754656)), ('Ministry_of_Youth_Affairs_and_Sports_MoYAS_', np.float64(0.02259818613308112))]
# ================================================================================
# Paragraph 46
#
# Top vocab ministry:
# [('Ministry_of_Food_Processing_Industries_MoFPI_', 0.07547169811178356), ('Ministry_of_Petroleum_and_Natural_Gas_MoPNG_', 0.07547169811178356), ('Ministry_of_Steel_MoS_', 0.07547169811178356)]
#
# Top embedding ministry:
# [('Ministry_of_Education_MoE_', np.float64(0.02327836359461412)), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.02230188419137423)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.02048769597426072))]
# ================================================================================
# Paragraph 47
#
# Top vocab ministry:
# [('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', 0.07692307692110455), ('Ministry_of_Heavy_Industries_MoHI_', 0.07692307692110455), ('Ministry_of_Electronics_and_Information_Technology_MeitY_', 0.07692307692110455)]
#
# Top embedding ministry:
# [('Ministry_of_Education_MoE_', np.float64(0.022587005727934036)), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.022069218408809363)), ('Ministry_of_Health_and_Family_Welfare_MoHFW_', np.float64(0.02172310978770301))]
# ================================================================================
# Paragraph 48
#
# Top vocab ministry:
# [('Ministry_of_Health_and_Family_Welfare_MoHFW_', 0.07499999999812501), ('Ministry_of_Power_MoP_', 0.04999999999875), ('Ministry_of_AYUSH_MoA_', 0.04999999999875)]
#
# Top embedding ministry:
# [('Ministry_of_Education_MoE_', np.float64(0.023022483365029506)), ('Ministry_of_Health_and_Family_Welfare_MoHFW_', np.float64(0.022696936273979357)), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.02157958127999623))]
# ================================================================================
# Paragraph 49
#
# Top vocab ministry:
# [('Ministry_of_AYUSH_MoA_', 0.157894736833795), ('Ministry_of_Health_and_Family_Welfare_MoHFW_', 0.10526315788919667), ('Ministry_of_Education_MoE_', 0.10526315788919667)]
#
# Top embedding ministry:
# [('Ministry_of_Health_and_Family_Welfare_MoHFW_', np.float64(0.022970746765949707)), ('Ministry_of_Women_and_Child_Development_MoWCD_', np.float64(0.02239954284545924)), ('Ministry_of_AYUSH_MoA_', np.float64(0.021322824904849474))]
# ================================================================================
# Paragraph 50
#
# Top vocab ministry:
# [('Ministry_of_Rural_Development_MoRD_', 0.07594936708764621), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', 0.06329113923970517), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', 0.05063291139176414)]
#
# Top embedding ministry:
# [('Ministry_of_Rural_Development_MoRD_', np.float64(0.02398619062216437)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.023800646075801533)), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', np.float64(0.022982889189645514))]
# ================================================================================
# Paragraph 51
#
# Top vocab ministry:
# [('Ministry_of_Panchayati_Raj_MoPR_', 0.08620689655023782), ('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', 0.06896551724019026), ('Ministry_of_Health_and_Family_Welfare_MoHFW_', 0.05172413793014269)]
#
# Top embedding ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.02231868939459832)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.022086946083660547)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.021886616206300984))]
# ================================================================================
# Paragraph 52
#
# Top vocab ministry:
# [('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.0689655172405866), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', 0.0574712643671555), ('Ministry_of_Women_and_Child_Development_MoWCD_', 0.0574712643671555)]
#
# Top embedding ministry:
# [('Ministry_of_Labour_and_Employment_MoLE_', np.float64(0.024143636622037546)), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', np.float64(0.022374213369270493)), ('Ministry_of_Electronics_and_Information_Technology_MeitY_', np.float64(0.022020894582671778))]
# ================================================================================
# Paragraph 53
#
# Top vocab ministry:
# [('Ministry_of_External_Affairs_MEA_', 0.06521739130293006), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', 0.06521739130293006), ('Ministry_of_Tourism_MoT_', 0.04347826086862004)]
#
# Top embedding ministry:
# [('Ministry_of_Planning_MoP_', np.float64(0.021613325636134103)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.02157872810617378)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.02154013396851963))]
# ================================================================================
# Paragraph 54
#
# Top vocab ministry:
# [('Ministry_of_Railways_MoR_', 0.10344827585850179), ('Ministry_of_Finance_MoF_', 0.10344827585850179), ('Ministry_of_Heavy_Industries_MoHI_', 0.06896551723900118)]
#
# Top embedding ministry:
# [('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.0220835924898944)), ('Ministry_of_Finance_MoF_', np.float64(0.021933293759442737)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.021646481098158803))]
# ================================================================================
# Paragraph 55
#
# Top vocab ministry:
# [('Ministry_of_Road_Transport_and_Highways_MoRTH_', 0.1111111111080247), ('Ministry_of_Tourism_MoT_', 0.08333333333101853), ('Ministry_of_Steel_MoS_', 0.08333333333101853)]
#
# Top embedding ministry:
# [('Ministry_of_Planning_MoP_', np.float64(0.022298427801020895)), ('Ministry_of_Finance_MoF_', np.float64(0.02207382013070461)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.021652613437372136))]
# ================================================================================
# Paragraph 56
#
# Top vocab ministry:
# [('Ministry_of_Petroleum_and_Natural_Gas_MoPNG_', 0.1086956521715501), ('Ministry_of_Jal_Shakti_MoJS_', 0.08695652173724008), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.06521739130293006)]
#
# Top embedding ministry:
# [('Ministry_of_Jal_Shakti_MoJS_', np.float64(0.023917963978288367)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.021864254545903843)), ('Ministry_of_New_and_Renewable_Energy_MNRE_', np.float64(0.02068949142136154))]
# ================================================================================
# Paragraph 57
#
# Top vocab ministry:
# [('Ministry_of_Culture', 0.07692307692110455), ('Ministry_of_Health_and_Family_Welfare_MoHFW_', 0.07692307692110455), ('Ministry_of_Finance_MoF_', 0.07692307692110455)]
#
# Top embedding ministry:
# [('Ministry_of_Jal_Shakti_MoJS_', np.float64(0.025452914417974815)), ('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', np.float64(0.021349431649824297)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.020855265405356597))]
# ================================================================================
# Paragraph 58
#
# Top vocab ministry:
# [('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', 0.0799999999968), ('Ministry_of_Petroleum_and_Natural_Gas_MoPNG_', 0.0799999999968), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', 0.0799999999968)]
#
# Top embedding ministry:
# [('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.02600201557247513)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.023469106776805353)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.022071380613804675))]
# ================================================================================
# Paragraph 59
#
# Top vocab ministry:
# [('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', 0.10344827585850179), ('Ministry_of_Science_and_Technology_MST_', 0.10344827585850179), ('Ministry_of_Tourism_MoT_', 0.06896551723900118)]
#
# Top embedding ministry:
# [('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.024298105352171324)), ('Ministry_of_Jal_Shakti_MoJS_', np.float64(0.0235557398115681)), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', np.float64(0.021446562742631715))]
# ================================================================================
# Paragraph 60
#
# Top vocab ministry:
# [('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.14285714285034012), ('Ministry_of_Coal_MoC_', 0.0952380952335601), ('Ministry_of_AYUSH_MoA_', 0.04761904761678005)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.022330321122444933)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.021162670262142528)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.021106860118634954))]
# ================================================================================
# Paragraph 61
#
# Top vocab ministry:
# [('Ministry_of_Power_MoP_', 0.08695652173724008), ('Ministry_of_Petroleum_and_Natural_Gas_MoPNG_', 0.08695652173724008), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.06521739130293006)]
#
# Top embedding ministry:
# [('Ministry_of_Power_MoP_', np.float64(0.02577332590972945)), ('Ministry_of_New_and_Renewable_Energy_MNRE_', np.float64(0.02162196329778324)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.021620550250516433))]
# ================================================================================
# Paragraph 62
#
# Top vocab ministry:
# [('Ministry_of_Power_MoP_', 0.07017543859526008), ('Ministry_of_Petroleum_and_Natural_Gas_MoPNG_', 0.052631578946445066), ('Ministry_of_Rural_Development_MoRD_', 0.052631578946445066)]
#
# Top embedding ministry:
# [('Ministry_of_Power_MoP_', np.float64(0.02211063833411522)), ('Ministry_of_New_and_Renewable_Energy_MNRE_', np.float64(0.021304003967098008)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.020841556351072918))]
# ================================================================================
# Paragraph 63
#
# Top vocab ministry:
# [('Ministry_of_Power_MoP_', 0.07499999999812501), ('Ministry_of_Defence_MoD_', 0.07499999999812501), ('Ministry_of_Heavy_Industries_MoHI_', 0.04999999999875)]
#
# Top embedding ministry:
# [('Ministry_of_Power_MoP_', np.float64(0.022861788563039366)), ('Ministry_of_New_and_Renewable_Energy_MNRE_', np.float64(0.02141049752451579)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.021286388934508273))]
# ================================================================================
# Paragraph 64
#
# Top vocab ministry:
# [('Ministry_of_Tourism_MoT_', 0.05555555555401235), ('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', 0.05555555555401235), ('Ministry_of_Science_and_Technology_MST_', 0.05555555555401235)]
#
# Top embedding ministry:
# [('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', np.float64(0.02497527814861604)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.021378535094445383)), ('Ministry_of_Finance_MoF_', np.float64(0.021150678947661938))]
# ================================================================================
# Paragraph 65
#
# Top vocab ministry:
# [('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', 0.11111111110493826), ('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', 0.11111111110493826), ('Ministry_of_Culture', 0.05555555555246913)]
#
# Top embedding ministry:
# [('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', np.float64(0.02469423162127387)), ('Ministry_of_Defence_MoD_', np.float64(0.021836109470701845)), ('Ministry_of_Railways_MoR_', np.float64(0.021561860245848802))]
# ================================================================================
# Paragraph 66
#
# Top vocab ministry:
# [('Ministry_of_Textiles_MoT_', 0.06521739130293006), ('Ministry_of_Petroleum_and_Natural_Gas_MoPNG_', 0.06521739130293006), ('Ministry_of_Steel_MoS_', 0.06521739130293006)]
#
# Top embedding ministry:
# [('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', np.float64(0.023989947850940503)), ('Ministry_of_Food_Processing_Industries_MoFPI_', np.float64(0.020806216656577205)), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.02073839146222606))]
# ================================================================================
# Paragraph 67
#
# Top vocab ministry:
# [('Ministry_of_Power_MoP_', 0.07692307692011835), ('Ministry_of_Petroleum_and_Natural_Gas_MoPNG_', 0.07692307692011835), ('Ministry_of_Youth_Affairs_and_Sports_MoYAS_', 0.07692307692011835)]
#
# Top embedding ministry:
# [('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', np.float64(0.026400693050879175)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.021333862904205185)), ('Ministry_of_Defence_MoD_', np.float64(0.02119471252923259))]
# ================================================================================
# Paragraph 68
#
# Top vocab ministry:
# [('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', 0.10256410256278764), ('Ministry_of_Road_Transport_and_Highways_MoRTH_', 0.07692307692209073), ('Ministry_of_Civil_Aviation_MoCA_', 0.06410256410174227)]
#
# Top embedding ministry:
# [('Ministry_of_Road_Transport_and_Highways_MoRTH_', np.float64(0.022611990384950768)), ('Ministry_of_Civil_Aviation_MoCA_', np.float64(0.022599331356237973)), ('Ministry_of_Railways_MoR_', np.float64(0.021911409178738236))]
# ================================================================================
# Paragraph 69
#
# Top vocab ministry:
# [('Ministry_of_Food_Processing_Industries_MoFPI_', 0.053571428570471945), ('Ministry_of_Railways_MoR_', 0.053571428570471945), ('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', 0.053571428570471945)]
#
# Top embedding ministry:
# [('Ministry_of_Civil_Aviation_MoCA_', np.float64(0.022104143462265358)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.02148187413391599)), ('Ministry_of_Railways_MoR_', np.float64(0.02113601996114196))]
# ================================================================================
# Paragraph 70
#
# Top vocab ministry:
# [('Ministry_of_Coal_MoC_', 0.10526315789196677), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', 0.05263157894598339), ('Ministry_of_Mines_MoM_', 0.05263157894598339)]
#
# Top embedding ministry:
# [('Ministry_of_Mines_MoM_', np.float64(0.02527768976535577)), ('Ministry_of_Coal_MoC_', np.float64(0.02481162729562974)), ('Ministry_of_Steel_MoS_', np.float64(0.021477237601240238))]
# ================================================================================
# Paragraph 71
#
# Top vocab ministry:
# [('Ministry_of_Coal_MoC_', 0.22222222219753085), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', 0.11111111109876542), ('Ministry_of_Tourism_MoT_', 0.11111111109876542)]
#
# Top embedding ministry:
# [('Ministry_of_Mines_MoM_', np.float64(0.026350194153541923)), ('Ministry_of_Coal_MoC_', np.float64(0.02368740404414935)), ('Ministry_of_Steel_MoS_', np.float64(0.023244881851649628))]
# ================================================================================
# Paragraph 72
#
# Top vocab ministry:
# [('Ministry_of_Women_and_Child_Development_MoWCD_', 0.07894736841897508), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.05263157894598339), ('Ministry_of_Home_Affairs_MHA_', 0.05263157894598339)]
#
# Top embedding ministry:
# [('Ministry_of_Rural_Development_MoRD_', np.float64(0.02257774286274854)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.022006092148865484)), ('Ministry_of_Minority_Affairs_MoMA_', np.float64(0.02178290282175905))]
# ================================================================================
# Paragraph 73
#
# Top vocab ministry:
# [('Ministry_of_Finance_MoF_', 0.18181818180165288), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.09090909090082644), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', 0.09090909090082644)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.0218455452959735)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.021804599250611525)), ('Ministry_of_Cooperation_MoC_', np.float64(0.02132063658264197))]
# ================================================================================
# Paragraph 74
#
# Top vocab ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.11111111109876542), ('Ministry_of_Heavy_Industries_MoHI_', 0.11111111109876542), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.11111111109876542)]
#
# Top embedding ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.02133464048491025)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.021326636352801073)), ('Ministry_of_Finance_MoF_', np.float64(0.021003197988700647))]
# ================================================================================
# Paragraph 75
#
# Top vocab ministry:
# [('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', 0.099999999995), ('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', 0.099999999995), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', 0.099999999995)]
#
# Top embedding ministry:
# [('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', np.float64(0.022822789069441504)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.021214022331599608)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.02111029521366465))]
# ================================================================================
# Paragraph 76
#
# Top vocab ministry:
# [('Ministry_of_Culture', 0.08333333333159723), ('Ministry_of_Tourism_MoT_', 0.062499999998697923), ('Ministry_of_Chemicals_and_Fertilizers_MoCF_', 0.062499999998697923)]
#
# Top embedding ministry:
# [('Ministry_of_Tourism_MoT_', np.float64(0.024771732935563767)), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', np.float64(0.021216933624292268)), ('Ministry_of_Housing_and_Urban_Affairs_MoHUA_', np.float64(0.02115151019092906))]
# ================================================================================
# Paragraph 77
#
# Top vocab ministry:
# [('Ministry_of_Rural_Development_MoRD_', 0.04918032786844934), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', 0.04918032786844934), ('Ministry_of_Science_and_Technology_MST_', 0.04918032786844934)]
#
# Top embedding ministry:
# [('Ministry_of_Tourism_MoT_', np.float64(0.02453291883216701)), ('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.022270610275075573)), ('Ministry_of_Youth_Affairs_and_Sports_MoYAS_', np.float64(0.020894257707440016))]
# ================================================================================
# Paragraph 78
#
# Top vocab ministry:
# [('Ministry_of_Tourism_MoT_', 0.08695652173534972), ('Ministry_of_Home_Affairs_MHA_', 0.08695652173534972), ('Ministry_of_Youth_Affairs_and_Sports_MoYAS_', 0.08695652173534972)]
#
# Top embedding ministry:
# [('Ministry_of_Tourism_MoT_', np.float64(0.024634714016520787)), ('Ministry_of_Culture', np.float64(0.02230754457008507)), ('Ministry_of_AYUSH_MoA_', np.float64(0.021315808124233185))]
# ================================================================================
# Paragraph 79
#
# Top vocab ministry:
# [('Ministry_of_Culture', 0.09999999999666667), ('Ministry_of_AYUSH_MoA_', 0.06666666666444444), ('Ministry_of_Tourism_MoT_', 0.06666666666444444)]
#
# Top embedding ministry:
# [('Ministry_of_Tourism_MoT_', np.float64(0.024614511264027337)), ('Ministry_of_AYUSH_MoA_', np.float64(0.022639850436101394)), ('Ministry_of_Health_and_Family_Welfare_MoHFW_', np.float64(0.022336309618171))]
# ================================================================================
# Paragraph 80
#
# Top vocab ministry:
# [('Ministry_of_Tourism_MoT_', 0.10344827585850179), ('Ministry_of_Planning_MoP_', 0.10344827585850179), ('Ministry_of_Steel_MoS_', 0.06896551723900118)]
#
# Top embedding ministry:
# [('Ministry_of_Planning_MoP_', np.float64(0.021671344228795044)), ('Ministry_of_Science_and_Technology_MST_', np.float64(0.02143361104287129)), ('Ministry_of_Development_of_North_Eastern_Region_MDoNER_', np.float64(0.02061081780346797))]
# ================================================================================
# Paragraph 81
#
# Top vocab ministry:
# [('Ministry_of_Mines_MoM_', 0.09756097560737657), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.04878048780368829), ('Ministry_of_Culture', 0.04878048780368829)]
#
# Top embedding ministry:
# ...
# ================================================================================
# Paragraph 153
#
# Top vocab ministry:
# [('Ministry_of_Commerce_and_Industry_MoCI_', 0.06779661016834243), ('Ministry_of_Corporate_Affairs_MCA_', 0.06779661016834243), ('Ministry_of_Law_and_Justice_MoLJ_', 0.05084745762625682)]
#
# Top embedding ministry:
# [('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.02215299970437623)), ('Ministry_of_Finance_MoF_', np.float64(0.022080997457417297)), ('Ministry_of_Railways_MoR_', np.float64(0.02153761419708839))]
# ================================================================================
# Paragraph 154
#
# Top vocab ministry:
# [('Ministry_of_Civil_Aviation_MoCA_', 0.08333333333101853), ('Ministry_of_Home_Affairs_MHA_', 0.05555555555401235), ('Ministry_of_Electronics_and_Information_Technology_MeitY_', 0.05555555555401235)]
#
# Top embedding ministry:
# [('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', np.float64(0.023352928980023602)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.02301010556086561)), ('Ministry_of_Finance_MoF_', np.float64(0.022413740786520576))]
# ================================================================================
# Paragraph 155
#
# Top vocab ministry:
# [('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.117647058816609), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.0588235294083045), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', 0.0588235294083045)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.022161201781811246)), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', np.float64(0.021969751739800293)), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.021141371907891577))]
# ================================================================================
# Paragraph 156
#
# Top vocab ministry:
# [('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.099999999995), ('Ministry_of_Commerce_and_Industry_MoCI_', 0.099999999995), ('Ministry_of_Communications_MoC_', 0.099999999995)]
#
# Top embedding ministry:
# [('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', np.float64(0.02175124641976877)), ('Ministry_of_Health_and_Family_Welfare_MoHFW_', np.float64(0.021314825570542307)), ('Ministry_of_Tribal_Affairs_MoTA_', np.float64(0.020839209374102913))]
# ================================================================================
# Paragraph 157
#
# Top vocab ministry:
# [('Ministry_of_Food_Processing_Industries_MoFPI_', 0.09374999999707033), ('Ministry_of_Women_and_Child_Development_MoWCD_', 0.09374999999707033), ('Ministry_of_Law_and_Justice_MoLJ_', 0.06249999999804688)]
#
# Top embedding ministry:
# [('Ministry_of_Information_and_Broadcasting_MIB_', np.float64(0.023261913540469182)), ('Ministry_of_Electronics_and_Information_Technology_MeitY_', np.float64(0.02300022172621023)), ('Ministry_of_Law_and_Justice_MoLJ_', np.float64(0.022671552796218214))]
# ================================================================================
# Paragraph 158
#
# Top vocab ministry:
# [('Ministry_of_Women_and_Child_Development_MoWCD_', 0.1599999999936), ('Ministry_of_Electronics_and_Information_Technology_MeitY_', 0.0799999999968), ('Ministry_of_Finance_MoF_', 0.0799999999968)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.022130216351364373)), ('Ministry_of_Law_and_Justice_MoLJ_', np.float64(0.021899099650113548)), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', np.float64(0.020758109802512963))]
# ================================================================================
# Paragraph 159
#
# Top vocab ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.19999999996), ('Ministry_of_Food_Processing_Industries_MoFPI_', 0.19999999996), ('Ministry_of_Rural_Development_MoRD_', 0.19999999996)]
#
# Top embedding ministry:
# [('Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_', np.float64(0.022058513373815522)), ('Ministry_of_Labour_and_Employment_MoLE_', np.float64(0.021971452657112117)), ('Ministry_of_Planning_MoP_', np.float64(0.02096867528803196))]
# ================================================================================
# Paragraph 160
#
# Top vocab ministry:
# [('Ministry_of_Heavy_Industries_MoHI_', 0.0781249999987793), ('Ministry_of_Electronics_and_Information_Technology_MeitY_', 0.0781249999987793), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.04687499999926758)]
#
# Top embedding ministry:
# [('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.02333085835959435)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.022137572623842198)), ('Ministry_of_Electronics_and_Information_Technology_MeitY_', np.float64(0.021913845674288827))]
# ================================================================================
# Paragraph 161
#
# Top vocab ministry:
# [('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', 0.07692307692110455), ('Ministry_of_Women_and_Child_Development_MoWCD_', 0.05128205128073636), ('Ministry_of_Home_Affairs_MHA_', 0.05128205128073636)]
#
# Top embedding ministry:
# [('Ministry_of_Ports_Shipping_and_Waterways_MoPSW_', np.float64(0.026044821362862763)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.022245601733058548)), ('Ministry_of_Finance_MoF_', np.float64(0.021343901223849295))]
# ================================================================================
# Paragraph 162
#
# Top vocab ministry:
# [('Ministry_of_Health_and_Family_Welfare_MoHFW_', 0.07692307692110455), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.05128205128073636), ('Ministry_of_Tourism_MoT_', 0.05128205128073636)]
#
# Top embedding ministry:
# [('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.021393024287882402)), ('Ministry_of_Corporate_Affairs_MCA_', np.float64(0.021279360517038135)), ('Ministry_of_Cooperation_MoC_', np.float64(0.020938680318033642))]
# ================================================================================
# Paragraph 163
#
# Top vocab ministry:
# [('Ministry_of_Power_MoP_', 0.04878048780368829), ('Ministry_of_Textiles_MoT_', 0.04878048780368829), ('Ministry_of_Heavy_Industries_MoHI_', 0.04878048780368829)]
#
# Top embedding ministry:
# [('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.020991126278508566)), ('Ministry_of_External_Affairs_MEA_', np.float64(0.020941835165085902)), ('Ministry_of_Finance_MoF_', np.float64(0.020798936699365993))]
# ================================================================================
# Paragraph 164
#
# Top vocab ministry:
# [('Ministry_of_Finance_MoF_', 0.13333333332444444), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.06666666666222222), ('Ministry_of_Heavy_Industries_MoHI_', 0.06666666666222222)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.022637701948249267)), ('Ministry_of_Commerce_and_Industry_MoCI_', np.float64(0.02106290486505162)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.02087868374663769))]
# ================================================================================
# Paragraph 165
#
# Top vocab ministry:
# [('Ministry_of_Finance_MoF_', 0.15384615383431952), ('Ministry_of_Power_MoP_', 0.07692307691715976), ('Ministry_of_Textiles_MoT_', 0.07692307691715976)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.0212552027667172)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.020999558454527945)), ('Ministry_of_Planning_MoP_', np.float64(0.02072596683456393))]
# ================================================================================
# Paragraph 166
#
# Top vocab ministry:
# [('Ministry_of_Parliamentary_Affairs_MPA_', 0.0793650793638196), ('Ministry_of_Home_Affairs_MHA_', 0.04761904761829176), ('Ministry_of_Railways_MoR_', 0.04761904761829176)]
#
# Top embedding ministry:
# [('Ministry_of_Rural_Development_MoRD_', np.float64(0.021413032789128997)), ('Ministry_of_Finance_MoF_', np.float64(0.021407308912842864)), ('Ministry_of_Heavy_Industries_MoHI_', np.float64(0.02122886150851796))]
# ================================================================================
# Paragraph 167
#
# Top vocab ministry:
# [('Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_', 0.0952380952335601), ('Ministry_of_Civil_Aviation_MoCA_', 0.0952380952335601), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.04761904761678005)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.021784067740971372)), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', np.float64(0.02148810657856609)), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.020694212078464252))]
# ================================================================================
# Paragraph 168
#
# Top vocab ministry:
# [('Ministry_of_Road_Transport_and_Highways_MoRTH_', 0.0909090909070248), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.0681818181802686), ('Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_', 0.0681818181802686)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.022231124891308695)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.021537022579874835)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.021300516982013268))]
# ================================================================================
# Paragraph 169
#
# Top vocab ministry:
# [('Ministry_of_Finance_MoF_', 0.1499999999925), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.099999999995), ('Ministry_of_Environment_Forest_and_Climate_Change_MoEFCC_', 0.099999999995)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.021783913941424215)), ('Ministry_of_Labour_and_Employment_MoLE_', np.float64(0.02101911013285746)), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', np.float64(0.02062570550769434))]
# ================================================================================
# Paragraph 170
#
# Top vocab ministry:
# [('Ministry_of_Finance_MoF_', 0.14285714285034012), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.0952380952335601), ('Ministry_of_Home_Affairs_MHA_', 0.0952380952335601)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.021781948689754586)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.021560036596826825)), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', np.float64(0.021502876960395184))]
# ================================================================================
# Paragraph 171
#
# Top vocab ministry:
# [('Ministry_of_Finance_MoF_', 0.09090909090743803), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.054545454544462815), ('Ministry_of_Home_Affairs_MHA_', 0.054545454544462815)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.0231024488558254)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.02082061074811817)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.020702716717633313))]
# ================================================================================
# Paragraph 172
#
# Top vocab ministry:
# [('Ministry_of_Finance_MoF_', 0.18181818180991735), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.09090909090495868), ('Ministry_of_Mines_MoM_', 0.09090909090495868)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.022972097587844038)), ('Ministry_of_Labour_and_Employment_MoLE_', np.float64(0.021935380893695792)), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.020906274416790632))]
# ================================================================================
# Paragraph 173
#
# Top vocab ministry:
# [('Ministry_of_Finance_MoF_', 0.157894736833795), ('Ministry_of_Steel_MoS_', 0.10526315788919667), ('Ministry_of_Coal_MoC_', 0.10526315788919667)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.02297725403430274)), ('Ministry_of_Rural_Development_MoRD_', np.float64(0.021302245726208622)), ('Ministry_of_Parliamentary_Affairs_MPA_', np.float64(0.02098537430749545))]
# ================================================================================
# Paragraph 174
#
# Top vocab ministry:
# [('Ministry_of_Power_MoP_', 0.0), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', 0.0), ('Ministry_of_AYUSH_MoA_', 0.0)]
#
# Top embedding ministry:
# [('Ministry_of_Parliamentary_Affairs_MPA_', np.float64(0.021270541924464315)), ('Ministry_of_Communications_MoC_', np.float64(0.020836812508321298)), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.020217585568022473))]
# ================================================================================
# Paragraph 175
#
# Top vocab ministry:
# [('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.07142857142687076), ('Ministry_of_Home_Affairs_MHA_', 0.07142857142687076), ('Ministry_of_Planning_MoP_', 0.07142857142687076)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.02319104871545977)), ('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', np.float64(0.021260390739665153)), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', np.float64(0.020788138349193234))]
# ================================================================================
# Paragraph 176
#
# Top vocab ministry:
# [('Ministry_of_Home_Affairs_MHA_', 0.3333333332222222), ('Ministry_of_Environment_Forest_and_Climate_Change_MoEFCC_', 0.3333333332222222), ('Ministry_of_Labour_and_Employment_MoLE_', 0.3333333332222222)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.023576027219332243)), ('Ministry_of_Corporate_Affairs_MCA_', np.float64(0.021539831062015822)), ('Ministry_of_Cooperation_MoC_', np.float64(0.02144033453984441))]
# ================================================================================
# Paragraph 177
#
# Top vocab ministry:
# [('Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_', 0.19999999996), ('Ministry_of_Law_and_Justice_MoLJ_', 0.19999999996), ('Ministry_of_Social_Justice_and_Empowerment_MoSJE_', 0.19999999996)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.023626981252014134)), ('Ministry_of_Corporate_Affairs_MCA_', np.float64(0.022008641376988755)), ('Ministry_of_Micro_Small_Medium_Enterprises_MoME_', np.float64(0.021288802575605503))]
# ================================================================================
# Paragraph 178
#
# Top vocab ministry:
# [('Ministry_of_Culture', 0.3333333332222222), ('Ministry_of_Health_and_Family_Welfare_MoHFW_', 0.3333333332222222), ('Ministry_of_Chemicals_and_Fertilizers_MoCF_', 0.3333333332222222)]
#
# Top embedding ministry:
# [('Ministry_of_Finance_MoF_', np.float64(0.022562550496055586)), ('Ministry_of_Corporate_Affairs_MCA_', np.float64(0.022212181674467747)), ('Ministry_of_Information_and_Broadcasting_MIB_', np.float64(0.020829121959172962))]
# ================================================================================
# Paragraph 179
#
# Top vocab ministry:
# [('Ministry_of_Textiles_MoT_', 0.124999999984375), ('Ministry_of_Tourism_MoT_', 0.124999999984375), ('Ministry_of_Youth_Affairs_and_Sports_MoYAS_', 0.124999999984375)]
#
# Top embedding ministry:
# [('Ministry_of_Corporate_Affairs_MCA_', np.float64(0.020871684523792663)), ('Ministry_of_Parliamentary_Affairs_MPA_', np.float64(0.020777758745059202)), ('Ministry_of_Law_and_Justice_MoLJ_', np.float64(0.02072099556409693))]
# ================================================================================
# Paragraph 180
#
# Top vocab ministry:
# [('Ministry_of_Law_and_Justice_MoLJ_', 0.136363636357438), ('Ministry_of_Statistics_and_Programme_Implementation_MoSPI_', 0.136363636357438), ('Ministry_of_Parliamentary_Affairs_MPA_', 0.136363636357438)]
#
# Top embedding ministry:
# [('Ministry_of_Parliamentary_Affairs_MPA_', np.float64(0.021811836832310357)), ('Ministry_of_Panchayati_Raj_MoPR_', np.float64(0.02146741641521573)), ('Ministry_of_Women_and_Child_Development_MoWCD_', np.float64(0.021194177632466664))]

# %%
len(results)
# Out:
# 181

# %%
# find for which ministries the vocab and embedding classifications match
matches = []
for res in results:
    vocab_top = max(res["vocab_distribution"], key=res["vocab_distribution"].get)
    embed_top = max(res["embedding_distribution"], key=res["embedding_distribution"].get)

    if vocab_top == embed_top:
        matches.append({
            "paragraph_id": res["paragraph_id"],
            "speaker": res["speaker"],
            "ministry": vocab_top,
            "paragraph_snippet": res["paragraph"]
        })
print("\nParagraphs where vocab and embedding classifications match:")
for match in matches:
    print(f"Paragraph {match['paragraph_id']} - Speaker: {match['speaker']} - Ministry: {match['ministry']}")
    print(f"Snippet: {match['paragraph_snippet']}")
    print("-" * 80)
# Out:
# Paragraphs where vocab and embedding classifications match:
# Paragraph 9 - Speaker: HON. SPEAKER - Ministry: Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_
# Snippet: prime dhandhaanya krishi yojana developing agri districts programme motivated success aspirational districts programme undertake prime dhandhaanya krishi yojana partnership states convergence existing schemes specialized measures programme cover districts low productivity moderate crop intensity belowaverage credit parameters aims enhance agricultural productivity adopt crop diversification sustainable agriculture practices augment postharvest storage panchayat block level improve irrigation facilities facilitate availability longterm shortterm credit programme likely help crore farmers
# --------------------------------------------------------------------------------
# Paragraph 10 - Speaker: HON. SPEAKER - Ministry: Ministry_of_Rural_Development_MoRD_
# Snippet: building rural prosperity resilience comprehensive multisectoral rural prosperity resilience programme launched partnership states address underemployment agriculture skilling investment technology invigorating rural economy goal generate ample opportunities rural areas migration option necessity
# --------------------------------------------------------------------------------
# Paragraph 14 - Speaker: HON. SPEAKER - Ministry: Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_
# Snippet: years ago concerted efforts succeeded achieving near selfsufficiency pulses farmers responded increasing cultivated area cent arranged procurement remunerative prices rising incomes better affordability consumption pulses increased significantly
# --------------------------------------------------------------------------------
# Paragraph 17 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_
# Snippet: comprehensive programme promote production efficient supplies processing remunerative prices farmers launched partnership states appropriate institutional mechanisms implementation participation farmer producer organizations cooperatives set
# --------------------------------------------------------------------------------
# Paragraph 18 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Food_Processing_Industries_MoFPI_
# Snippet: makhana board bihar special opportunity bihar makhana board established state improve production processing value addition marketing makhana engaged activities organized fpos board provide handholding training makhana farmers work receive benefits relevant schemes
# --------------------------------------------------------------------------------
# Paragraph 21 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_
# Snippet: mission cotton productivity benefit lakhs cotton growing farmers announce mission cotton productivity mission facilitate significant improvements productivity sustainability cotton farming promote extralong staple cotton varieties best science technology provided farmers aligned integrated vision textile sector help increasing incomes farmers steady supply quality cotton rejuvenating indias traditional textile sector
# --------------------------------------------------------------------------------
# Paragraph 28 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Micro_Small_Medium_Enterprises_MoME_
# Snippet: msmes engine msmes engine encompasses manufacturing services focus msmes numbering crore
# --------------------------------------------------------------------------------
# Paragraph 30 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Micro_Small_Medium_Enterprises_MoME_
# Snippet: significant enhancement credit availability guarantee cover improve access credit credit guarantee cover enhanced micro small enterprises crore crore leading additional credit lakh crore years startups crore crore guarantee fee moderated cent loans focus sectors atmanirbhar bharat wellrun exporter msmes term loans crore
# --------------------------------------------------------------------------------
# Paragraph 31 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Micro_Small_Medium_Enterprises_MoME_
# Snippet: credit cards micro enterprises micro enterprises introduce customized credit cards lakh limit micro enterprises registered udyam portal lakh cards issued
# --------------------------------------------------------------------------------
# Paragraph 35 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Textiles_MoT_
# Snippet: focus product scheme footwear leather sectors enhance productivity quality competitiveness indias footwear leather sector focus product scheme implemented scheme design capacity component manufacturing machinery required production nonleather quality footwear leather footwear products scheme expected facilitate employment lakh persons generate turnover lakh crore exports lakh crore
# --------------------------------------------------------------------------------
# Paragraph 37 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Food_Processing_Industries_MoFPI_
# Snippet: food processing line commitment purvodaya establish national institute food technology entrepreneurship management bihar institute provide strong fillip food processing activities entire eastern region result enhanced income farmers value addition produce skilling entrepreneurship employment opportunities youth
# --------------------------------------------------------------------------------
# Paragraph 44 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Education_MoE_
# Snippet: bharatiya bhasha pustak scheme propose implement bharatiya bhasha pustak scheme provide digitalform indian language books school higher education aims help students understand subjects language better
# --------------------------------------------------------------------------------
# Paragraph 50 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Rural_Development_MoRD_
# Snippet: strengthening urban livelihoods giving priority assisting urban poor vulnerable groups scheme socioeconomic upliftment urban workers implemented help improve incomes sustainable livelihoods better quality life
# --------------------------------------------------------------------------------
# Paragraph 59 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Housing_and_Urban_Affairs_MoHUA_
# Snippet: urban challenge fund set urban challenge fund lakh crore implement proposals cities growth hubs creative redevelopment cities water sanitation purposes announced july budget
# --------------------------------------------------------------------------------
# Paragraph 61 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Power_MoP_
# Snippet: power sector reforms incentivize electricity distribution reforms augmentation intrastate transmission capacity states improve financial health capacity electricity companies additional borrowing cent gsdp allowed states contingent reforms
# --------------------------------------------------------------------------------
# Paragraph 62 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Power_MoP_
# Snippet: nuclear energy mission viksit bharat development nuclear energy essential energy transition efforts active partnership private sector goal amendments atomic energy act civil liability nuclear damage act taken
# --------------------------------------------------------------------------------
# Paragraph 63 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Power_MoP_
# Snippet: nuclear energy mission research development small modular reactors smr outlay crore set indigenously developed small modular reactors smrs operationalized
# --------------------------------------------------------------------------------
# Paragraph 73 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: building success swamih fund established blended finance facility contribution banks private investors
# --------------------------------------------------------------------------------
# Paragraph 74 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Micro_Small_Medium_Enterprises_MoME_
# Snippet: fund crore aim expeditious completion lakh units
# --------------------------------------------------------------------------------
# Paragraph 78 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Tourism_MoT_
# Snippet: continuing emphasis places spiritual religious significance july budget special focus destinations related life times buddha
# --------------------------------------------------------------------------------
# Paragraph 82 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Science_and_Technology_MST_
# Snippet: research fellowship years research fellowship scheme provide thousand fellowships technological research iits iisc enhanced financial
# --------------------------------------------------------------------------------
# Paragraph 83 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_
# Snippet: gene bank crops germplasm gene bank lakh germplasm lines set future food nutritional security provide conservation public private sectors genetic resources
# --------------------------------------------------------------------------------
# Paragraph 85 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Culture
# Snippet: gyan bharatam mission gyan bharatam mission survey documentation conservation manuscript heritage academic institutions museums libraries private collectors undertaken cover crore manuscripts set national digital repository indian knowledge systems knowledge sharing
# --------------------------------------------------------------------------------
# Paragraph 90 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_
# Snippet: facilitation groups participation senior officers industry representatives formed select products supply chains
# --------------------------------------------------------------------------------
# Paragraph 94 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Petroleum_and_Natural_Gas_MoPNG_
# Snippet: reforms fuel reforms fuel specific reforms
# --------------------------------------------------------------------------------
# Paragraph 96 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: financial sector reforms development fdi insurance sector fdi limit insurance sector raised cent
# --------------------------------------------------------------------------------
# Paragraph 99 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: credit enhancement facility nabfid nabfid set partial credit enhancement facility corporate bonds infrastructure
# --------------------------------------------------------------------------------
# Paragraph 112 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Statistics_and_Programme_Implementation_MoSPI_
# Snippet: revised estimates revised estimate total receipts borrowings lakh crore net tax receipts lakh crore revised estimate total expenditure lakh crore capital expenditure lakh crore
# --------------------------------------------------------------------------------
# Paragraph 113 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: revised estimate fiscal deficit cent gdp
# --------------------------------------------------------------------------------
# Paragraph 115 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: fiscal deficit estimated cent gdp
# --------------------------------------------------------------------------------
# Paragraph 125 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Heavy_Industries_MoHI_
# Snippet: lithium ion battery list exempted capital goods propose add additional capital goods battery manufacturing additional capital goods mobile phone battery manufacturing boost domestic manufacture lithiumion batteries mobile phones electric vehicles
# --------------------------------------------------------------------------------
# Paragraph 131 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_
# Snippet: marine products enhance indias competitiveness global seafood market propose reduce bcd frozen fish paste surimi manufacture export analogue products propose reduce bcd fish hydrolysates manufacture fish shrimp feeds
# --------------------------------------------------------------------------------
# Paragraph 133 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Railways_MoR_
# Snippet: propose extend dispensation railway goods
# --------------------------------------------------------------------------------
# Paragraph 134 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: trade facilitation limit provisional assessment presently customs act does provide limit finalize provisional assessments leading uncertainty cost trade measure promoting ease doing business propose fix timelimit years extendable finalising provisional assessment
# --------------------------------------------------------------------------------
# Paragraph 153 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: ease doing business streamline transfer pricing provide alternative yearly examination propose introduce scheme determining arms length price international transaction block period years line global best practices
# --------------------------------------------------------------------------------
# Paragraph 161 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Ports_Shipping_and_Waterways_MoPSW_
# Snippet: tonnage tax scheme inland vessels presently tonnage tax scheme available sea going ships benefits existing tonnage tax scheme proposed extended inland vessels registered indian vessels act promote inland water transport country
# --------------------------------------------------------------------------------
# Paragraph 164 - Speaker: SHRI AKHILESH YADAV (KANNAUJ) - Ministry: Ministry_of_Finance_MoF_
# Snippet: alternate investment funds aifs category category aifs undertaking investments infrastructure sectors propose provide certainty taxation entities gains securities
# --------------------------------------------------------------------------------
# Paragraph 165 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: extension investment date sovereign pension funds promote funding sovereign wealth funds pension funds infrastructure sector propose extend date making investment years march
# --------------------------------------------------------------------------------
# Paragraph 169 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: slabs rates changed board benefit taxpayers
# --------------------------------------------------------------------------------
# Paragraph 170 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: structure substantially reduce taxes middle class leave money hands boosting household consumption savings investment
# --------------------------------------------------------------------------------
# Paragraph 171 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: tax regime propose revise tax rate structure follows lakh rupees nil lakh rupees cent lakh rupees cent lakh rupees cent lakh rupees cent lakh rupees cent lakh rupees cent tax payers upto lakh normal income special rate income capital gains read tax payers upto lakh income special rate income capital gains tax rebate provided addition benefit slab rate reduction manner tax payable total tax benefit slab rate changes rebate different income levels illustrated examples
# --------------------------------------------------------------------------------
# Paragraph 172 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: tax payer regime income lakh benefit tax tax payable existing rates person having income lakh benefit tax tax payable existing rates person income lakh gets benefit tax payable existing rates
# --------------------------------------------------------------------------------
# Paragraph 173 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Ministry: Ministry_of_Finance_MoF_
# Snippet: result proposals speaker sir revenue lakh crore direct taxes crore indirect taxes forgone
# --------------------------------------------------------------------------------

# %%
len(matches)
# Out:
# 43

# %%
# total paragraphs = 181
# matches = 43
# top 2 = 33
# top 3 = 46
# top 4 = 59
# top 5 = 65

# %%
# find top 5 errors for ministry classification 
# (vocab top 1 != embedding top 1 and vocab top 1 is comming in top 5 of embedding or vice versa)
errors = []
for res in results:
    vocab_top = max(res["vocab_distribution"], key=res["vocab_distribution"].get)
    embed_top = max(res["embedding_distribution"], key=res["embedding_distribution"].get)

    if vocab_top != embed_top:
        vocab_top_5 = sorted(res["vocab_distribution"].items(), key=lambda x: x[1], reverse=True)[:5]
        embed_top_5 = sorted(res["embedding_distribution"].items(), key=lambda x: x[1], reverse=True)[:5]

        vocab_top_5_ministries = [v[0] for v in vocab_top_5]
        embed_top_5_ministries = [e[0] for e in embed_top_5]

        if (vocab_top in embed_top_5_ministries) or (embed_top in vocab_top_5_ministries):
            errors.append({
                "paragraph_id": res["paragraph_id"],
                "speaker": res["speaker"],
                "vocab_top": vocab_top,
                "embed_top": embed_top,
                "paragraph_snippet": res["paragraph"]
            })
print("\nClassification errors where vocab and embedding disagree but one is in top 5 of the other:")
for error in errors:
    print(f"Paragraph {error['paragraph_id']} - Speaker: {error['speaker']} - Vocab Top: {error['vocab_top']} - Embed Top: {error['embed_top']}")
    print(f"Snippet: {error['paragraph_snippet']}")
    print("-" * 80)
# Out:
# Classification errors where vocab and embedding disagree but one is in top 5 of the other:
# Paragraph 0 - Speaker: HON. SPEAKER - Vocab Top: Ministry_of_Statistics_and_Programme_Implementation_MoSPI_ - Embed Top: Ministry_of_Parliamentary_Affairs_MPA_
# Snippet: honble members ample opportunity participate discussion motion thanks presidents address budget
# --------------------------------------------------------------------------------
# Paragraph 4 - Speaker: HON. SPEAKER - Vocab Top: Ministry_of_External_Affairs_MEA_ - Embed Top: Ministry_of_Tourism_MoT_
# Snippet: embark journey unlock nations tremendous potential prosperity global positioning leadership
# --------------------------------------------------------------------------------
# Paragraph 5 - Speaker: HON. SPEAKER - Vocab Top: Ministry_of_Planning_MoP_ - Embed Top: Ministry_of_External_Affairs_MEA_
# Snippet: prime shri narendra modias complete quarter century continuing geopolitical headwinds suggest lower global economic growth medium termhowever aspiration viksit bharat inspires transformative work governments terms guides march forward resolutelybudget theme economy fastestgrowing major global economies development track record past years structural reforms drawn global attentionconfidence indias capability potential grown period years unique opportunity realize sabka vikas stimulating balanced growth regions
# --------------------------------------------------------------------------------
# Paragraph 12 - Speaker: HON. SPEAKER - Vocab Top: Ministry_of_Commerce_and_Industry_MoCI_ - Embed Top: Ministry_of_Development_of_North_Eastern_Region_MDoNER_
# Snippet: global domestic best practices incorporated appropriate technical financial assistance sought multilateral development banks phase developing agridistricts covered
# --------------------------------------------------------------------------------
# Paragraph 13 - Speaker: HON. SPEAKER - Vocab Top: Ministry_of_Food_Processing_Industries_MoFPI_ - Embed Top: Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_
# Snippet: aatmanirbharta pulses implementing national mission edible oilseed achieving atmanirbhrata edible oils farmers capability grow needs
# --------------------------------------------------------------------------------
# Paragraph 15 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Textiles_MoT_ - Embed Top: Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_
# Snippet: launch mission aatmanirbharta pulses special focus tur urad masoor central agencies nafed nccf ready procure pulses offered years farmers register agencies enter agreements
# --------------------------------------------------------------------------------
# Paragraph 16 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_ - Embed Top: Ministry_of_Agriculture_and_Farmers_Welfare_MoAFW_
# Snippet: comprehensive programme vegetables fruits encouraging increasingly aware nutritional needs sign society healthier rising income levels consumption vegetables fruits shreeanna increasing significantly
# --------------------------------------------------------------------------------
# Paragraph 20 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Fisheries_Animal_Husbandry_and_Dairying_MoFAHD_ - Embed Top: Ministry_of_Ports_Shipping_and_Waterways_MoPSW_
# Snippet: seafood exports valued thousand crore unlock untapped potential marine sector bring enabling framework sustainable harnessing fisheries indian exclusive economic zone high seas special focus andaman nicobar lakshadweep islands
# --------------------------------------------------------------------------------
# Paragraph 23 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Development_of_North_Eastern_Region_MDoNER_ - Embed Top: Ministry_of_Chemicals_and_Fertilizers_MoCF_
# Snippet: urea plant assam atmanirbharta urea production reopened dormant urea plants eastern region augment urea supply plant annual capacity lakh metric tons set namrup assam
# --------------------------------------------------------------------------------
# Paragraph 24 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Communications_MoC_ - Embed Top: Ministry_of_Rural_Development_MoRD_
# Snippet: india post catalyst rural economy india post lakh rural post offices complemented india post payment bank vast network lakh dak sevaks repositioned act catalyst rural economy
# --------------------------------------------------------------------------------
# Paragraph 26 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Rural_Development_MoRD_ - Embed Top: Ministry_of_Micro_Small_Medium_Enterprises_MoME_
# Snippet: meet rising needs viswakarmas entrepreneurs women selfhelp groups msmes large business organizations
# --------------------------------------------------------------------------------
# Paragraph 36 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Textiles_MoT_ - Embed Top: Ministry_of_Heavy_Industries_MoHI_
# Snippet: measures toy sector building national action plan toys implement scheme india global hub toys scheme focus development clusters skills manufacturing ecosystem create highquality unique innovative sustainable toys represent india brand
# --------------------------------------------------------------------------------
# Paragraph 38 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Planning_MoP_ - Embed Top: Ministry_of_Heavy_Industries_MoHI_
# Snippet: manufacturing mission furthering india set national manufacturing mission covering small medium large industries furthering india providing policy execution roadmaps governance monitoring framework central ministries states
# --------------------------------------------------------------------------------
# Paragraph 39 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_New_and_Renewable_Energy_MNRE_ - Embed Top: Ministry_of_Heavy_Industries_MoHI_
# Snippet: clean tech manufacturing given commitment climatefriendly development mission clean tech manufacturing aim improve domestic value addition build ecosystem solar cells batteries motors controllers electrolyzers wind turbines high voltage transmission equipment grid scale batteries
# --------------------------------------------------------------------------------
# Paragraph 41 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Education_MoE_ - Embed Top: Ministry_of_Women_and_Child_Development_MoWCD_
# Snippet: investing saksham anganwadi poshan saksham anganwadi poshan programme provides nutritional crore children crore pregnant women lactating mothers country lakh adolescent girls aspirational districts northeast region cost norms nutritional enhanced appropriately
# --------------------------------------------------------------------------------
# Paragraph 42 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Youth_Affairs_and_Sports_MoYAS_ - Embed Top: Ministry_of_Science_and_Technology_MST_
# Snippet: atal tinkering labs thousand atal tinkering labs set schools years cultivate spirit curiosity innovation foster scientific temper young minds
# --------------------------------------------------------------------------------
# Paragraph 45 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Statistics_and_Programme_Implementation_MoSPI_ - Embed Top: Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_
# Snippet: national centres excellence skilling building initiative announced july budget national centres excellence skilling set global expertise partnerships equip youth skills required india world manufacturing partnerships cover curriculum design training trainers skills certification framework periodic reviews
# --------------------------------------------------------------------------------
# Paragraph 46 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Food_Processing_Industries_MoFPI_ - Embed Top: Ministry_of_Education_MoE_
# Snippet: expansion capacity iits total number students iits increased cent lakh past years additional infrastructure created iits started facilitate education students hostel infrastructure capacity iit patna expanded
# --------------------------------------------------------------------------------
# Paragraph 48 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Health_and_Family_Welfare_MoHFW_ - Embed Top: Ministry_of_Education_MoE_
# Snippet: expansion medical education added lakh medical education seats years increase cent additional seats added medical colleges hospitals goal adding seats years
# --------------------------------------------------------------------------------
# Paragraph 49 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_AYUSH_MoA_ - Embed Top: Ministry_of_Health_and_Family_Welfare_MoHFW_
# Snippet: day care cancer centres district hospitals facilitate setting day care cancer centres district hospitals years centres established
# --------------------------------------------------------------------------------
# Paragraph 51 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Panchayati_Raj_MoPR_ - Embed Top: Ministry_of_Micro_Small_Medium_Enterprises_MoME_
# Snippet: svanidhi svanidhi scheme benefitted lakh street vendors giving respite highinterest informal sector loans building success scheme revamped enhanced loans banks upi linked credit cards limit capacity building
# --------------------------------------------------------------------------------
# Paragraph 56 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Petroleum_and_Natural_Gas_MoPNG_ - Embed Top: Ministry_of_Jal_Shakti_MoJS_
# Snippet: jal jeevan mission crore households representing cent indias rural population provided access potable tap water connections achieve cent coverage announce extension mission enhanced total outlay
# --------------------------------------------------------------------------------
# Paragraph 65 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_ - Embed Top: Ministry_of_Ports_Shipping_and_Waterways_MoPSW_
# Snippet: large ships specified size included infrastructure harmonized master list hml
# --------------------------------------------------------------------------------
# Paragraph 67 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Power_MoP_ - Embed Top: Ministry_of_Ports_Shipping_and_Waterways_MoPSW_
# Snippet: maritime development fund longterm financing maritime industry maritime development fund corpus crore set distributed promoting competition cent contribution balance mobilized ports private sector
# --------------------------------------------------------------------------------
# Paragraph 68 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Development_of_North_Eastern_Region_MDoNER_ - Embed Top: Ministry_of_Road_Transport_and_Highways_MoRTH_
# Snippet: udan regional connectivity scheme udan enabled crore middleclass meet aspirations speedier travel scheme connected airports operationalized routes inspired success modified udan scheme launched enhance regional connectivity destinations carry crore additional passengers yearsthe scheme helipads smaller airports hilly aspirational north east regional districts
# --------------------------------------------------------------------------------
# Paragraph 70 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Coal_MoC_ - Embed Top: Ministry_of_Mines_MoM_
# Snippet: mining sector reforms mining sector reforms including minor minerals encouraged sharing best practices institution state mining index
# --------------------------------------------------------------------------------
# Paragraph 71 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Coal_MoC_ - Embed Top: Ministry_of_Mines_MoM_
# Snippet: policy recovery critical minerals tailings brought
# --------------------------------------------------------------------------------
# Paragraph 72 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Women_and_Child_Development_MoWCD_ - Embed Top: Ministry_of_Rural_Development_MoRD_
# Snippet: swamih fund special window affordable midincome housing swamih thousand dwelling units stressed housing projects completed keys handed homebuyers fortythousand units completed helping middleclass families paying emis loans taken apartments paying rent current dwellings
# --------------------------------------------------------------------------------
# Paragraph 76 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Culture - Embed Top: Ministry_of_Tourism_MoT_
# Snippet: tourism employmentled growth tourist destination sites country developed partnership states challenge mode land building key infrastructure provided states hotels destinations included infrastructure harmonized list
# --------------------------------------------------------------------------------
# Paragraph 77 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Rural_Development_MoRD_ - Embed Top: Ministry_of_Tourism_MoT_
# Snippet: following measures taken facilitating employmentled growth organizing intensive skilldevelopment programmes youth including institutes hospitality management providing mudra loans homestays improving ease travel connectivity tourist destinations providing performancelinked incentives states effective destination management including tourist amenities cleanliness marketing efforts introducing streamlined evisa facilities visafee waivers certain tourist groups
# --------------------------------------------------------------------------------
# Paragraph 79 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Culture - Embed Top: Ministry_of_Tourism_MoT_
# Snippet: medical tourism heal india medical tourism heal india promoted partnership private sector capacity building easier visa norms
# --------------------------------------------------------------------------------
# Paragraph 80 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Tourism_MoT_ - Embed Top: Ministry_of_Planning_MoP_
# Snippet: investing innovation research development innovation implement private sector driven research development innovation initiative announced july budget allocating crore
# --------------------------------------------------------------------------------
# Paragraph 81 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Mines_MoM_ - Embed Top: Ministry_of_Science_and_Technology_MST_
# Snippet: deep tech fund funds deep tech fund funds explored catalyse generation startups initiative
# --------------------------------------------------------------------------------
# Paragraph 86 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Micro_Small_Medium_Enterprises_MoME_ - Embed Top: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: exports engine export promotion mission set export promotion mission sectoral targets driven jointly ministries commerce msme finance facilitate easy access export credit crossborder factoring msmes tackle nontariff measures overseas markets
# --------------------------------------------------------------------------------
# Paragraph 89 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Food_Processing_Industries_MoFPI_ - Embed Top: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: integration global supply chains provided develop domestic manufacturing capacities economys integration global supply chains sectors identified based objective criteria
# --------------------------------------------------------------------------------
# Paragraph 91 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Youth_Affairs_and_Sports_MoYAS_ - Embed Top: Ministry_of_Skill_Development_and_Entrepreneurship_MSDE_
# Snippet: huge opportunities related industry needs high skills talent youth domestic electronic equipment industry leverage opportunity benefit youth
# --------------------------------------------------------------------------------
# Paragraph 93 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_ - Embed Top: Ministry_of_Ports_Shipping_and_Waterways_MoPSW_
# Snippet: warehousing facility air cargo facilitate upgradation infrastructure warehousing air cargo including high value perishable horticulture produce cargo screening customs protocols streamlined userfriendly
# --------------------------------------------------------------------------------
# Paragraph 95 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Culture - Embed Top: Ministry_of_Finance_MoF_
# Snippet: tax reforms past years implemented reforms convenience tax payers faceless assessment tax payers charter faster returns cent returns selfassessment vivad vishwas schemecontinuing efforts reaffirm commitment tax department trust scrutinize later propose introduce incometax week indirect tax reforms changes direct taxes
# --------------------------------------------------------------------------------
# Paragraph 100 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Statistics_and_Programme_Implementation_MoSPI_ - Embed Top: Ministry_of_Panchayati_Raj_MoPR_
# Snippet: grameen credit score public sector banks develop grameen credit score framework serve credit needs shg members rural areas
# --------------------------------------------------------------------------------
# Paragraph 102 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Communications_MoC_ - Embed Top: Ministry_of_Electronics_and_Information_Technology_MeitY_
# Snippet: kyc simplification implement earlier announcement simplifying kyc processes revamped central kyc registry rolled implement streamlined periodic updating
# --------------------------------------------------------------------------------
# Paragraph 104 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Tourism_MoT_ - Embed Top: Ministry_of_External_Affairs_MEA_
# Snippet: bilateral investment treaties proposed interim budget signed bilateral investment treaties bit countries encourage sustained foreign investment spirit develop india current model bit revamped investorfriendly
# --------------------------------------------------------------------------------
# Paragraph 105 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Corporate_Affairs_MCA_ - Embed Top: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: regulatory reforms years aspects including financial nonfinancial demonstrated steadfast commitment ease doing business determined regulations technological innovations global policy developments lighttouch regulatory framework based principles trust unleash productivity employment
# --------------------------------------------------------------------------------
# Paragraph 107 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Commerce_and_Industry_MoCI_ - Embed Top: Ministry_of_Corporate_Affairs_MCA_
# Snippet: develop modern flexible peoplefriendly trustbased regulatory framework appropriate twentyfirst century propose specific measures high level regulatory reforms highlevel regulatory reforms set review nonfinancial sector regulations certifications licenses permissions expected recommendations objective strengthen trustbased economic governance transformational measures enhance ease doing business especially matters inspections compliances states encouraged join endeavour
# --------------------------------------------------------------------------------
# Paragraph 108 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Planning_MoP_ - Embed Top: Ministry_of_Cooperation_MoC_
# Snippet: investment friendliness index states investment friendliness index states launched spirit competitive cooperative federalism
# --------------------------------------------------------------------------------
# Paragraph 110 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Youth_Affairs_and_Sports_MoYAS_ - Embed Top: Ministry_of_Law_and_Justice_MoLJ_
# Snippet: jan vishwas jan vishwas act legal provisions decriminalized bring jan vishwas decriminalize provisions various laws
# --------------------------------------------------------------------------------
# Paragraph 114 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Statistics_and_Programme_Implementation_MoSPI_ - Embed Top: Ministry_of_Finance_MoF_
# Snippet: budget estimates coming total receipts borrowings total expenditure estimated lakh crore lakh crore respectively net tax receipts estimated lakh crore
# --------------------------------------------------------------------------------
# Paragraph 117 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Finance_MoF_ - Embed Top: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: indirect taxes proposals relating customs aim rationalize tariff structure address duty inversion domestic manufacturing value addition promote exports facilitate trade provide relief common
# --------------------------------------------------------------------------------
# Paragraph 118 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Finance_MoF_ - Embed Top: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: rationalisation customs tariff structure industrial goods comprehensive review customs rate structure announced july budget propose remove seven tariff rates seven tariff rates removed budget remaining tariff rates including zero rate apply appropriate cess broadly maintain effective duty incidence items incidence reduce marginally iii levy cess surcharge propose exempt social welfare surcharge tariff lines subject cess
# --------------------------------------------------------------------------------
# Paragraph 119 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_AYUSH_MoA_ - Embed Top: Ministry_of_Chemicals_and_Fertilizers_MoCF_
# Snippet: relief import drugsmedicines provide relief patients particularly suffering cancer rare diseases severe chronic diseases propose add lifesaving drugs medicines list medicines fully exempted basic custom duty bcd propose add lifesaving medicines list attracting concessional custom duty exemption concessional duty respectively apply bulk drugs manufacture
# --------------------------------------------------------------------------------
# Paragraph 120 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Chemicals_and_Fertilizers_MoCF_ - Embed Top: Ministry_of_Health_and_Family_Welfare_MoHFW_
# Snippet: specified drugs medicines patient assistance programmes run pharmaceutical companies fully exempt bcd provided medicines supplied free cost patients propose add medicines patient assistance programmes
# --------------------------------------------------------------------------------
# Paragraph 121 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Heavy_Industries_MoHI_ - Embed Top: Ministry_of_Mines_MoM_
# Snippet: domestic manufacturing value addition critical minerals july budget fully exempted bcd critical minerals domestically available reduced bcd minerals provide major fillip processing especially msmes propose fully exempt cobalt powder waste scrap lithiumion battery lead zinc critical minerals help secure availability manufacturing india promote jobs youth
# --------------------------------------------------------------------------------
# Paragraph 123 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Heavy_Industries_MoHI_ - Embed Top: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: electronic goods line india policy rectify inverted duty structure propose increase bcd interactive flat panel display ifpd reduce bcd open cell components
# --------------------------------------------------------------------------------
# Paragraph 128 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_ - Embed Top: Ministry_of_Communications_MoC_
# Snippet: telecommunication prevent classification disputes propose reduce bcd carrier grade ethernet switches par noncarrier grade ethernet switches
# --------------------------------------------------------------------------------
# Paragraph 129 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Textiles_MoT_ - Embed Top: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: export promotion handicraft goods facilitate exports handicrafts propose extend period export months extendable months required propose add items list dutyfree inputs
# --------------------------------------------------------------------------------
# Paragraph 132 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Personnel_Public_Grievances_and_Pensions_MoPPGP_ - Embed Top: Ministry_of_Railways_MoR_
# Snippet: domestic mros railway goods july budget promote development domestic mros aircraft ships extended limit export foreign origin goods imported repairs months extendable
# --------------------------------------------------------------------------------
# Paragraph 139 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Commerce_and_Industry_MoCI_ - Embed Top: Ministry_of_Finance_MoF_
# Snippet: gone missing kumbh disappeareddirect taxes
# --------------------------------------------------------------------------------
# Paragraph 140 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Home_Affairs_MHA_ - Embed Top: Ministry_of_Finance_MoF_
# Snippet: briefly underlined taxation reforms key reforms realize vision viksit bharat respect criminal law earlier ushered bharatiya nyaya sanhita replacing bharatiya danda sanhita happy inform august country incometax carry forward spirit nyaya drafting
# --------------------------------------------------------------------------------
# Paragraph 146 - Speaker: SHRI ANAND BHADAURIA (DHAURAHRA) - Vocab Top: Ministry_of_Women_and_Child_Development_MoWCD_ - Embed Top: Ministry_of_Finance_MoF_
# Snippet: tdstcs rationalization easing difficulties propose rationalize tax deduction source tds reducing number rates thresholds tds deducted threshold amounts tax deduction increased better clarity uniformity limit tax deduction senior citizens doubled present lakh similarly annual limit lakh tds rent increased lakh reduce number transactions liable tds benefitting small tax payers receiving small payments
# --------------------------------------------------------------------------------
# Paragraph 148 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Electronics_and_Information_Technology_MeitY_ - Embed Top: Ministry_of_Consumer_Affairs_Food_and_Public_Distribution_MoCAF_PD_
# Snippet: tds tcs applied transaction relating sale goods prevent compliance difficulties propose omit tcs propose provisions higher tds deduction apply nonpan cases
# --------------------------------------------------------------------------------
# Paragraph 154 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Civil_Aviation_MoCA_ - Embed Top: Ministry_of_Ports_Shipping_and_Waterways_MoPSW_
# Snippet: view reduce litigation provide certainty international taxation scope safe harbour rules expanded
# --------------------------------------------------------------------------------
# Paragraph 158 - Speaker: SHRI ANAND BHADAURIA (DHAURAHRA) - Vocab Top: Ministry_of_Women_and_Child_Development_MoWCD_ - Embed Top: Ministry_of_Finance_MoF_
# Snippet: july brought vivad vishwas scheme resolve income tax disputes pending appeal scheme received great response nearly tax payers having availed scheme settle disputes
# --------------------------------------------------------------------------------
# Paragraph 160 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Heavy_Industries_MoHI_ - Embed Top: Ministry_of_Commerce_and_Industry_MoCI_
# Snippet: tax certainty electronics manufacturing schemes proposed provide presumptive taxation regime nonresidents provide services resident company establishing operating electronics manufacturing facility propose introduce safe harbour tax certainty nonresidents store components supply specified electronics manufacturing units
# --------------------------------------------------------------------------------
# Paragraph 168 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Road_Transport_and_Highways_MoRTH_ - Embed Top: Ministry_of_Finance_MoF_
# Snippet: right nil tax slab raised lakh raised lakh lakh reflective governments trust middleclass tax payers happy announce income tax payable upto income lakh average income lakh month special rate income capital gains regime limit lakh salaried tax payers standard deduction
# --------------------------------------------------------------------------------
# Paragraph 175 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Statistics_and_Programme_Implementation_MoSPI_ - Embed Top: Ministry_of_Finance_MoF_
# Snippet: sir permission rise lay table following statements section fiscal responsibility budget management frbm act mediumterm fiscal policy cum fiscal policy strategy statement macroeconomic framework statement
# --------------------------------------------------------------------------------
# Paragraph 180 - Speaker: SHRIMATI NIRMALA SITHARAMAN - Vocab Top: Ministry_of_Law_and_Justice_MoLJ_ - Embed Top: Ministry_of_Parliamentary_Affairs_MPA_
# Snippet: lok sabha adjourned till clock monday february magha saka
# --------------------------------------------------------------------------------

# %%
len(errors)
# Out:
# 65

# %%
import numpy as np

def compute_document_distribution(results, method="embedding"):
    
    ministry_scores = {}

    for item in results:

        if method == "embedding":
            dist = item["embedding_distribution"]
        else:
            dist = item["vocab_distribution"]

        for ministry, prob in dist.items():
            ministry_scores[ministry] = ministry_scores.get(ministry, 0) + prob

    # normalize
    total = sum(ministry_scores.values())

    ministry_scores = {
        k: v / total
        for k, v in ministry_scores.items()
    }

    return ministry_scores

# %%
def print_top_ministries(distribution, top_k=10):

    sorted_min = sorted(
        distribution.items(),
        key=lambda x: x[1],
        reverse=True
    )

    print("\nTOP MINISTRIES IN DOCUMENT\n")

    for ministry, score in sorted_min[:top_k]:
        print(f"{ministry:40} {score:.4f}")

# %%
import matplotlib.pyplot as plt

def plot_ministry_distribution(distribution, top_k=10):

    sorted_min = sorted(
        distribution.items(),
        key=lambda x: x[1],
        reverse=True
    )[:top_k]

    ministries = [x[0] for x in sorted_min]
    scores = [x[1] for x in sorted_min]

    plt.figure(figsize=(12,6))

    plt.barh(ministries, scores)

    plt.xlabel("Probability")
    plt.title("Document Ministry Distribution")

    plt.gca().invert_yaxis()

    plt.show()

# %%
def plot_comparison(vocab_dist, embed_dist, top_k=10):

    vocab_sorted = sorted(vocab_dist.items(), key=lambda x: x[1], reverse=True)[:top_k]
    embed_sorted = sorted(embed_dist.items(), key=lambda x: x[1], reverse=True)[:top_k]

    ministries = [x[0] for x in embed_sorted]

    vocab_scores = [vocab_dist.get(m,0) for m in ministries]
    embed_scores = [embed_dist.get(m,0) for m in ministries]

    x = np.arange(len(ministries))

    plt.figure(figsize=(12,6))

    plt.bar(x-0.2, vocab_scores, width=0.4, label="Vocab")
    plt.bar(x+0.2, embed_scores, width=0.4, label="Embedding")

    plt.xticks(x, ministries, rotation=60)
    plt.ylabel("Score")

    plt.title("Ministry Distribution Comparison")

    plt.legend()

    plt.show()

# %%
def build_heatmap_matrix(results, method="embedding"):

    ministries = list(results[0][f"{method}_distribution"].keys())
    num_paragraphs = len(results)

    matrix = np.zeros((len(ministries), num_paragraphs))

    for j, para in enumerate(results):

        dist = para[f"{method}_distribution"]

        for i, ministry in enumerate(ministries):

            matrix[i, j] = dist[ministry]

    return matrix, ministries

import matplotlib.pyplot as plt

def plot_ministry_heatmap(matrix, ministries):

    plt.figure(figsize=(16,8))

    plt.imshow(matrix, aspect='auto')

    plt.colorbar(label="Ministry Relevance")

    plt.ylabel("Ministries")
    plt.xlabel("Paragraph Index")

    plt.yticks(range(len(ministries)), ministries)

    plt.title("Ministry Discussion Heatmap Across Paragraphs")

    plt.show()

# %%
vocab_doc_dist = compute_document_distribution(results, "vocab")
embed_doc_dist = compute_document_distribution(results, "embedding")

print_top_ministries(embed_doc_dist)
# Out:
# TOP MINISTRIES IN DOCUMENT
#
# Ministry_of_Finance_MoF_                 0.0201
# Ministry_of_Micro_Small_Medium_Enterprises_MoME_ 0.0200
# Ministry_of_Commerce_and_Industry_MoCI_  0.0200
# Ministry_of_Rural_Development_MoRD_      0.0198
# Ministry_of_Heavy_Industries_MoHI_       0.0198
# Ministry_of_Development_of_North_Eastern_Region_MDoNER_ 0.0198
# Ministry_of_Food_Processing_Industries_MoFPI_ 0.0195
# Ministry_of_Planning_MoP_                0.0195
# Ministry_of_Housing_and_Urban_Affairs_MoHUA_ 0.0195
# Ministry_of_Cooperation_MoC_             0.0195

# %%
plot_ministry_distribution(embed_doc_dist, top_k=15)

# %%
plot_comparison(vocab_doc_dist, embed_doc_dist, top_k=15)

# %%
matrix, ministries = build_heatmap_matrix(results, "embedding")

plot_ministry_heatmap(matrix, ministries)

# %%
matrix, ministries = build_heatmap_matrix(results, "vocab")

plot_ministry_heatmap(matrix, ministries)

# %%
def plot_top_ministry_heatmap(matrix, ministries, top_k=10):

    ministry_scores = matrix.sum(axis=1)

    top_idx = np.argsort(ministry_scores)[::-1][:top_k]

    top_matrix = matrix[top_idx]
    top_ministries = [ministries[i] for i in top_idx]

    plt.figure(figsize=(16,6))

    plt.imshow(top_matrix, aspect='auto')

    plt.colorbar(label="Relevance")

    plt.yticks(range(top_k), top_ministries)

    plt.xlabel("Paragraph Index")
    plt.ylabel("Top Ministries")

    plt.title("Top Ministry Heatmap Across Paragraphs")

    plt.show()
    
matrix, ministries = build_heatmap_matrix(results)

plot_top_ministry_heatmap(matrix, ministries)

# %%
matrix, ministries = build_heatmap_matrix(results, method="vocab")

plot_top_ministry_heatmap(matrix, ministries)

# %%
from collections import defaultdict

def build_speaker_ministry_matrix(results, method="embedding"):

    speaker_ministry = defaultdict(lambda: defaultdict(float))

    for item in results:

        speaker = item["speaker"]

        dist = item[f"{method}_distribution"]

        for ministry, prob in dist.items():
            speaker_ministry[speaker][ministry] += prob

    speakers = list(speaker_ministry.keys())
    ministries = list(next(iter(speaker_ministry.values())).keys())

    matrix = np.zeros((len(speakers), len(ministries)))

    for i, spk in enumerate(speakers):
        for j, minstry in enumerate(ministries):

            matrix[i, j] = speaker_ministry[spk][minstry]

    # ministers dominate because they speak more
    # it should show speaker focus instead of speaker volume
    # so normalize rows to sum to 1
    matrix = matrix / (matrix.sum(axis=0, keepdims=True) + 1e-9)
    
    return matrix, speakers, ministries

# %%
def select_top_ministries(matrix, ministries, top_k=10):

    scores = matrix.sum(axis=0)

    top_idx = np.argsort(scores)[::-1][:top_k]

    new_matrix = matrix[:, top_idx]

    new_ministries = [ministries[i] for i in top_idx]

    return new_matrix, new_ministries

# %%
import seaborn as sns

def plot_speaker_ministry_heatmap(matrix, speakers, ministries):

    plt.figure(figsize=(14,8))

    sns.heatmap(
        matrix,
        xticklabels=ministries,
        yticklabels=speakers,
        cmap="YlOrRd"
    )

    plt.xlabel("Ministry")
    plt.ylabel("Speaker")

    plt.title("Speaker × Ministry Discussion Heatmap")

    plt.show()

# %%
matrix, speakers, ministries = build_speaker_ministry_matrix(results, method="embedding")

matrix, ministries = select_top_ministries(matrix, ministries, top_k=20)

plot_speaker_ministry_heatmap(matrix, speakers, ministries)

# %%
matrix, speakers, ministries = build_speaker_ministry_matrix(results, method="vocab")

matrix, ministries = select_top_ministries(matrix, ministries, top_k=20)

plot_speaker_ministry_heatmap(matrix, speakers, ministries)

# %%
# def get_paragraph_labels(results, method="embedding"):

#     labels = []

#     for item in results:

#         dist = item[f"{method}_distribution"]

#         ministry = max(dist, key=dist.get)

#         labels.append(ministry)

#     return labels


# def build_transition_matrix(labels):

#     transitions = defaultdict(lambda: defaultdict(int))

#     for i in range(len(labels)-1):

#         src = labels[i]
#         dst = labels[i+1]

#         transitions[src][dst] += 1

#     return transitions


# import networkx as nx

# def build_transition_graph(transitions):

#     G = nx.DiGraph()

#     for src in transitions:
#         for dst in transitions[src]:

#             weight = transitions[src][dst]

#             G.add_edge(src, dst, weight=weight)

#     return G


# def plot_transition_graph(G):

#     plt.figure(figsize=(12,8))

#     pos = nx.spring_layout(G, k=0.8)

#     weights = [G[u][v]['weight'] for u,v in G.edges()]

#     nx.draw(
#         G,
#         pos,
#         with_labels=True,
#         node_size=2500,
#         font_size=8,
#         width=weights
#     )

#     plt.title("Ministry Topic Transition Graph")

#     plt.show()
    
# labels = get_paragraph_labels(results, method="embedding")

# transitions = build_transition_matrix(labels)

# G = build_transition_graph(transitions)

# plot_transition_graph(G)
