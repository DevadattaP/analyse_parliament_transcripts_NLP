# %%
import sys
sys.path.append('..')
from src.topic_modeling.preprocessor import load_ministry_texts

# %%
ministries = load_ministry_texts("../data/ministry_profiles")

# %%
ministries['Ministry_of_Power_MoP_']
# Out:
# 'Ministry of Power MoP Full Form Ministry of Power.\nGenesis and Historical Evolution  Origins Formerly the Ministry of Energy it was restructured to focus specifically n the thermal hydro and nuclear power sectors as well as the national grid nd distribution reforms.\n The "One Nation One Grid" Paradigm A historical marker achieved in 2013 reating a single synchronous grid for the entire country. Modern debates focus n the Green Energy Corridor to integrate renewables into this grid.\n Draft National Electricity Policy NEP 2026 The highest-priority 2026 NLP arker. Released for consultation in early 2026 it targets increasing per capita lectricity consumption from ~1460 kWh to 2000 kWh by 2030 and 4000 kWh y 2047 emphasizing decarbonization and "Viksit Bharat" infrastructure.\n Crucial NLP Distinction Power vs. MNRE * Ministry of Power Handles the Utility Thermal plants Hydro-electric Nuclear Transmission lines Smart Meters and DISCOMs.  MNRE Handles the Source Technology Solar panel
# ...

# %%
temp = """
the	2793	NA	unstop
and	2075	NA	unstop
of	1699	NA	unstop
to	991	NA	unstop
for	728	NA	unstop
in	615	NA	unstop
it	428	NA	unstop
ministry	413	NA	unstop
national	311	NA	unstop
india	308	NA	unstop
act	306	NA	unstop
is	286	NA	unstop
on	273	NA	unstop
with	201	NA	unstop
by	172	NA	unstop
indian	164	NA	unstop
development	155	NA	unstop
scheme	150	NA	unstop
nlp	149	NA	unstop
massive	148	NA	unstop
these	145	NA	unstop
this	144	NA	unstop
as	143	NA	unstop
or	134	NA	unstop
statutory	132	0.70	stop
debates	124	NA	unstop
from	118	NA	unstop
central	117	0.89	stop
nd	110	NA	unstop
under	109	NA	unstop
he	107	NA	unstop
infrastructure	105	0.98	stop
department	103	NA	unstop
mission	100	NA	unstop
india's	97	NA	unstop
an	95	NA	unstop
bodies	93	0.80	stop
research	93	0.62	stop
digital	93	0.61	stop
that	92	NA	unstop
policy	90	0.59	stop
interventions	88	1.0	stop
government	87	NA	unstop
handles	86	0.90	stop
public	86	0.74	stop
like	86	NA	unstop
body	84	0.96	stop
all	84	NA	unstop
was	83	NA	unstop
map	80	1.0	stop
into	79	NA	unstop
sector	79	0.80	stop
regulatory	77	1.0	stop
food	77	0.96	stop
are	76	NA	unstop
key	76	NA	unstop
education	76	0.72	stop
schemes	74	1.0	stop
keywords	73	NA	unstop
form	72	NA	unstop
vs	72	NA	unstop
flagship	72	1.0	stop
specific	72	0.93	stop
health	71	0.84	stop
security	71	0.49	stop
regarding	71	NA	unstop
coal	71	1.0	stop
historical	70	1.0	stop
system	70	1.0	stop
marker	69	1.0	stop
strictly	66	NA	unstop
limited	66	0.59	stop
global	66	0.63	stop
management	66	0.96	stop
technology	65	0.67	stop
financial	65	0.52	stop
institute	65	0.81	stop
bharat	64	NA	unstop
crucial	64	1.0	stop
its	63	NA	unstop
acronyms	62	NA	unstop
welfare	62	1.0	stop
full	61	NA	unstop
provides	61	NA	unstop
at	61	NA	unstop
new	60	NA	unstop
autonomous	59	0.79	stop
highly	59	NA	unstop
water	58	0.90	stop
acts	58	1.0	stop
data	57	0.62	stop
board	57	0.75	stop
critical	57	0.86	stop
domain	56	NA	unstop
training	56	0.64	stop
affairs	56	0.81	stop
evolution	55	0.97	stop
rural	54	0.68	stop
state	54	0.88	stop
genesis	53	1.0	stop
trade	53	0.84	stop
vocabulary	53	NA	unstop
safety	53	0.52	stop
power	52	0.79	stop
authority	52	0.92	stop
through	52	NA	unstop
one	51	NA	unstop
concepts	51	NA	unstop
e.g	51	NA	unstop
origins	50	NA	unstop
while	50	NA	unstop
mentions	49	NA	unstop
major	49	0.79	stop
international	49	0.97	stop
agricultural	49	0.90	stop
steel	49	1.0	stop
commission	48	0.59	stop
model	48	1.0	stop
manufacturing	48	0.82	stop
debated	48	NA	unstop
here	48	NA	unstop
providing	48	1.0	stop
nodal	47	1.0	stop
services	47	0.76	stop
focuses	47	1.0	stop
their	47	NA	unstop
entities	46	1.0	stop
control	46	0.61	stop
programme	45	0.87	stop
over	45	NA	unstop
regulates	44	1.0	stop
urban	44	1.0	stop
council	44	0.62	stop
agency	44	1.0	stop
heavily	43	0.97	stop
most	43	NA	unstop
responsible	43	0.94	stop
which	43	NA	unstop
green	42	0.65	stop
domestic	42	0.70	stop
premier	42	0.94	stop
portal	42	0.94	stop
parliamentary	42	0.84	stop
up	42	NA	unstop
legal	42	0.80	stop
across	42	NA	unstop
foreign	42	0.73	stop
distinction	41	0.96	stop
finance	41	0.86	stop
has	41	NA	unstop
project	41	0.92	stop
moc	41	0.57	stop
framework	40	1.0	stop
pm	40	NA	unstop
include	40	NA	unstop
processing	40	0.80	stop
mines	40	1.0	stop
energy	39	1.0	stop
crore	39	1.0	stop
funding	39	1.0	stop
fund	39	0.72	stop
primary	39	1.0	stop
protection	39	0.60	stop
established	39	1.0	stop
standards	39	0.93	stop
manages	39	0.96	stop
social	39	0.80	stop
industrial	38	0.59	stop
parliament	38	0.81	stop
initiative	38	0.90	stop
yojana	38	0.96	stop
defence	38	1.0	stop
agriculture	38	0.96	stop
focus	37	NA	unstop
deals	37	1.0	stop
dedicated	36	0.85	stop
based	36	NA	unstop
capital	36	0.78	stop
air	36	0.64	stop
medical	36	0.73	stop
update	36	1.0	stop
industry	35	0.79	stop
information	35	0.71	stop
shift	35	0.89	stop
cooperative	35	1.0	stop
modern	34	1.0	stop
production	34	0.86	stop
private	34	1.0	stop
ensure	34	NA	unstop
debate	34	NA	unstop
areas	34	0.71	stop
them	34	NA	unstop
strategic	34	0.65	stop
administrative	34	0.70	stop
corporate	34	0.82	stop
created	33	NA	unstop
states	33	1.0	stop
general	33	1.0	stop
mining	33	0.96	stop
pradhan	33	0.59	stop
mantri	33	0.69	stop
corporation	32	1.0	stop
projects	32	0.90	stop
note	32	NA	unstop
launched	32	1.0	stop
mandate	32	1.0	stop
planning	32	0.62	stop
funds	32	0.88	stop
traditional	31	0.67	stop
apex	30	1.0	stop
industries	30	0.79	stop
export	30	0.92	stop
regulation	30	1.0	stop
two	30	NA	unstop
civil	30	0.80	stop
companies	30	0.79	stop
engineering	30	0.84	stop
country	29	1.0	stop
plants	29	0.67	stop
network	29	0.59	stop
skill	29	0.82	stop
first	29	NA	unstop
centre	29	0.78	stop
ayush	29	1.0	stop
science	29	1.0	stop
farmers	29	0.91	stop
pli	29	0.81	stop
budget	29	0.79	stop
departments	29	0.92	stop
platform	29	0.83	stop
workers	29	1.0	stop
forest	29	0.78	stop
support	28	NA	unstop
if	28	NA	unstop
legislative	28	0.80	stop
promotion	28	0.66	stop
explicitly	28	0.95	stop
provide	28	0.95	stop
independent	28	1.0	stop
testing	28	0.79	stop
rules	28	1.0	stop
cultural	28	1.0	stop
economic	28	0.77	stop
market	27	0.55	stop
via	27	NA	unstop
attached	27	1.0	stop
integrated	27	1.0	stop
tourism	27	0.87	stop
tribal	27	0.95	stop
rd	27	NA	unstop
wing	27	0.87	stop
constitutional	27	0.72	stop
labour	27	0.89	stop
small	26	NA	unstop
amendment	26	NA	unstop
area	26	0.60	stop
your	26	NA	unstop
quality	26	0.89	stop
environment	26	0.72	stop
core	26	1.0	stop
centres	26	0.95	stop
but	26	NA	unstop
mha	26	0.80	stop
law	26	0.79	stop
gas	26	1.0	stop
paradigm	25	0.86	stop
single	25	1.0	stop
solar	25	1.0	stop
context	25	1.0	stop
psu	25	0.83	stop
operates	25	0.86	stop
within	25	NA	unstop
world	25	1.0	stop
institutes	25	0.78	stop
price	25	0.91	stop
building	25	1.0	stop
code	25	0.66	stop
women	25	0.82	stop
youth	25	1.0	stop
consumer	25	0.91	stop
specifically	24	1.0	stop
prices	24	0.84	stop
designed	24	NA	unstop
between	24	NA	unstop
credit	24	0.72	stop
including	24	0.81	stop
psus	24	0.78	stop
recent	24	NA	unstop
focusing	24	0.83	stop
not	24	NA	unstop
commercial	24	0.73	stop
land	24	0.67	stop
office	24	0.79	stop
mod	24	0.81	stop
fertilizers	24	0.88	stop
telecom	24	1.0	stop
distribution	23	0.79	stop
early	23	NA	unstop
they	23	NA	unstop
specialized	23	NA	unstop
must	23	NA	unstop
taxonomy	23	1.0	stop
laws	23	0.88	stop
electronics	23	0.80	stop
service	23	0.62	stop
moafw	23	1.0	stop
insurance	23	0.94	stop
border	23	0.72	stop
technical	22	0.81	stop
regional	22	0.74	stop
heavy	22	1.0	stop
investment	22	0.78	stop
scientific	22	0.56	stop
three	22	NA	unstop
child	22	0.94	stop
north	22	NA	unstop
natural	22	0.65	stop
other	22	NA	unstop
union	22	0.58	stop
gram	22	1.0	stop
historically	22	1.0	stop
indigenous	22	0.73	stop
construction	22	0.59	stop
ocean	22	1.0	stop
mea	22	1.0	stop
sectors	21	1.0	stop
grid	21	0.79	stop
conservation	21	0.66	stop
aims	21	NA	unstop
largest	21	NA	unstop
value	21	NA	unstop
chain	21	0.74	stop
supply	21	1.0	stop
mof	21	0.73	stop
bank	21	0.73	stop
governance	21	0.66	stop
distinct	21	1.0	stop
exclusively	21	1.0	stop
cities	21	0.74	stop
heritage	21	0.87	stop
resources	21	0.67	stop
often	21	NA	unstop
company	21	0.76	stop
forces	21	0.79	stop
bureau	20	0.63	stop
systems	20	1.0	stop
open	20	NA	unstop
commerce	20	1.0	stop
moci	20	0.90	stop
tax	20	0.81	stop
institutions	20	0.73	stop
policies	20	1.0	stop
region	20	0.74	stop
minister	20	NA	unstop
ministries	20	0.79	stop
free	20	0.70	stop
rights	20	0.62	stop
managing	20	1.0	stop
transport	20	0.94	stop
aviation	20	0.90	stop
east	20	0.77	stop
moefcc	20	0.90	stop
mohua	20	1.0	stop
mop	19	0.90	stop
formerly	19	1.0	stop
hydrogen	19	0.86	stop
storage	19	0.70	stop
subsidies	19	0.90	stop
about	19	NA	unstop
frequently	19	0.94	stop
any	19	NA	unstop
prime	19	1.0	stop
registration	19	0.73	stop
business	19	0.65	stop
linked	19	1.0	stop
replaced	19	1.0	stop
innovation	19	1.0	stop
parks	19	1.0	stop
set	19	NA	unstop
organization	19	0.94	stop
disputes	19	0.84	stop
years	19	1.0	stop
marketing	19	0.68	stop
post	19	0.80	stop
growth	19	0.83	stop
per	18	NA	unstop
lakh	18	1.0	stop
msme	18	1.0	stop
monitoring	18	0.62	stop
drugs	18	0.79	stop
capacity	18	0.93	stop
electronic	18	0.79	stop
delhi	18	0.74	stop
eastern	18	0.93	stop
committee	18	NA	unstop
pension	18	0.66	stop
justice	18	1.0	stop
molj	18	1.0	stop
mantralaya	18	1.0	stop
courts	18	0.93	stop
nfrastructure	18	1.0	stop
hub	18	1.0	stop
grants	18	1.0	stop
revolution	18	0.80	stop
force	18	0.86	stop
coastal	18	0.79	stop
ports	18	0.93	stop
housing	18	1.0	stop
climate	18	1.0	stop
both	17	NA	unstop
focused	17	1.0	stop
mandatory	17	1.0	stop
overnment	17	0.68	stop
products	17	0.81	stop
developing	17	1.0	stop
promote	17	0.77	stop
backbone	17	0.93	stop
during	17	1.0	stop
survey	17	0.83	stop
status	17	1.0	stop
year	17	NA	unstop
ecosystem	17	0.79	stop
monitors	17	0.93	stop
administration	17	0.82	stop
district	17	0.58	stop
institution	17	1.0	stop
vikas	17	0.80	stop
administers	17	0.93	stop
crop	17	1.0	stop
directorate	17	1.0	stop
mineral	17	1.0	stop
fisheries	17	0.93	stop
mca	17	0.89	stop
aircraft	17	1.0	stop
mojs	17	1.0	stop
smart	16	1.0	stop
sustainable	16	0.88	stop
undertakings	16	0.72	stop
access	16	1.0	stop
interest	16	1.0	stop
employment	16	0.72	stop
unified	16	0.76	stop
procurement	16	0.56	stop
common	16	0.93	stop
medicine	16	0.93	stop
minimum	16	0.72	stop
facilities	16	0.93	stop
networks	16	1.0	stop
textiles	16	1.0	stop
academic	16	0.78	stop
index	16	0.68	stop
th	16	NA	unstop
divided	16	1.0	stop
maps	16	0.72	stop
special	16	0.79	stop
empowerment	16	0.81	stop
belong	16	0.93	stop
goods	16	1.0	stop
equipment	16	0.60	stop
higher	16	NA	unstop
operations	16	0.85	stop
ensuring	16	0.88	stop
now	16	NA	unstop
metro	16	0.86	stop
meity	16	1.0	stop
change	16	0.86	stop
animal	16	1.0	stop
reforms	15	0.54	stop
mnre	15	1.0	stop
gap	15	0.73	stop
every	15	0.88	stop
exports	15	0.75	stop
loans	15	0.88	stop
use	15	NA	unstop
assistance	15	0.92	stop
mandates	15	1.0	stop
target	15	0.61	stop
subsidy	15	0.73	stop
make	15	NA	unstop
centers	15	1.0	stop
overarching	15	1.0	stop
known	15	1.0	stop
functions	15	0.68	stop
high	15	NA	unstop
care	15	0.73	stop
cooperation	15	0.82	stop
out	15	NA	unstop
components	15	0.79	stop
legacy	15	1.0	stop
home	15	0.65	stop
citizens	15	1.0	stop
ai	15	NA	unstop
article	15	0.80	stop
scheduled	15	0.92	stop
division	15	0.64	stop
umbrella	15	1.0	stop
resource	15	0.92	stop
film	15	1.0	stop
road	15	0.88	stop
"""

# %%
# get lines, seperate by tab, remove rows with stop in 4th column, get first column as word, add to list
stop_words = []
for line in temp.strip().split("\n"):
    parts = line.split("\t")
    if "unstop" in line:
        stop_words.append(parts[0])
stop_words
# Out:
# ['the',
#  'and',
#  'of',
#  'to',
#  'for',
#  'in',
#  'it',
#  'ministry',
#  'national',
#  'india',
#  'act',
#  'is',
#  'on',
#  'with',
#  'by',
#  'indian',
#  'development',
#  'scheme',
#  'nlp',
#  'massive',
#  'these',
#  'this',
#  'as',
#  'or',
#  'debates',
#  'from',
#  'nd',
#  'under',
#  'he',
#  'department',
#  'mission',
#  "india's",
#  'an',
#  'that',
#  'government',
#  'like',
#  'all',
#  'was',
#  'into',
#  'are',
#  'key',
#  'keywords',
#  'form',
#  'vs',
#  'regarding',
#  'strictly',
#  'bharat',
#  'its',
#  'acronyms',
#  'full',
#  'provides',
#  'at',
#  'new',
#  'highly',
#  'domain',
#  'vocabulary',
#  'through',
#  'one',
#  'concepts',
#  'e.g',
#  'origins',
#  'while',
#  'mentions',
#  'debated',
#  'here',
#  'their',
#  'over',
#  'most',
#  'which',
#  'up',
#  'across',
#  'has',
#  'pm',
#  'include',
#  'focus',
#  'based',
#  'ensure',
#  'debate',
#  'them',
#  'created',
#  'note',
#  'two',
#  'first',
#  'support',
# ...

# %%
# write stopwords into file ../data/stopwords/stopwords.txt
with open("../data/stopwords/stopwords.txt", "w", encoding="utf-8") as f:
    for word in stop_words:
        f.write(f"{word}\n")
